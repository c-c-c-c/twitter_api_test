# %% [markdown]
# <a href="https://colab.research.google.com/github/tomonari-masada/course-nlp2020/blob/master/11_topic_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 標準使用ライブラリー
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')
import gc
import os
import shutil
from icecream import ic
from tqdm import tqdm_notebook as tqdm 



# 追記
import json
import datetime
import math

# debug
#%pdb on

import pixiedust #%pixie_debugger

# tfがエラーはかないため
# tfがエラーはかないため
#import tensorflow as tf
#import os
#os.environ["CUDA_VISIBLE_DEVICES"]="5"
#physical_devices = tf.config.experimental.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.19</span>
#         </div>

# %%
import pandas as pd
import re
import emoji
from wordcloud import WordCloud, STOPWORDS

df = pd.read_csv("../data/result0605.csv", engine='python')

type(df["description"])
docs = df["description"].to_list()

# %%
print(len(docs))
# Out:
# 93794

# %% [markdown]
# ### Neologdを使ってtokenizeする

# %%
import subprocess
import MeCab

def make_neologd_tagger():
    cmd='echo `mecab-config --dicdir`"/mecab-ipadic-neologd"'
    path_neologd = (subprocess.Popen(cmd, stdout=subprocess.PIPE,
                               shell=True).communicate()[0]).decode('utf-8')
    m=MeCab.Tagger("-Ochasen -d "+str(path_neologd))
    return (m)


def neolog_prep_text( text, m):
    return_words = []

    
    splited_text = (re.split('[\t,]', line) for line in m.parse(text).split('\n'))
    for tmp_word in splited_text :
        if (tmp_word[0] in ('EOS', '', 't', 'ー') ):
           continue 
        if not re.match( '名詞' ,tmp_word[3]  ) or tmp_word[0] in emoji.UNICODE_EMOJI["en"]:
            continue
        else:
            return_words.append(tmp_word[0])

    return return_words

# %% [markdown]
# * tokenizationの実行

# %%
from tqdm import tqdm


m = make_neologd_tagger()

new_docs = list()
for doc in tqdm(docs):
  if str(doc) == "nan":
    continue
  tmp_words =  neolog_prep_text(str(doc), m)
  new_docs.append( tmp_words )
# Out:
# 100%|██████████| 93794/93794 [01:11<00:00, 1313.81it/s]

# %% [markdown]
# * tokenizationの結果を確認

# %%
print(new_docs[5])
# Out:
# ['過去', 'ジャパリカート', '動画', 'TSUMURI', 'KART', 'VRChat', 'ワリスノ', 'MK', '8', 'DX', '一位', 'りし', 'た人', '社会', '出て', '配信', 'https', 'co', 'FJoitl', '8', 'JHE', 'ヘッダ', '猫', '飼い主', 'smmmmm']

# %% [markdown]
# * 各文書を長い文字列で表しなおす（CountVectorizerを後で使うため）

# %%
corpus = [' '.join(doc) for doc in new_docs]

# %% [markdown]
# ## 11-02 データ行列の作成
# * LDAの場合、単に単語の出現頻度を重みとして各文書をベクトル化する。

# %% [markdown]
# ### sklearnのCountVectorizerで疎行列化する

# %% [markdown]
# * 全文書の半分より多い文書に現れる単語は、高頻度語とみなして削除する。
# * 30件未満の文書にしか現れない単語は、低頻度語とみなして削除する。

# %%
import os
import urllib.request
def download_stopwords(path):
    url = 'http://svn.sourceforge.jp/svnroot/slothlib/CSharp/Version1/SlothLib/NLP/Filter/StopWord/word/Japanese.txt'
    if os.path.exists(path):
        print('File already exists.')
    else:
        print('Downloading...')
        # Download the file from `url` and save it locally under `file_name`:
        urllib.request.urlretrieve(url, path)

def create_stopwords(file_path):
    stop_words = []
    for w in open(path, "r"):
        w = w.replace('\n','')
        if len(w) > 0:
          stop_words.append(w)
    return stop_words    

path = "stop_words.txt"
download_stopwords(path)
stop_words = create_stopwords(path)
# Out:
# File already exists.

# %%
from sklearn.feature_extraction.text import CountVectorizer

MIN_DF = 30

vectorizer = CountVectorizer(max_df=0.5, min_df= MIN_DF, stop_words=stop_words)

X = vectorizer.fit_transform(corpus)

# %%
print(len(vectorizer.get_feature_names()))
# Out:
# 5100

# %% [markdown]
# * 文書数と語彙サイズを変数にセット

# %%
n_samples, n_features = X.shape

# %% [markdown]
# ### TF-IDFで各文書における単語の重みを計算する

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf = TfidfTransformer()
Xtfidf = tfidf.fit_transform(X)

# %%
print(Xtfidf[0])
# Out:
#   (0, 4227)	0.603862693464167
#   (0, 4148)	0.4706802938434637
#   (0, 3490)	0.1847556021921528
#   (0, 3414)	0.33418592758883475
#   (0, 3402)	0.3582132311126842
#   (0, 1747)	0.24047370992039763
#   (0, 1109)	0.28609564411708244

# %%
Xtfidf.shape
# Out:
# (88481, 5100)

# %% [markdown]
# ### LDAのインポート

# %%
from sklearn.decomposition import NMF, LatentDirichletAllocation
from time import time
from matplotlib.backends.backend_pdf import PdfPages
import datetime
from tmtoolkit.topicmod.evaluate import metric_coherence_gensim

# %% [markdown]
# ### トピックの重要語を取り出す関数の定義

# %%
def get_top_words(model, feature_names, n_top_words=30):
  top_features = list()
  weights = list()
  for topic_idx, topic in enumerate(model.components_):
    top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
    top_features.append([feature_names[i] for i in top_features_ind])
    weights.append(topic[top_features_ind])
  return top_features, weights

# %% [markdown]
# # LDAでトピック抽出

# %% [markdown]
# ### LDAによるトピック抽出の実行

# %%
def make_word_cloud(n_components, lda):
    # matplotlib and seaborn for plotting
    import matplotlib.pyplot as plt
    # %matplotlib inline
    import seaborn as sns
    plt.style.use('dark_background')
    top_words, weights = get_top_words(lda, vectorizer.get_feature_names())
    topic_words = [dict(zip(top_words[i], weights[i])) for i in range(n_components)]
    FONT_PATH = "/usr/share/fonts/opentype/ipaexfont-mincho/ipaexm.ttf"
    cloud = WordCloud(stopwords=STOPWORDS,
                  font_path=FONT_PATH,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=100,
                  colormap='tab10'
                  )

    tate = math.ceil(len(topic_words) / 2)
    fig, axes = plt.subplots(tate, 2, figsize=(32, 50), sharex=True, sharey=True)

    for i, ax in enumerate(axes.flatten()):

        if i >= len(topic_words):
            break

        fig.add_subplot(ax)
        cloud.generate_from_frequencies(topic_words[i], max_font_size=500)
        plt.gca().imshow(cloud)
        plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
        plt.gca().axis('off')

    plt.subplots_adjust(wspace=0, hspace=0)
    plt.axis('off')
    plt.margins(x=0, y=0)
    plt.tight_layout()

    pdf = PdfPages( 
                    now_ +'topic.pdf')

    fignums = plt.get_fignums()
    for fignum in fignums:
        plt.figure(fignum)
        pdf.savefig()

    pdf.close()

# %%
import logging
import pickle
import itertools

def lda_main (now_, batch_size ,n_components, topic_word_prior,doc_topic_prior  ,max_iter=30):

    folder_name = now_

    # フォルダを作成
    os.mkdir("../experiment/0714expt/"+folder_name)
    os.chdir("../experiment/0714expt/"+folder_name)


    
    
    lda = LatentDirichletAllocation(n_components=n_components, 
                                    max_iter=max_iter,
                                    topic_word_prior=topic_word_prior, # トピック数の逆数が目安の0.01,0.02,0.05,0.1などなど試す
                                    doc_topic_prior =  doc_topic_prior, 
                                    learning_method='online',
                                    learning_offset=50,
                                    batch_size= batch_size,# 多くする
                                    learning_decay = 0.7,
                                    mean_change_tol=1e-4,
                                    random_state=1,
                                    evaluate_every=1,
                                    verbose=1)
    print((f"Fitting LDA models with tf features, "
    f"n_samples={n_samples} and n_features={n_features}"))
    t0 = time()
    lda.fit(X)
    print(f"done in {time() - t0:0.3f}s.")
    # パラメータの比較はperplexity
    # ハイパーパラメータ調整を頑張る！（やってられない！といわない！！）
    
    
    coherance = metric_coherence_gensim(measure='c_v', 
#                         top_n=20, # これはデフォルトが20
                        topic_word_distrib=lda.components_, 
                        dtm=Xtfidf,  # tfidfの結果
                        vocab=np.array([x for x in vectorizer.vocabulary_.keys()]), 
                        texts=new_docs)
    
    
    results = {
            "perplexity" : lda.perplexity(X) ,
            "coherance": coherance,
        }

    logger.warning('TIME:{0}'.format(now_) )
    logger.warning('MIN_DF:{0}'.format(MIN_DF) )
    logger.warning('params:batch_size:{0}'.format(batch_size)) 
    logger.warning('params:n_components:{0}'.format(n_components)) 
    logger.warning('params:topic_word_prior:{0}'.format(topic_word_prior)) 
    logger.warning('params:doc_topic_prior:{0}'.format(doc_topic_prior)) 
    logger.warning('params:max_iter:{0}'.format(max_iter)) 
    logger.warning('done n_iter:{0}'.format(lda.n_iter_)) 
    logger.warning('perplexity:{0}'.format(results["perplexity"])) 
    logger.warning('coherance:{0}'.format(results["coherance"]) )
    logger.warning('check all params:{0}'.format(lda.get_params() )) 
    make_word_cloud(n_components, lda)
    # pickle
    file_name = now_ + '_lda.pickle'
    with open(file_name, mode="wb") as f:
        pickle.dump(lda, f)
    
#     breakpoint()
    
    os.chdir("../../")
    return(results)

# %%
# logging
logger = logging.getLogger()
fhandler = logging.FileHandler(filename='../experiment/0714expt/mylog.log', mode='a')
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
fhandler.setFormatter(formatter)
logger.addHandler(fhandler)
logger.setLevel(logging.WARNING)

# for batch_size,n_components, topic_word_prior, doc_topic_prior in itertools.product([1500] ,[6, 8, 10,12,15,18,22,25,30,35,40], # 6,8 のあと落ちた、、
# for batch_size,n_components, topic_word_prior, doc_topic_prior in itertools.product([1500] ,[18,22,25,30,35,40], # 6,8 のあと落ちた、、
for batch_size,n_components, topic_word_prior, doc_topic_prior in itertools.product([1500] ,[35,40], # 35からラスト のあと落ちた、、
                                                                                    [0.005,0.01, 0.03,0.05, 0.15, 0.3, 0.4,  0.6, 0.8],[0.005,0.01, 0.03,0.05, 0.15, 0.3, 0.4,  0.6, 0.8] ):
    now_ = (datetime.datetime.now() + datetime.timedelta(hours=9) ) .strftime('%m%d_%H%M')
    
    lda_main(now_, n_components=n_components, topic_word_prior=topic_word_prior, doc_topic_prior = doc_topic_prior, batch_size=batch_size, max_iter=50)
# Out:
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 3887.8140
# iteration: 2 of max_iter: 50, perplexity: 2997.8809
# iteration: 3 of max_iter: 50, perplexity: 2734.5850
# iteration: 4 of max_iter: 50, perplexity: 2670.6449
# iteration: 5 of max_iter: 50, perplexity: 2654.5921
# iteration: 6 of max_iter: 50, perplexity: 2650.2262
# iteration: 7 of max_iter: 50, perplexity: 2648.2637
# iteration: 8 of max_iter: 50, perplexity: 2648.1877
# done in 236.016s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 3324.9636
# iteration: 2 of max_iter: 50, perplexity: 2545.7092
# iteration: 3 of max_iter: 50, perplexity: 2315.3934
# iteration: 4 of max_iter: 50, perplexity: 2252.3703
# iteration: 5 of max_iter: 50, perplexity: 2230.6325
# iteration: 6 of max_iter: 50, perplexity: 2221.1361
# iteration: 7 of max_iter: 50, perplexity: 2216.9933
# iteration: 8 of max_iter: 50, perplexity: 2214.9550
# iteration: 9 of max_iter: 50, perplexity: 2213.7913
# iteration: 10 of max_iter: 50, perplexity: 2213.5463
# iteration: 11 of max_iter: 50, perplexity: 2213.9932
# iteration: 12 of max_iter: 50, perplexity: 2214.6981
# iteration: 13 of max_iter: 50, perplexity: 2215.8314
# iteration: 14 of max_iter: 50, perplexity: 2216.6412
# iteration: 15 of max_iter: 50, perplexity: 2217.3573
# iteration: 16 of max_iter: 50, perplexity: 2217.8734
# iteration: 17 of max_iter: 50, perplexity: 2218.5808
# iteration: 18 of max_iter: 50, perplexity: 2219.2789
# iteration: 19 of max_iter: 50, perplexity: 2219.8932
# iteration: 20 of max_iter: 50, perplexity: 2220.8385
# iteration: 21 of max_iter: 50, perplexity: 2221.4085
# iteration: 22 of max_iter: 50, perplexity: 2222.0601
# iteration: 23 of max_iter: 50, perplexity: 2222.8120
# iteration: 24 of max_iter: 50, perplexity: 2223.4931
# iteration: 25 of max_iter: 50, perplexity: 2223.6321
# iteration: 26 of max_iter: 50, perplexity: 2224.2370
# iteration: 27 of max_iter: 50, perplexity: 2224.4728
# iteration: 28 of max_iter: 50, perplexity: 2224.9382
# iteration: 29 of max_iter: 50, perplexity: 2225.4191
# iteration: 30 of max_iter: 50, perplexity: 2225.8972
# iteration: 31 of max_iter: 50, perplexity: 2226.5832
# iteration: 32 of max_iter: 50, perplexity: 2227.0540
# iteration: 33 of max_iter: 50, perplexity: 2227.4972
# iteration: 34 of max_iter: 50, perplexity: 2227.7186
# iteration: 35 of max_iter: 50, perplexity: 2228.1287
# iteration: 36 of max_iter: 50, perplexity: 2228.5056
# iteration: 37 of max_iter: 50, perplexity: 2228.8705
# iteration: 38 of max_iter: 50, perplexity: 2229.1669
# iteration: 39 of max_iter: 50, perplexity: 2229.3076
# iteration: 40 of max_iter: 50, perplexity: 2229.4376
# iteration: 41 of max_iter: 50, perplexity: 2229.8674
# iteration: 42 of max_iter: 50, perplexity: 2229.9691
# iteration: 43 of max_iter: 50, perplexity: 2230.0784
# iteration: 44 of max_iter: 50, perplexity: 2230.1620
# done in 1133.353s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2795.6636
# iteration: 2 of max_iter: 50, perplexity: 2089.9136
# iteration: 3 of max_iter: 50, perplexity: 1881.7392
# iteration: 4 of max_iter: 50, perplexity: 1820.9090
# iteration: 5 of max_iter: 50, perplexity: 1797.3065
# iteration: 6 of max_iter: 50, perplexity: 1785.1756
# iteration: 7 of max_iter: 50, perplexity: 1778.3343
# iteration: 8 of max_iter: 50, perplexity: 1773.8535
# iteration: 9 of max_iter: 50, perplexity: 1770.4709
# iteration: 10 of max_iter: 50, perplexity: 1768.2857
# iteration: 11 of max_iter: 50, perplexity: 1767.0761
# iteration: 12 of max_iter: 50, perplexity: 1766.0284
# iteration: 13 of max_iter: 50, perplexity: 1765.0296
# iteration: 14 of max_iter: 50, perplexity: 1764.5448
# iteration: 15 of max_iter: 50, perplexity: 1764.2384
# iteration: 16 of max_iter: 50, perplexity: 1763.8479
# iteration: 17 of max_iter: 50, perplexity: 1763.8761
# done in 472.595s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2685.8220
# iteration: 2 of max_iter: 50, perplexity: 1984.2688
# iteration: 3 of max_iter: 50, perplexity: 1777.8970
# iteration: 4 of max_iter: 50, perplexity: 1715.8244
# iteration: 5 of max_iter: 50, perplexity: 1690.3084
# iteration: 6 of max_iter: 50, perplexity: 1676.5675
# iteration: 7 of max_iter: 50, perplexity: 1668.3214
# iteration: 8 of max_iter: 50, perplexity: 1662.6404
# iteration: 9 of max_iter: 50, perplexity: 1658.4928
# iteration: 10 of max_iter: 50, perplexity: 1655.7590
# iteration: 11 of max_iter: 50, perplexity: 1653.5891
# iteration: 12 of max_iter: 50, perplexity: 1651.9349
# iteration: 13 of max_iter: 50, perplexity: 1650.5108
# iteration: 14 of max_iter: 50, perplexity: 1649.3424
# iteration: 15 of max_iter: 50, perplexity: 1648.4634
# iteration: 16 of max_iter: 50, perplexity: 1647.8383
# iteration: 17 of max_iter: 50, perplexity: 1647.3862
# iteration: 18 of max_iter: 50, perplexity: 1646.9809
# iteration: 19 of max_iter: 50, perplexity: 1646.5447
# iteration: 20 of max_iter: 50, perplexity: 1646.1404
# iteration: 21 of max_iter: 50, perplexity: 1645.7460
# iteration: 22 of max_iter: 50, perplexity: 1645.4299
# iteration: 23 of max_iter: 50, perplexity: 1645.2146
# iteration: 24 of max_iter: 50, perplexity: 1644.9774
# iteration: 25 of max_iter: 50, perplexity: 1644.6113
# iteration: 26 of max_iter: 50, perplexity: 1644.3712
# iteration: 27 of max_iter: 50, perplexity: 1644.0964
# iteration: 28 of max_iter: 50, perplexity: 1643.9784
# iteration: 29 of max_iter: 50, perplexity: 1643.8679
# iteration: 30 of max_iter: 50, perplexity: 1643.7036
# iteration: 31 of max_iter: 50, perplexity: 1643.6205
# done in 825.930s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2705.6109
# iteration: 2 of max_iter: 50, perplexity: 1946.6942
# iteration: 3 of max_iter: 50, perplexity: 1720.8966
# iteration: 4 of max_iter: 50, perplexity: 1647.9611
# iteration: 5 of max_iter: 50, perplexity: 1615.5839
# iteration: 6 of max_iter: 50, perplexity: 1596.9947
# iteration: 10 of max_iter: 50, perplexity: 1564.5026
# iteration: 11 of max_iter: 50, perplexity: 1560.2480
# iteration: 12 of max_iter: 50, perplexity: 1556.7633
# iteration: 13 of max_iter: 50, perplexity: 1553.7893
# iteration: 14 of max_iter: 50, perplexity: 1551.1193
# iteration: 15 of max_iter: 50, perplexity: 1548.6441
# iteration: 16 of max_iter: 50, perplexity: 1546.5322
# iteration: 17 of max_iter: 50, perplexity: 1544.7282
# iteration: 18 of max_iter: 50, perplexity: 1543.0776
# iteration: 19 of max_iter: 50, perplexity: 1541.5742
# iteration: 20 of max_iter: 50, perplexity: 1540.2050
# iteration: 21 of max_iter: 50, perplexity: 1539.0414
# iteration: 22 of max_iter: 50, perplexity: 1538.0534
# iteration: 23 of max_iter: 50, perplexity: 1537.1860
# iteration: 24 of max_iter: 50, perplexity: 1536.4301
# iteration: 25 of max_iter: 50, perplexity: 1535.7538
# iteration: 26 of max_iter: 50, perplexity: 1535.1426
# iteration: 27 of max_iter: 50, perplexity: 1534.6008
# iteration: 28 of max_iter: 50, perplexity: 1534.0829
# iteration: 32 of max_iter: 50, perplexity: 1532.4740
# iteration: 33 of max_iter: 50, perplexity: 1532.1379
# iteration: 34 of max_iter: 50, perplexity: 1531.7753
# iteration: 35 of max_iter: 50, perplexity: 1531.4689
# iteration: 36 of max_iter: 50, perplexity: 1531.1710
# iteration: 37 of max_iter: 50, perplexity: 1530.8996
# iteration: 38 of max_iter: 50, perplexity: 1530.6426
# iteration: 39 of max_iter: 50, perplexity: 1530.3727
# iteration: 40 of max_iter: 50, perplexity: 1530.0676
# iteration: 41 of max_iter: 50, perplexity: 1529.8036
# iteration: 42 of max_iter: 50, perplexity: 1529.5324
# iteration: 43 of max_iter: 50, perplexity: 1529.2800
# iteration: 44 of max_iter: 50, perplexity: 1529.0404
# iteration: 45 of max_iter: 50, perplexity: 1528.8194
# iteration: 46 of max_iter: 50, perplexity: 1528.6344
# iteration: 47 of max_iter: 50, perplexity: 1528.4552
# iteration: 48 of max_iter: 50, perplexity: 1528.2826
# iteration: 49 of max_iter: 50, perplexity: 1528.1351
# iteration: 50 of max_iter: 50, perplexity: 1527.9863
# done in 1332.276s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2865.4474
# iteration: 2 of max_iter: 50, perplexity: 2013.1215
# iteration: 3 of max_iter: 50, perplexity: 1750.2011
# iteration: 4 of max_iter: 50, perplexity: 1663.8649
# iteration: 5 of max_iter: 50, perplexity: 1626.3956
# iteration: 6 of max_iter: 50, perplexity: 1605.3436
# iteration: 7 of max_iter: 50, perplexity: 1591.9428
# iteration: 8 of max_iter: 50, perplexity: 1582.8844
# iteration: 9 of max_iter: 50, perplexity: 1576.0650
# iteration: 10 of max_iter: 50, perplexity: 1570.8076
# iteration: 11 of max_iter: 50, perplexity: 1566.5679
# iteration: 12 of max_iter: 50, perplexity: 1563.1710
# iteration: 13 of max_iter: 50, perplexity: 1560.3809
# iteration: 14 of max_iter: 50, perplexity: 1557.9593
# iteration: 15 of max_iter: 50, perplexity: 1555.9785
# iteration: 16 of max_iter: 50, perplexity: 1554.3311
# iteration: 17 of max_iter: 50, perplexity: 1552.9429
# iteration: 18 of max_iter: 50, perplexity: 1551.7458
# iteration: 19 of max_iter: 50, perplexity: 1550.7051
# iteration: 20 of max_iter: 50, perplexity: 1549.8027
# iteration: 21 of max_iter: 50, perplexity: 1549.0263
# iteration: 22 of max_iter: 50, perplexity: 1548.3562
# iteration: 23 of max_iter: 50, perplexity: 1547.7714
# iteration: 24 of max_iter: 50, perplexity: 1547.2557
# iteration: 25 of max_iter: 50, perplexity: 1546.7736
# iteration: 26 of max_iter: 50, perplexity: 1546.3374
# iteration: 27 of max_iter: 50, perplexity: 1545.9484
# iteration: 28 of max_iter: 50, perplexity: 1545.5962
# iteration: 29 of max_iter: 50, perplexity: 1545.2640
# iteration: 30 of max_iter: 50, perplexity: 1544.9603
# iteration: 31 of max_iter: 50, perplexity: 1544.6837
# iteration: 32 of max_iter: 50, perplexity: 1544.4304
# iteration: 33 of max_iter: 50, perplexity: 1544.1964
# iteration: 34 of max_iter: 50, perplexity: 1543.9768
# iteration: 35 of max_iter: 50, perplexity: 1543.7720
# iteration: 36 of max_iter: 50, perplexity: 1543.5833
# iteration: 37 of max_iter: 50, perplexity: 1543.4081
# iteration: 38 of max_iter: 50, perplexity: 1543.2457
# iteration: 39 of max_iter: 50, perplexity: 1543.0931
# iteration: 40 of max_iter: 50, perplexity: 1542.9501
# iteration: 41 of max_iter: 50, perplexity: 1542.8152
# iteration: 42 of max_iter: 50, perplexity: 1542.6884
# iteration: 43 of max_iter: 50, perplexity: 1542.5689
# iteration: 44 of max_iter: 50, perplexity: 1542.4561
# iteration: 45 of max_iter: 50, perplexity: 1542.3498
# iteration: 46 of max_iter: 50, perplexity: 1542.2497
# iteration: 47 of max_iter: 50, perplexity: 1542.1552
# done in 1078.745s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 3006.8380
# iteration: 2 of max_iter: 50, perplexity: 2047.3842
# iteration: 3 of max_iter: 50, perplexity: 1718.2973
# iteration: 4 of max_iter: 50, perplexity: 1597.5825
# iteration: 5 of max_iter: 50, perplexity: 1544.2093
# iteration: 6 of max_iter: 50, perplexity: 1516.3321
# iteration: 7 of max_iter: 50, perplexity: 1499.5757
# iteration: 8 of max_iter: 50, perplexity: 1488.4168
# iteration: 9 of max_iter: 50, perplexity: 1480.6803
# iteration: 10 of max_iter: 50, perplexity: 1475.0116
# iteration: 11 of max_iter: 50, perplexity: 1470.6924
# iteration: 12 of max_iter: 50, perplexity: 1467.2491
# iteration: 13 of max_iter: 50, perplexity: 1464.4777
# iteration: 14 of max_iter: 50, perplexity: 1462.1346
# iteration: 15 of max_iter: 50, perplexity: 1460.0072
# iteration: 16 of max_iter: 50, perplexity: 1458.1517
# iteration: 17 of max_iter: 50, perplexity: 1456.4902
# iteration: 18 of max_iter: 50, perplexity: 1454.9016
# iteration: 19 of max_iter: 50, perplexity: 1453.5088
# iteration: 20 of max_iter: 50, perplexity: 1452.2833
# iteration: 21 of max_iter: 50, perplexity: 1451.2015
# iteration: 22 of max_iter: 50, perplexity: 1450.2389
# iteration: 23 of max_iter: 50, perplexity: 1449.3797
# iteration: 24 of max_iter: 50, perplexity: 1448.6298
# iteration: 25 of max_iter: 50, perplexity: 1447.9507
# iteration: 26 of max_iter: 50, perplexity: 1447.3078
# iteration: 27 of max_iter: 50, perplexity: 1446.7553
# iteration: 28 of max_iter: 50, perplexity: 1446.2650
# iteration: 29 of max_iter: 50, perplexity: 1445.7762
# iteration: 30 of max_iter: 50, perplexity: 1445.2699
# iteration: 31 of max_iter: 50, perplexity: 1444.8310
# iteration: 32 of max_iter: 50, perplexity: 1444.4518
# iteration: 33 of max_iter: 50, perplexity: 1444.1193
# iteration: 34 of max_iter: 50, perplexity: 1443.8237
# iteration: 35 of max_iter: 50, perplexity: 1443.5584
# iteration: 36 of max_iter: 50, perplexity: 1443.3182
# iteration: 37 of max_iter: 50, perplexity: 1443.0991
# iteration: 38 of max_iter: 50, perplexity: 1442.8991
# iteration: 39 of max_iter: 50, perplexity: 1442.7161
# iteration: 40 of max_iter: 50, perplexity: 1442.5478
# iteration: 41 of max_iter: 50, perplexity: 1442.3924
# iteration: 42 of max_iter: 50, perplexity: 1442.2471
# iteration: 43 of max_iter: 50, perplexity: 1442.1070
# iteration: 44 of max_iter: 50, perplexity: 1441.9705
# iteration: 45 of max_iter: 50, perplexity: 1441.8330
# iteration: 46 of max_iter: 50, perplexity: 1441.7014
# iteration: 47 of max_iter: 50, perplexity: 1441.5796
# iteration: 48 of max_iter: 50, perplexity: 1441.4668
# iteration: 49 of max_iter: 50, perplexity: 1441.3616
# iteration: 50 of max_iter: 50, perplexity: 1441.2624
# done in 1002.032s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 4958.9339
# iteration: 2 of max_iter: 50, perplexity: 3063.4944
# iteration: 3 of max_iter: 50, perplexity: 2285.4694
# iteration: 4 of max_iter: 50, perplexity: 1918.8977
# iteration: 5 of max_iter: 50, perplexity: 1732.2415
# iteration: 6 of max_iter: 50, perplexity: 1628.8705
# iteration: 7 of max_iter: 50, perplexity: 1566.2847
# iteration: 8 of max_iter: 50, perplexity: 1525.6158
# iteration: 9 of max_iter: 50, perplexity: 1497.7576
# iteration: 10 of max_iter: 50, perplexity: 1477.8033
# iteration: 11 of max_iter: 50, perplexity: 1462.9563
# iteration: 12 of max_iter: 50, perplexity: 1451.5980
# iteration: 13 of max_iter: 50, perplexity: 1442.6835
# iteration: 14 of max_iter: 50, perplexity: 1435.5005
# iteration: 15 of max_iter: 50, perplexity: 1429.6004
# iteration: 16 of max_iter: 50, perplexity: 1424.6502
# iteration: 17 of max_iter: 50, perplexity: 1420.4203
# iteration: 18 of max_iter: 50, perplexity: 1416.7547
# iteration: 19 of max_iter: 50, perplexity: 1413.5422
# iteration: 20 of max_iter: 50, perplexity: 1410.7060
# iteration: 21 of max_iter: 50, perplexity: 1408.1966
# iteration: 22 of max_iter: 50, perplexity: 1405.9734
# iteration: 23 of max_iter: 50, perplexity: 1404.0070
# iteration: 24 of max_iter: 50, perplexity: 1402.2749
# iteration: 25 of max_iter: 50, perplexity: 1400.7545
# iteration: 26 of max_iter: 50, perplexity: 1399.4207
# iteration: 27 of max_iter: 50, perplexity: 1398.2483
# iteration: 28 of max_iter: 50, perplexity: 1397.2142
# iteration: 29 of max_iter: 50, perplexity: 1396.2981
# iteration: 30 of max_iter: 50, perplexity: 1395.4825
# iteration: 31 of max_iter: 50, perplexity: 1394.7526
# iteration: 32 of max_iter: 50, perplexity: 1394.0956
# iteration: 33 of max_iter: 50, perplexity: 1393.5005
# iteration: 34 of max_iter: 50, perplexity: 1392.9581
# iteration: 35 of max_iter: 50, perplexity: 1392.4604
# iteration: 36 of max_iter: 50, perplexity: 1392.0006
# iteration: 37 of max_iter: 50, perplexity: 1391.5730
# iteration: 38 of max_iter: 50, perplexity: 1391.1730
# iteration: 39 of max_iter: 50, perplexity: 1390.7973
# iteration: 40 of max_iter: 50, perplexity: 1390.4433
# iteration: 41 of max_iter: 50, perplexity: 1390.1093
# iteration: 42 of max_iter: 50, perplexity: 1389.7941
# iteration: 43 of max_iter: 50, perplexity: 1389.4968
# iteration: 44 of max_iter: 50, perplexity: 1389.2165
# iteration: 45 of max_iter: 50, perplexity: 1388.9523
# iteration: 46 of max_iter: 50, perplexity: 1388.7028
# iteration: 47 of max_iter: 50, perplexity: 1388.4672
# iteration: 48 of max_iter: 50, perplexity: 1388.2451
# iteration: 49 of max_iter: 50, perplexity: 1388.0361
# iteration: 50 of max_iter: 50, perplexity: 1387.8397
# done in 922.600s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 7231.8814
# iteration: 2 of max_iter: 50, perplexity: 5049.4296
# iteration: 3 of max_iter: 50, perplexity: 3727.4214
# iteration: 4 of max_iter: 50, perplexity: 2958.5487
# iteration: 5 of max_iter: 50, perplexity: 2502.2326
# iteration: 6 of max_iter: 50, perplexity: 2221.2394
# iteration: 7 of max_iter: 50, perplexity: 2038.6256
# iteration: 8 of max_iter: 50, perplexity: 1913.8280
# iteration: 9 of max_iter: 50, perplexity: 1824.6599
# iteration: 10 of max_iter: 50, perplexity: 1758.3632
# iteration: 11 of max_iter: 50, perplexity: 1707.3690
# iteration: 12 of max_iter: 50, perplexity: 1667.0957
# iteration: 13 of max_iter: 50, perplexity: 1634.6362
# iteration: 14 of max_iter: 50, perplexity: 1608.0831
# iteration: 15 of max_iter: 50, perplexity: 1586.1066
# iteration: 16 of max_iter: 50, perplexity: 1567.7253
# iteration: 17 of max_iter: 50, perplexity: 1552.2107
# iteration: 18 of max_iter: 50, perplexity: 1539.0196
# iteration: 19 of max_iter: 50, perplexity: 1527.7379
# iteration: 20 of max_iter: 50, perplexity: 1518.0437
# iteration: 21 of max_iter: 50, perplexity: 1509.6812
# iteration: 22 of max_iter: 50, perplexity: 1502.4406
# iteration: 23 of max_iter: 50, perplexity: 1496.1456
# iteration: 24 of max_iter: 50, perplexity: 1490.6478
# iteration: 25 of max_iter: 50, perplexity: 1485.8246
# iteration: 26 of max_iter: 50, perplexity: 1481.5763
# iteration: 27 of max_iter: 50, perplexity: 1477.8213
# iteration: 28 of max_iter: 50, perplexity: 1474.4927
# iteration: 29 of max_iter: 50, perplexity: 1471.5340
# iteration: 30 of max_iter: 50, perplexity: 1468.8974
# iteration: 31 of max_iter: 50, perplexity: 1466.5440
# iteration: 32 of max_iter: 50, perplexity: 1464.4399
# iteration: 33 of max_iter: 50, perplexity: 1462.5546
# iteration: 34 of max_iter: 50, perplexity: 1460.8604
# iteration: 35 of max_iter: 50, perplexity: 1459.3334
# iteration: 36 of max_iter: 50, perplexity: 1457.9525
# iteration: 37 of max_iter: 50, perplexity: 1456.6992
# iteration: 38 of max_iter: 50, perplexity: 1455.5577
# iteration: 39 of max_iter: 50, perplexity: 1454.5138
# iteration: 40 of max_iter: 50, perplexity: 1453.5547
# iteration: 41 of max_iter: 50, perplexity: 1452.6700
# iteration: 42 of max_iter: 50, perplexity: 1451.8522
# iteration: 43 of max_iter: 50, perplexity: 1451.0949
# iteration: 44 of max_iter: 50, perplexity: 1450.3920
# iteration: 45 of max_iter: 50, perplexity: 1449.7377
# iteration: 46 of max_iter: 50, perplexity: 1449.1269
# iteration: 47 of max_iter: 50, perplexity: 1448.5550
# iteration: 48 of max_iter: 50, perplexity: 1448.0183
# iteration: 49 of max_iter: 50, perplexity: 1447.5134
# iteration: 50 of max_iter: 50, perplexity: 1447.0374
# done in 996.558s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 3436.9902
# iteration: 2 of max_iter: 50, perplexity: 2805.6702
# iteration: 3 of max_iter: 50, perplexity: 2663.3091
# iteration: 4 of max_iter: 50, perplexity: 2636.2635
# iteration: 5 of max_iter: 50, perplexity: 2630.6233
# iteration: 6 of max_iter: 50, perplexity: 2631.1588
# iteration: 7 of max_iter: 50, perplexity: 2633.4204
# iteration: 8 of max_iter: 50, perplexity: 2635.4987
# iteration: 9 of max_iter: 50, perplexity: 2637.5562
# iteration: 10 of max_iter: 50, perplexity: 2640.1631
# iteration: 11 of max_iter: 50, perplexity: 2642.7644
# iteration: 12 of max_iter: 50, perplexity: 2645.6785
# iteration: 13 of max_iter: 50, perplexity: 2648.0709
# iteration: 14 of max_iter: 50, perplexity: 2649.9606
# iteration: 15 of max_iter: 50, perplexity: 2652.4233
# iteration: 16 of max_iter: 50, perplexity: 2654.5062
# iteration: 17 of max_iter: 50, perplexity: 2656.8635
# iteration: 18 of max_iter: 50, perplexity: 2658.7183
# iteration: 19 of max_iter: 50, perplexity: 2660.0516
# iteration: 20 of max_iter: 50, perplexity: 2662.3748
# iteration: 21 of max_iter: 50, perplexity: 2664.0992
# iteration: 22 of max_iter: 50, perplexity: 2665.9812
# iteration: 23 of max_iter: 50, perplexity: 2667.5785
# iteration: 24 of max_iter: 50, perplexity: 2668.9469
# iteration: 25 of max_iter: 50, perplexity: 2670.0951
# iteration: 26 of max_iter: 50, perplexity: 2671.1135
# iteration: 27 of max_iter: 50, perplexity: 2672.0980
# iteration: 28 of max_iter: 50, perplexity: 2673.2919
# iteration: 29 of max_iter: 50, perplexity: 2674.3960
# iteration: 30 of max_iter: 50, perplexity: 2675.2325
# iteration: 31 of max_iter: 50, perplexity: 2675.7157
# iteration: 32 of max_iter: 50, perplexity: 2676.4769
# iteration: 33 of max_iter: 50, perplexity: 2677.2976
# iteration: 34 of max_iter: 50, perplexity: 2678.1763
# iteration: 35 of max_iter: 50, perplexity: 2678.8213
# iteration: 36 of max_iter: 50, perplexity: 2679.7431
# iteration: 37 of max_iter: 50, perplexity: 2680.4398
# iteration: 38 of max_iter: 50, perplexity: 2681.2071
# iteration: 39 of max_iter: 50, perplexity: 2681.6376
# iteration: 40 of max_iter: 50, perplexity: 2682.1996
# iteration: 41 of max_iter: 50, perplexity: 2682.5737
# iteration: 42 of max_iter: 50, perplexity: 2683.1508
# iteration: 43 of max_iter: 50, perplexity: 2683.9177
# iteration: 44 of max_iter: 50, perplexity: 2684.0447
# iteration: 45 of max_iter: 50, perplexity: 2684.5688
# iteration: 46 of max_iter: 50, perplexity: 2684.8394
# iteration: 47 of max_iter: 50, perplexity: 2685.0718
# iteration: 48 of max_iter: 50, perplexity: 2685.3492
# iteration: 49 of max_iter: 50, perplexity: 2685.7899
# iteration: 50 of max_iter: 50, perplexity: 2686.2824
# done in 1316.407s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2940.1726
# iteration: 2 of max_iter: 50, perplexity: 2383.1881
# iteration: 3 of max_iter: 50, perplexity: 2252.9243
# iteration: 4 of max_iter: 50, perplexity: 2218.6242
# iteration: 5 of max_iter: 50, perplexity: 2207.7701
# iteration: 6 of max_iter: 50, perplexity: 2204.3724
# iteration: 7 of max_iter: 50, perplexity: 2204.0529
# iteration: 8 of max_iter: 50, perplexity: 2204.4719
# iteration: 9 of max_iter: 50, perplexity: 2205.4494
# iteration: 10 of max_iter: 50, perplexity: 2206.7324
# iteration: 11 of max_iter: 50, perplexity: 2207.2825
# iteration: 12 of max_iter: 50, perplexity: 2208.1207
# iteration: 13 of max_iter: 50, perplexity: 2209.5517
# iteration: 14 of max_iter: 50, perplexity: 2211.0013
# iteration: 15 of max_iter: 50, perplexity: 2212.1320
# iteration: 16 of max_iter: 50, perplexity: 2213.0158
# iteration: 17 of max_iter: 50, perplexity: 2213.4706
# iteration: 18 of max_iter: 50, perplexity: 2213.8498
# iteration: 19 of max_iter: 50, perplexity: 2214.6889
# iteration: 20 of max_iter: 50, perplexity: 2215.4433
# iteration: 21 of max_iter: 50, perplexity: 2216.3446
# iteration: 22 of max_iter: 50, perplexity: 2217.3836
# iteration: 23 of max_iter: 50, perplexity: 2218.3540
# iteration: 24 of max_iter: 50, perplexity: 2218.9937
# iteration: 25 of max_iter: 50, perplexity: 2219.5385
# iteration: 26 of max_iter: 50, perplexity: 2220.3426
# iteration: 27 of max_iter: 50, perplexity: 2220.8749
# iteration: 28 of max_iter: 50, perplexity: 2221.4127
# iteration: 29 of max_iter: 50, perplexity: 2221.9514
# iteration: 30 of max_iter: 50, perplexity: 2222.3139
# iteration: 31 of max_iter: 50, perplexity: 2222.4965
# iteration: 32 of max_iter: 50, perplexity: 2223.0051
# iteration: 33 of max_iter: 50, perplexity: 2223.3947
# iteration: 34 of max_iter: 50, perplexity: 2223.6880
# iteration: 35 of max_iter: 50, perplexity: 2224.0534
# iteration: 36 of max_iter: 50, perplexity: 2224.4463
# iteration: 37 of max_iter: 50, perplexity: 2224.6701
# iteration: 38 of max_iter: 50, perplexity: 2224.9408
# iteration: 39 of max_iter: 50, perplexity: 2225.3721
# iteration: 40 of max_iter: 50, perplexity: 2225.7049
# iteration: 41 of max_iter: 50, perplexity: 2226.0870
# iteration: 42 of max_iter: 50, perplexity: 2226.2824
# iteration: 43 of max_iter: 50, perplexity: 2226.6220
# iteration: 44 of max_iter: 50, perplexity: 2227.1964
# iteration: 45 of max_iter: 50, perplexity: 2227.6017
# iteration: 46 of max_iter: 50, perplexity: 2227.7059
# iteration: 47 of max_iter: 50, perplexity: 2227.9895
# iteration: 48 of max_iter: 50, perplexity: 2228.2390
# iteration: 49 of max_iter: 50, perplexity: 2228.5345
# iteration: 50 of max_iter: 50, perplexity: 2228.8038
# done in 1384.100s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2477.4631
# iteration: 2 of max_iter: 50, perplexity: 1962.4587
# iteration: 3 of max_iter: 50, perplexity: 1836.3055
# iteration: 4 of max_iter: 50, perplexity: 1799.1686
# iteration: 5 of max_iter: 50, perplexity: 1783.6612
# iteration: 6 of max_iter: 50, perplexity: 1775.7850
# iteration: 7 of max_iter: 50, perplexity: 1771.1687
# iteration: 8 of max_iter: 50, perplexity: 1768.0723
# iteration: 9 of max_iter: 50, perplexity: 1766.0833
# iteration: 10 of max_iter: 50, perplexity: 1765.2020
# iteration: 11 of max_iter: 50, perplexity: 1764.2617
# iteration: 12 of max_iter: 50, perplexity: 1764.0096
# iteration: 13 of max_iter: 50, perplexity: 1764.0032
# done in 370.472s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2378.9226
# iteration: 2 of max_iter: 50, perplexity: 1860.6666
# iteration: 3 of max_iter: 50, perplexity: 1732.5541
# iteration: 4 of max_iter: 50, perplexity: 1693.6652
# iteration: 5 of max_iter: 50, perplexity: 1676.1442
# iteration: 6 of max_iter: 50, perplexity: 1666.3801
# iteration: 7 of max_iter: 50, perplexity: 1660.2805
# iteration: 8 of max_iter: 50, perplexity: 1655.3190
# iteration: 9 of max_iter: 50, perplexity: 1651.9870
# iteration: 10 of max_iter: 50, perplexity: 1649.5816
# iteration: 11 of max_iter: 50, perplexity: 1647.8812
# iteration: 12 of max_iter: 50, perplexity: 1646.4598
# iteration: 13 of max_iter: 50, perplexity: 1645.4809
# iteration: 14 of max_iter: 50, perplexity: 1644.7106
# iteration: 15 of max_iter: 50, perplexity: 1644.0500
# iteration: 16 of max_iter: 50, perplexity: 1643.4401
# iteration: 17 of max_iter: 50, perplexity: 1643.1177
# iteration: 18 of max_iter: 50, perplexity: 1642.7226
# iteration: 19 of max_iter: 50, perplexity: 1642.4542
# iteration: 20 of max_iter: 50, perplexity: 1642.2548
# iteration: 21 of max_iter: 50, perplexity: 1641.9989
# iteration: 22 of max_iter: 50, perplexity: 1641.8495
# iteration: 23 of max_iter: 50, perplexity: 1641.6995
# iteration: 24 of max_iter: 50, perplexity: 1641.4919
# iteration: 25 of max_iter: 50, perplexity: 1641.3808
# iteration: 26 of max_iter: 50, perplexity: 1641.1859
# iteration: 27 of max_iter: 50, perplexity: 1641.1213
# done in 729.074s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2397.1875
# iteration: 2 of max_iter: 50, perplexity: 1827.2228
# iteration: 3 of max_iter: 50, perplexity: 1680.9088
# iteration: 4 of max_iter: 50, perplexity: 1630.4594
# iteration: 5 of max_iter: 50, perplexity: 1605.0905
# iteration: 6 of max_iter: 50, perplexity: 1589.8313
# iteration: 7 of max_iter: 50, perplexity: 1579.5518
# iteration: 8 of max_iter: 50, perplexity: 1572.0709
# iteration: 9 of max_iter: 50, perplexity: 1566.4131
# iteration: 10 of max_iter: 50, perplexity: 1561.8682
# iteration: 11 of max_iter: 50, perplexity: 1558.1609
# iteration: 12 of max_iter: 50, perplexity: 1555.1227
# iteration: 13 of max_iter: 50, perplexity: 1552.4594
# iteration: 14 of max_iter: 50, perplexity: 1550.0156
# iteration: 15 of max_iter: 50, perplexity: 1547.9024
# iteration: 16 of max_iter: 50, perplexity: 1546.0191
# iteration: 17 of max_iter: 50, perplexity: 1544.4163
# iteration: 18 of max_iter: 50, perplexity: 1542.9977
# iteration: 19 of max_iter: 50, perplexity: 1541.6621
# iteration: 20 of max_iter: 50, perplexity: 1540.4544
# iteration: 21 of max_iter: 50, perplexity: 1539.3776
# iteration: 22 of max_iter: 50, perplexity: 1538.4216
# iteration: 23 of max_iter: 50, perplexity: 1537.5592
# iteration: 24 of max_iter: 50, perplexity: 1536.7641
# iteration: 25 of max_iter: 50, perplexity: 1536.0880
# iteration: 26 of max_iter: 50, perplexity: 1535.4766
# iteration: 27 of max_iter: 50, perplexity: 1534.9293
# iteration: 28 of max_iter: 50, perplexity: 1534.4042
# iteration: 29 of max_iter: 50, perplexity: 1533.9082
# iteration: 30 of max_iter: 50, perplexity: 1533.4836
# iteration: 31 of max_iter: 50, perplexity: 1533.0802
# iteration: 32 of max_iter: 50, perplexity: 1532.6563
# iteration: 33 of max_iter: 50, perplexity: 1532.2762
# iteration: 34 of max_iter: 50, perplexity: 1531.9401
# iteration: 35 of max_iter: 50, perplexity: 1531.6453
# iteration: 36 of max_iter: 50, perplexity: 1531.3529
# iteration: 37 of max_iter: 50, perplexity: 1531.0784
# iteration: 38 of max_iter: 50, perplexity: 1530.8151
# iteration: 39 of max_iter: 50, perplexity: 1530.5838
# iteration: 40 of max_iter: 50, perplexity: 1530.3336
# iteration: 41 of max_iter: 50, perplexity: 1530.1354
# iteration: 42 of max_iter: 50, perplexity: 1529.9469
# iteration: 43 of max_iter: 50, perplexity: 1529.7850
# iteration: 44 of max_iter: 50, perplexity: 1529.6159
# iteration: 45 of max_iter: 50, perplexity: 1529.4557
# iteration: 46 of max_iter: 50, perplexity: 1529.3000
# iteration: 47 of max_iter: 50, perplexity: 1529.1461
# iteration: 48 of max_iter: 50, perplexity: 1528.9937
# iteration: 49 of max_iter: 50, perplexity: 1528.8410
# iteration: 50 of max_iter: 50, perplexity: 1528.7868
# done in 1275.285s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2533.2686
# iteration: 2 of max_iter: 50, perplexity: 1879.4542
# iteration: 3 of max_iter: 50, perplexity: 1705.7896
# iteration: 4 of max_iter: 50, perplexity: 1646.0058
# iteration: 5 of max_iter: 50, perplexity: 1617.2737
# iteration: 6 of max_iter: 50, perplexity: 1599.9930
# iteration: 7 of max_iter: 50, perplexity: 1588.6803
# iteration: 8 of max_iter: 50, perplexity: 1580.8192
# iteration: 9 of max_iter: 50, perplexity: 1574.9573
# iteration: 10 of max_iter: 50, perplexity: 1570.2729
# iteration: 11 of max_iter: 50, perplexity: 1566.6017
# iteration: 12 of max_iter: 50, perplexity: 1563.6747
# iteration: 13 of max_iter: 50, perplexity: 1561.1297
# iteration: 14 of max_iter: 50, perplexity: 1559.0029
# iteration: 15 of max_iter: 50, perplexity: 1557.2467
# iteration: 16 of max_iter: 50, perplexity: 1555.8157
# iteration: 17 of max_iter: 50, perplexity: 1554.6195
# iteration: 18 of max_iter: 50, perplexity: 1553.5661
# iteration: 19 of max_iter: 50, perplexity: 1552.6605
# iteration: 20 of max_iter: 50, perplexity: 1551.8851
# iteration: 21 of max_iter: 50, perplexity: 1551.2111
# iteration: 22 of max_iter: 50, perplexity: 1550.6203
# iteration: 23 of max_iter: 50, perplexity: 1550.0995
# iteration: 24 of max_iter: 50, perplexity: 1549.6280
# iteration: 25 of max_iter: 50, perplexity: 1549.0955
# iteration: 26 of max_iter: 50, perplexity: 1548.6207
# iteration: 27 of max_iter: 50, perplexity: 1548.1924
# iteration: 28 of max_iter: 50, perplexity: 1547.8098
# iteration: 29 of max_iter: 50, perplexity: 1547.4603
# iteration: 30 of max_iter: 50, perplexity: 1547.1435
# iteration: 31 of max_iter: 50, perplexity: 1546.8534
# iteration: 32 of max_iter: 50, perplexity: 1546.5833
# iteration: 33 of max_iter: 50, perplexity: 1546.3336
# iteration: 34 of max_iter: 50, perplexity: 1546.1026
# iteration: 35 of max_iter: 50, perplexity: 1545.8865
# iteration: 36 of max_iter: 50, perplexity: 1545.6850
# iteration: 37 of max_iter: 50, perplexity: 1545.4939
# iteration: 38 of max_iter: 50, perplexity: 1545.3148
# iteration: 39 of max_iter: 50, perplexity: 1545.1473
# iteration: 40 of max_iter: 50, perplexity: 1544.9899
# iteration: 41 of max_iter: 50, perplexity: 1544.8432
# iteration: 42 of max_iter: 50, perplexity: 1544.7060
# iteration: 43 of max_iter: 50, perplexity: 1544.5787
# iteration: 44 of max_iter: 50, perplexity: 1544.4591
# iteration: 45 of max_iter: 50, perplexity: 1544.3490
# iteration: 46 of max_iter: 50, perplexity: 1544.2459
# iteration: 47 of max_iter: 50, perplexity: 1544.1500
# done in 1133.067s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2646.1815
# iteration: 2 of max_iter: 50, perplexity: 1886.7877
# iteration: 3 of max_iter: 50, perplexity: 1657.4454
# iteration: 4 of max_iter: 50, perplexity: 1572.8332
# iteration: 5 of max_iter: 50, perplexity: 1532.1494
# iteration: 6 of max_iter: 50, perplexity: 1509.6459
# iteration: 7 of max_iter: 50, perplexity: 1495.6518
# iteration: 8 of max_iter: 50, perplexity: 1486.1208
# iteration: 9 of max_iter: 50, perplexity: 1479.3969
# iteration: 10 of max_iter: 50, perplexity: 1474.4302
# iteration: 11 of max_iter: 50, perplexity: 1470.6097
# iteration: 12 of max_iter: 50, perplexity: 1467.5586
# iteration: 13 of max_iter: 50, perplexity: 1465.0172
# iteration: 14 of max_iter: 50, perplexity: 1462.8199
# iteration: 15 of max_iter: 50, perplexity: 1460.8311
# iteration: 16 of max_iter: 50, perplexity: 1459.0951
# iteration: 17 of max_iter: 50, perplexity: 1457.5685
# iteration: 18 of max_iter: 50, perplexity: 1456.1243
# iteration: 19 of max_iter: 50, perplexity: 1454.8230
# iteration: 20 of max_iter: 50, perplexity: 1453.6837
# iteration: 21 of max_iter: 50, perplexity: 1452.6788
# iteration: 22 of max_iter: 50, perplexity: 1451.7942
# iteration: 23 of max_iter: 50, perplexity: 1451.0221
# iteration: 24 of max_iter: 50, perplexity: 1450.3458
# iteration: 25 of max_iter: 50, perplexity: 1449.6946
# iteration: 26 of max_iter: 50, perplexity: 1449.1160
# iteration: 27 of max_iter: 50, perplexity: 1448.6148
# iteration: 28 of max_iter: 50, perplexity: 1448.1807
# iteration: 29 of max_iter: 50, perplexity: 1447.7980
# iteration: 30 of max_iter: 50, perplexity: 1447.4461
# iteration: 31 of max_iter: 50, perplexity: 1447.1263
# iteration: 32 of max_iter: 50, perplexity: 1446.8325
# iteration: 33 of max_iter: 50, perplexity: 1446.4726
# iteration: 34 of max_iter: 50, perplexity: 1446.1309
# iteration: 35 of max_iter: 50, perplexity: 1445.8332
# iteration: 36 of max_iter: 50, perplexity: 1445.5719
# iteration: 37 of max_iter: 50, perplexity: 1445.3377
# iteration: 38 of max_iter: 50, perplexity: 1445.1187
# iteration: 39 of max_iter: 50, perplexity: 1444.9166
# iteration: 40 of max_iter: 50, perplexity: 1444.7298
# iteration: 41 of max_iter: 50, perplexity: 1444.5576
# iteration: 42 of max_iter: 50, perplexity: 1444.3995
# iteration: 43 of max_iter: 50, perplexity: 1444.2538
# iteration: 44 of max_iter: 50, perplexity: 1444.1190
# iteration: 45 of max_iter: 50, perplexity: 1443.9939
# iteration: 46 of max_iter: 50, perplexity: 1443.8775
# iteration: 47 of max_iter: 50, perplexity: 1443.7689
# iteration: 48 of max_iter: 50, perplexity: 1443.6674
# iteration: 49 of max_iter: 50, perplexity: 1443.5724
# done in 1152.631s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 4323.0409
# iteration: 2 of max_iter: 50, perplexity: 2721.6171
# iteration: 3 of max_iter: 50, perplexity: 2098.5619
# iteration: 4 of max_iter: 50, perplexity: 1816.2756
# iteration: 5 of max_iter: 50, perplexity: 1672.2964
# iteration: 6 of max_iter: 50, perplexity: 1591.0067
# iteration: 7 of max_iter: 50, perplexity: 1540.7623
# iteration: 8 of max_iter: 50, perplexity: 1507.6091
# iteration: 9 of max_iter: 50, perplexity: 1484.6107
# iteration: 10 of max_iter: 50, perplexity: 1467.9486
# iteration: 11 of max_iter: 50, perplexity: 1455.4618
# iteration: 12 of max_iter: 50, perplexity: 1445.8291
# iteration: 13 of max_iter: 50, perplexity: 1438.2041
# iteration: 14 of max_iter: 50, perplexity: 1432.0302
# iteration: 15 of max_iter: 50, perplexity: 1426.9426
# iteration: 16 of max_iter: 50, perplexity: 1422.6616
# iteration: 17 of max_iter: 50, perplexity: 1418.9884
# iteration: 18 of max_iter: 50, perplexity: 1415.7775
# iteration: 19 of max_iter: 50, perplexity: 1412.9335
# iteration: 20 of max_iter: 50, perplexity: 1410.4078
# iteration: 21 of max_iter: 50, perplexity: 1408.1673
# iteration: 22 of max_iter: 50, perplexity: 1406.1878
# iteration: 23 of max_iter: 50, perplexity: 1404.4459
# iteration: 24 of max_iter: 50, perplexity: 1402.9173
# iteration: 25 of max_iter: 50, perplexity: 1401.5777
# iteration: 26 of max_iter: 50, perplexity: 1400.4027
# iteration: 27 of max_iter: 50, perplexity: 1399.3691
# iteration: 28 of max_iter: 50, perplexity: 1398.4567
# iteration: 29 of max_iter: 50, perplexity: 1397.6477
# iteration: 30 of max_iter: 50, perplexity: 1396.9269
# iteration: 31 of max_iter: 50, perplexity: 1396.2814
# iteration: 32 of max_iter: 50, perplexity: 1395.7008
# iteration: 33 of max_iter: 50, perplexity: 1395.1761
# iteration: 34 of max_iter: 50, perplexity: 1394.6995
# iteration: 35 of max_iter: 50, perplexity: 1394.2636
# iteration: 36 of max_iter: 50, perplexity: 1393.8623
# iteration: 37 of max_iter: 50, perplexity: 1393.4905
# iteration: 38 of max_iter: 50, perplexity: 1393.1442
# iteration: 39 of max_iter: 50, perplexity: 1392.8198
# iteration: 40 of max_iter: 50, perplexity: 1392.5143
# iteration: 41 of max_iter: 50, perplexity: 1392.2250
# iteration: 42 of max_iter: 50, perplexity: 1391.9499
# iteration: 43 of max_iter: 50, perplexity: 1391.6869
# iteration: 44 of max_iter: 50, perplexity: 1391.4342
# iteration: 45 of max_iter: 50, perplexity: 1391.1900
# iteration: 46 of max_iter: 50, perplexity: 1390.9539
# iteration: 47 of max_iter: 50, perplexity: 1390.7263
# iteration: 48 of max_iter: 50, perplexity: 1390.5078
# iteration: 49 of max_iter: 50, perplexity: 1390.2988
# iteration: 50 of max_iter: 50, perplexity: 1390.0993
# done in 910.966s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 6282.7649
# iteration: 2 of max_iter: 50, perplexity: 4428.5687
# iteration: 3 of max_iter: 50, perplexity: 3323.9411
# iteration: 4 of max_iter: 50, perplexity: 2696.8360
# iteration: 5 of max_iter: 50, perplexity: 2328.3668
# iteration: 6 of max_iter: 50, perplexity: 2100.9600
# iteration: 7 of max_iter: 50, perplexity: 1951.8672
# iteration: 8 of max_iter: 50, perplexity: 1848.8973
# iteration: 9 of max_iter: 50, perplexity: 1774.5847
# iteration: 10 of max_iter: 50, perplexity: 1718.8031
# iteration: 11 of max_iter: 50, perplexity: 1675.5076
# iteration: 12 of max_iter: 50, perplexity: 1641.0326
# iteration: 13 of max_iter: 50, perplexity: 1613.0585
# iteration: 14 of max_iter: 50, perplexity: 1590.0482
# iteration: 15 of max_iter: 50, perplexity: 1570.9213
# iteration: 16 of max_iter: 50, perplexity: 1554.8726
# iteration: 17 of max_iter: 50, perplexity: 1541.2902
# iteration: 18 of max_iter: 50, perplexity: 1529.7104
# iteration: 19 of max_iter: 50, perplexity: 1519.7777
# iteration: 20 of max_iter: 50, perplexity: 1511.2170
# iteration: 21 of max_iter: 50, perplexity: 1503.8118
# iteration: 22 of max_iter: 50, perplexity: 1497.3857
# iteration: 23 of max_iter: 50, perplexity: 1491.7905
# iteration: 24 of max_iter: 50, perplexity: 1486.9002
# iteration: 25 of max_iter: 50, perplexity: 1482.6105
# iteration: 26 of max_iter: 50, perplexity: 1478.8387
# iteration: 27 of max_iter: 50, perplexity: 1475.5164
# iteration: 28 of max_iter: 50, perplexity: 1472.5839
# iteration: 29 of max_iter: 50, perplexity: 1469.9891
# iteration: 30 of max_iter: 50, perplexity: 1467.6869
# iteration: 31 of max_iter: 50, perplexity: 1465.6388
# iteration: 32 of max_iter: 50, perplexity: 1463.8112
# iteration: 33 of max_iter: 50, perplexity: 1462.1745
# iteration: 34 of max_iter: 50, perplexity: 1460.7035
# iteration: 35 of max_iter: 50, perplexity: 1459.3776
# iteration: 36 of max_iter: 50, perplexity: 1458.1790
# iteration: 37 of max_iter: 50, perplexity: 1457.0922
# iteration: 38 of max_iter: 50, perplexity: 1456.1032
# iteration: 39 of max_iter: 50, perplexity: 1455.1995
# iteration: 40 of max_iter: 50, perplexity: 1454.3703
# iteration: 41 of max_iter: 50, perplexity: 1453.6058
# iteration: 42 of max_iter: 50, perplexity: 1452.8975
# iteration: 43 of max_iter: 50, perplexity: 1452.2382
# iteration: 44 of max_iter: 50, perplexity: 1451.6216
# iteration: 45 of max_iter: 50, perplexity: 1451.0428
# iteration: 46 of max_iter: 50, perplexity: 1450.4977
# iteration: 47 of max_iter: 50, perplexity: 1449.9832
# iteration: 48 of max_iter: 50, perplexity: 1449.4969
# iteration: 49 of max_iter: 50, perplexity: 1449.0365
# iteration: 50 of max_iter: 50, perplexity: 1448.6003
# done in 970.652s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2954.3247
# iteration: 2 of max_iter: 50, perplexity: 2660.1265
# iteration: 3 of max_iter: 50, perplexity: 2613.7488
# iteration: 4 of max_iter: 50, perplexity: 2607.9460
# iteration: 5 of max_iter: 50, perplexity: 2612.3021
# iteration: 6 of max_iter: 50, perplexity: 2618.6240
# iteration: 7 of max_iter: 50, perplexity: 2624.4279
# iteration: 8 of max_iter: 50, perplexity: 2629.2629
# iteration: 9 of max_iter: 50, perplexity: 2632.1390
# iteration: 10 of max_iter: 50, perplexity: 2635.8572
# iteration: 11 of max_iter: 50, perplexity: 2639.2966
# iteration: 12 of max_iter: 50, perplexity: 2642.1796
# iteration: 13 of max_iter: 50, perplexity: 2644.5764
# iteration: 14 of max_iter: 50, perplexity: 2647.6349
# iteration: 15 of max_iter: 50, perplexity: 2650.0967
# iteration: 16 of max_iter: 50, perplexity: 2652.3551
# iteration: 17 of max_iter: 50, perplexity: 2655.0555
# iteration: 18 of max_iter: 50, perplexity: 2657.7478
# iteration: 19 of max_iter: 50, perplexity: 2659.9687
# iteration: 20 of max_iter: 50, perplexity: 2662.2328
# iteration: 21 of max_iter: 50, perplexity: 2663.8162
# iteration: 22 of max_iter: 50, perplexity: 2665.5390
# iteration: 23 of max_iter: 50, perplexity: 2666.9553
# iteration: 24 of max_iter: 50, perplexity: 2668.5076
# iteration: 25 of max_iter: 50, perplexity: 2670.0604
# iteration: 26 of max_iter: 50, perplexity: 2671.6940
# iteration: 27 of max_iter: 50, perplexity: 2673.2149
# iteration: 28 of max_iter: 50, perplexity: 2674.5892
# iteration: 29 of max_iter: 50, perplexity: 2675.7943
# iteration: 30 of max_iter: 50, perplexity: 2676.8506
# iteration: 31 of max_iter: 50, perplexity: 2677.9899
# iteration: 32 of max_iter: 50, perplexity: 2678.7654
# iteration: 33 of max_iter: 50, perplexity: 2679.8977
# iteration: 34 of max_iter: 50, perplexity: 2680.8108
# iteration: 35 of max_iter: 50, perplexity: 2681.9501
# iteration: 36 of max_iter: 50, perplexity: 2683.0999
# iteration: 37 of max_iter: 50, perplexity: 2683.8966
# iteration: 38 of max_iter: 50, perplexity: 2684.6467
# iteration: 39 of max_iter: 50, perplexity: 2686.0375
# iteration: 40 of max_iter: 50, perplexity: 2686.8258
# iteration: 41 of max_iter: 50, perplexity: 2687.7108
# iteration: 42 of max_iter: 50, perplexity: 2688.4040
# iteration: 43 of max_iter: 50, perplexity: 2689.1942
# iteration: 44 of max_iter: 50, perplexity: 2689.7629
# iteration: 45 of max_iter: 50, perplexity: 2690.1631
# iteration: 46 of max_iter: 50, perplexity: 2690.8268
# iteration: 47 of max_iter: 50, perplexity: 2691.2597
# iteration: 48 of max_iter: 50, perplexity: 2691.7347
# iteration: 49 of max_iter: 50, perplexity: 2691.9228
# iteration: 50 of max_iter: 50, perplexity: 2692.4986
# done in 1342.195s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2532.5981
# iteration: 2 of max_iter: 50, perplexity: 2262.1995
# iteration: 3 of max_iter: 50, perplexity: 2211.3977
# iteration: 4 of max_iter: 50, perplexity: 2199.8905
# iteration: 5 of max_iter: 50, perplexity: 2198.6851
# iteration: 6 of max_iter: 50, perplexity: 2201.6137
# iteration: 7 of max_iter: 50, perplexity: 2203.7414
# iteration: 8 of max_iter: 50, perplexity: 2206.3463
# iteration: 9 of max_iter: 50, perplexity: 2208.2553
# iteration: 10 of max_iter: 50, perplexity: 2210.2006
# iteration: 11 of max_iter: 50, perplexity: 2212.6221
# iteration: 12 of max_iter: 50, perplexity: 2214.4395
# iteration: 13 of max_iter: 50, perplexity: 2216.1943
# iteration: 14 of max_iter: 50, perplexity: 2218.2408
# iteration: 15 of max_iter: 50, perplexity: 2219.5158
# iteration: 16 of max_iter: 50, perplexity: 2220.8695
# iteration: 17 of max_iter: 50, perplexity: 2221.9664
# iteration: 18 of max_iter: 50, perplexity: 2222.9807
# iteration: 19 of max_iter: 50, perplexity: 2224.3332
# iteration: 20 of max_iter: 50, perplexity: 2225.4888
# iteration: 21 of max_iter: 50, perplexity: 2226.4521
# iteration: 22 of max_iter: 50, perplexity: 2227.2383
# iteration: 27 of max_iter: 50, perplexity: 2230.9930
# iteration: 28 of max_iter: 50, perplexity: 2231.8554
# iteration: 29 of max_iter: 50, perplexity: 2232.8404
# iteration: 30 of max_iter: 50, perplexity: 2233.4714
# iteration: 31 of max_iter: 50, perplexity: 2234.2628
# iteration: 32 of max_iter: 50, perplexity: 2234.8657
# iteration: 33 of max_iter: 50, perplexity: 2235.5598
# iteration: 34 of max_iter: 50, perplexity: 2236.3955
# iteration: 35 of max_iter: 50, perplexity: 2237.0214
# iteration: 36 of max_iter: 50, perplexity: 2237.6142
# iteration: 37 of max_iter: 50, perplexity: 2238.1821
# iteration: 38 of max_iter: 50, perplexity: 2238.7122
# iteration: 39 of max_iter: 50, perplexity: 2239.2075
# iteration: 40 of max_iter: 50, perplexity: 2239.6930
# iteration: 41 of max_iter: 50, perplexity: 2239.9734
# iteration: 42 of max_iter: 50, perplexity: 2240.3625
# iteration: 43 of max_iter: 50, perplexity: 2240.6285
# iteration: 44 of max_iter: 50, perplexity: 2240.8001
# iteration: 45 of max_iter: 50, perplexity: 2241.0031
# iteration: 46 of max_iter: 50, perplexity: 2241.3256
# iteration: 47 of max_iter: 50, perplexity: 2241.6809
# iteration: 48 of max_iter: 50, perplexity: 2241.6936
# done in 1237.389s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2134.3702
# iteration: 2 of max_iter: 50, perplexity: 1862.2433
# iteration: 3 of max_iter: 50, perplexity: 1804.8309
# iteration: 4 of max_iter: 50, perplexity: 1786.2360
# iteration: 5 of max_iter: 50, perplexity: 1777.9027
# iteration: 6 of max_iter: 50, perplexity: 1774.0456
# iteration: 7 of max_iter: 50, perplexity: 1771.7294
# iteration: 8 of max_iter: 50, perplexity: 1770.2043
# iteration: 9 of max_iter: 50, perplexity: 1769.2123
# iteration: 10 of max_iter: 50, perplexity: 1768.6924
# iteration: 11 of max_iter: 50, perplexity: 1768.3303
# iteration: 12 of max_iter: 50, perplexity: 1768.5041
# iteration: 13 of max_iter: 50, perplexity: 1768.7450
# iteration: 14 of max_iter: 50, perplexity: 1769.0275
# iteration: 15 of max_iter: 50, perplexity: 1769.2410
# iteration: 16 of max_iter: 50, perplexity: 1769.6055
# iteration: 17 of max_iter: 50, perplexity: 1769.7796
# iteration: 18 of max_iter: 50, perplexity: 1770.1754
# iteration: 19 of max_iter: 50, perplexity: 1770.3756
# iteration: 20 of max_iter: 50, perplexity: 1770.4094
# done in 572.838s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 2051.2484
# iteration: 2 of max_iter: 50, perplexity: 1766.4576
# iteration: 3 of max_iter: 50, perplexity: 1704.5251
# iteration: 4 of max_iter: 50, perplexity: 1682.6478
# iteration: 5 of max_iter: 50, perplexity: 1672.0873
# iteration: 6 of max_iter: 50, perplexity: 1665.6102
# iteration: 7 of max_iter: 50, perplexity: 1661.5548
# iteration: 8 of max_iter: 50, perplexity: 1658.8714
# iteration: 9 of max_iter: 50, perplexity: 1656.8421
# iteration: 10 of max_iter: 50, perplexity: 1655.2431
# iteration: 11 of max_iter: 50, perplexity: 1654.1432
# iteration: 12 of max_iter: 50, perplexity: 1653.3220
# iteration: 13 of max_iter: 50, perplexity: 1652.8215
# iteration: 14 of max_iter: 50, perplexity: 1652.3394
# iteration: 15 of max_iter: 50, perplexity: 1651.9809

# %% [markdown]
# ### results

# %%
tmp_results

# %% [markdown]
# ### プロフィールを

# %%
def get_top_prof (topic_idx, top_n = 100):
    
    topics = lda.transform(X)
    prof_idx_list = topics[:, topic_idx].argsort()[:-top_n - 1:-1]
    return [docs[d] for d in prof_idx_list]

# %%
# get_top_prof(0, 20)

# %%
# get_top_prof(1, 20)

# %%
# get_top_prof(2, 20)

# %%
# get_top_prof(3, 20)

# %%
# get_top_prof(4, 20)

# %%
# get_top_prof(5, 20)

# %%
nownow_file = (datetime.datetime.now() + datetime.timedelta(hours=9) ).strftime('%m%d_%H%M')+"topic_modeling.ipynb"

# !cp ./topic_modeling.ipynb ./jupyter_backup_for_param/$nownow_file

# %%
file_name = (datetime.datetime.now() + datetime.timedelta(hours=9) ) .strftime('%m%d_%H%M')+"_output.txt"
