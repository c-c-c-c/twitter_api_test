# %% [markdown]
# <a href="https://colab.research.google.com/github/tomonari-masada/course-nlp2020/blob/master/11_topic_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 標準使用ライブラリー
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')
import gc
import os
import shutil
from icecream import ic
from tqdm import tqdm_notebook as tqdm 



# 追記
import json
import datetime
import math

# debug
#%pdb on

import pixiedust #%pixie_debugger

# tfがエラーはかないため
# tfがエラーはかないため
#import tensorflow as tf
#import os
#os.environ["CUDA_VISIBLE_DEVICES"]="5"
#physical_devices = tf.config.experimental.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.19</span>
#         </div>

# %%
import pandas as pd
import re
import emoji
from wordcloud import WordCloud, STOPWORDS

df = pd.read_csv("./result0605.csv", engine='python')

type(df["description"])
docs = df["description"].to_list()

# %%
print(len(docs))
# Out:
# 93794

# %% [markdown]
# ### Neologdを使ってtokenizeする

# %%
import subprocess
import MeCab

def make_neologd_tagger():
    cmd='echo `mecab-config --dicdir`"/mecab-ipadic-neologd"'
    path_neologd = (subprocess.Popen(cmd, stdout=subprocess.PIPE,
                               shell=True).communicate()[0]).decode('utf-8')
    m=MeCab.Tagger("-Ochasen -d "+str(path_neologd))
    return (m)


def neolog_prep_text( text, m):
    return_words = []

    
    splited_text = (re.split('[\t,]', line) for line in m.parse(text).split('\n'))
    for tmp_word in splited_text :
        if (tmp_word[0] in ('EOS', '', 't', 'ー') ):
           continue 
        if not re.match( '名詞' ,tmp_word[3]  ) or tmp_word[0] in emoji.UNICODE_EMOJI["en"]:
            continue
        else:
            return_words.append(tmp_word[0])

    return return_words

# %% [markdown]
# * tokenizationの実行

# %%
from tqdm import tqdm


m = make_neologd_tagger()

new_docs = list()
for doc in tqdm(docs):
  if str(doc) == "nan":
    continue
  tmp_words =  neolog_prep_text(str(doc), m)
  new_docs.append( tmp_words )
# Out:
# 100%|██████████| 93794/93794 [00:23<00:00, 3931.52it/s]

# %% [markdown]
# * tokenizationの結果を確認

# %%
print(new_docs[5])
# Out:
# ['過去', 'ジャパリカート', '動画', 'TSUMURI', 'KART', 'VRChat', 'ワリスノ', 'MK', '8', 'DX', '一位', 'りし', 'た人', '社会', '出て', '配信', 'https', 'co', 'FJoitl', '8', 'JHE', 'ヘッダ', '猫', '飼い主', 'smmmmm']

# %% [markdown]
# * 各文書を長い文字列で表しなおす（CountVectorizerを後で使うため）

# %%
corpus = [' '.join(doc) for doc in new_docs]

# %% [markdown]
# ## 11-02 データ行列の作成
# * LDAの場合、単に単語の出現頻度を重みとして各文書をベクトル化する。

# %% [markdown]
# ### sklearnのCountVectorizerで疎行列化する

# %% [markdown]
# * 全文書の半分より多い文書に現れる単語は、高頻度語とみなして削除する。
# * 30件未満の文書にしか現れない単語は、低頻度語とみなして削除する。

# %%
import os
import urllib.request
def download_stopwords(path):
    url = 'http://svn.sourceforge.jp/svnroot/slothlib/CSharp/Version1/SlothLib/NLP/Filter/StopWord/word/Japanese.txt'
    if os.path.exists(path):
        print('File already exists.')
    else:
        print('Downloading...')
        # Download the file from `url` and save it locally under `file_name`:
        urllib.request.urlretrieve(url, path)

def create_stopwords(file_path):
    stop_words = []
    for w in open(path, "r"):
        w = w.replace('\n','')
        if len(w) > 0:
          stop_words.append(w)
    return stop_words    

path = "stop_words.txt"
download_stopwords(path)
stop_words = create_stopwords(path)
# Out:
# File already exists.

# %%
from sklearn.feature_extraction.text import CountVectorizer

MIN_DF = 30

vectorizer = CountVectorizer(max_df=0.5, min_df= MIN_DF, stop_words=stop_words)

X = vectorizer.fit_transform(corpus)

# %%
print(len(vectorizer.get_feature_names()))
# Out:
# 5100

# %% [markdown]
# * 文書数と語彙サイズを変数にセット

# %%
n_samples, n_features = X.shape

# %% [markdown]
# ### TF-IDFで各文書における単語の重みを計算する

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf = TfidfTransformer()
Xtfidf = tfidf.fit_transform(X)

# %%
print(Xtfidf[0])
# Out:
#   (0, 4227)	0.603862693464167
#   (0, 4148)	0.4706802938434637
#   (0, 3490)	0.1847556021921528
#   (0, 3414)	0.3341859275888348
#   (0, 3402)	0.3582132311126841
#   (0, 1747)	0.24047370992039763
#   (0, 1109)	0.2860956441170824

# %%
Xtfidf.shape
# Out:
# (88481, 5100)

# %% [markdown]
# ### LDAのインポート

# %%
from sklearn.decomposition import NMF, LatentDirichletAllocation
from time import time
from matplotlib.backends.backend_pdf import PdfPages
import datetime
from tmtoolkit.topicmod.evaluate import metric_coherence_gensim

# %% [markdown]
# ### トピックの重要語を取り出す関数の定義

# %%
def get_top_words(model, feature_names, n_top_words=30):
  top_features = list()
  weights = list()
  for topic_idx, topic in enumerate(model.components_):
    top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
    top_features.append([feature_names[i] for i in top_features_ind])
    weights.append(topic[top_features_ind])
  return top_features, weights

# %% [markdown]
# # LDAでトピック抽出

# %% [markdown]
# ### LDAによるトピック抽出の実行

# %%
def make_word_cloud(n_components, lda):
    # matplotlib and seaborn for plotting
    import matplotlib.pyplot as plt
    # %matplotlib inline
    import seaborn as sns
    plt.style.use('dark_background')
    top_words, weights = get_top_words(lda, vectorizer.get_feature_names())
    topic_words = [dict(zip(top_words[i], weights[i])) for i in range(n_components)]
    FONT_PATH = "/usr/share/fonts/opentype/ipaexfont-mincho/ipaexm.ttf"
    cloud = WordCloud(stopwords=STOPWORDS,
                  font_path=FONT_PATH,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=100,
                  colormap='tab10'
                  )

    tate = math.ceil(n_components / 2)
    fig, axes = plt.subplots(tate, 2, figsize=(32, 50), sharex=True, sharey=True)

    for i, ax in enumerate(axes.flatten()):

        if i > len(topic_words)-1:
            break

        fig.add_subplot(ax)
        cloud.generate_from_frequencies(topic_words[i], max_font_size=500)
        plt.gca().imshow(cloud)
        plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
        plt.gca().axis('off')

    plt.subplots_adjust(wspace=0, hspace=0)
    plt.axis('off')
    plt.margins(x=0, y=0)
    plt.tight_layout()

    pdf = PdfPages( 
        (datetime.datetime.now() + datetime.timedelta(hours=9) ) .strftime('%m%d_%H%M') + 'topic.pdf')


    fignums = plt.get_fignums()
    for fignum in fignums:
        plt.figure(fignum)
        pdf.savefig()

    pdf.close()

# %%
import logging
import pickle
import itertools

def lda_main (batch_size ,n_components, topic_word_prior,doc_topic_prior  ,max_iter=30):

    folder_name = (datetime.datetime.now() + datetime.timedelta(hours=9) ) .strftime('%m%d_%H%M')

    # フォルダを作成
    os.mkdir("./"+folder_name)
    os.chdir("./"+folder_name)

    # logging
    logger = logging.getLogger()
    fhandler = logging.FileHandler(filename='mylog.log', mode='a')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    fhandler.setFormatter(formatter)
    logger.addHandler(fhandler)
    logger.setLevel(logging.WARNING)
    
    
    lda = LatentDirichletAllocation(n_components=n_components, 
                                    max_iter=max_iter,
                                    topic_word_prior=topic_word_prior, # トピック数の逆数が目安の0.01,0.02,0.05,0.1などなど試す
                                    doc_topic_prior =  doc_topic_prior, 
                                    learning_method='online',
                                    learning_offset=50,
                                    batch_size= batch_size,# 多くする
                                    # learning_decay : 2??
                        
                                    mean_change_tol=1e-4,
                                    random_state=1,
                                    evaluate_every=1,
                                    verbose=1)
    print((f"Fitting LDA models with tf features, "
    f"n_samples={n_samples} and n_features={n_features}"))
    t0 = time()
    lda.fit(X)
    print(f"done in {time() - t0:0.3f}s.")
    # パラメータの比較はperplexity
    # ハイパーパラメータ調整を頑張る！（やってられない！といわない！！）
    
    
    coherance = metric_coherence_gensim(measure='c_v', 
#                         top_n=20, # これはデフォルトが20
                        topic_word_distrib=lda.components_, 
                        dtm=Xtfidf,  # tfidfの結果
                        vocab=np.array([x for x in vectorizer.vocabulary_.keys()]), 
                        texts=new_docs)
    
    
    results = {
            "perplexity" : lda.perplexity(X) ,
            "coherance": coherance,
        }

    logger.warning('MIN_DF:{0}'.format(MIN_DF) )
    logger.warning('params:batch_size:{0}'.format(batch_size)) 
    logger.warning('params:n_components:{0}'.format(n_components)) 
    logger.warning('params:topic_word_prior:{0}'.format(topic_word_prior)) 
    logger.warning('params:doc_topic_prior:{0}'.format(doc_topic_prior)) 
    logger.warning('params:max_iter:{0}'.format(max_iter)) 
    logger.warning('done n_iter:{0}'.format(lda.n_iter_)) 
    logger.warning('perplexity:{0}'.format(results["perplexity"])) 
    logger.warning('coherance:{0}'.format(results["coherance"]) )
    logger.warning('check all params:{0}'.format(lda.get_params() )) 
    make_word_cloud(n_components, lda)
    # pickle
    file_name = (datetime.datetime.now() + datetime.timedelta(hours=9) ) .strftime('%m%d_%H%M') + '_lda.pickle'
    with open(file_name, mode="wb") as f:
        pickle.dump(lda, f)
    
#     breakpoint()
    
    os.chdir("../")
    return(results)

# %%
for batch_size,n_components, topic_word_prior, doc_topic_prior in itertools.product([1500, 2500, 4000,5000 ] ,[6,7,8,9,10],
                                                                                    [0.05, 0.15, 0.3, 0.4, 0.5, 0.6, 0.8],[0.05, 0.15, 0.3, 0.4, 0.5, 0.6, 0.8] ):

    lda_main(n_components=n_components, topic_word_prior=topic_word_prior, doc_topic_prior = doc_topic_prior, batch_size=batch_size, max_iter=50)
# Out:
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1646.4481
# iteration: 2 of max_iter: 50, perplexity: 1572.3380
# iteration: 3 of max_iter: 50, perplexity: 1546.3431
# iteration: 4 of max_iter: 50, perplexity: 1533.4905
# iteration: 5 of max_iter: 50, perplexity: 1526.0198
# iteration: 6 of max_iter: 50, perplexity: 1521.8285
# iteration: 7 of max_iter: 50, perplexity: 1518.9320
# iteration: 8 of max_iter: 50, perplexity: 1517.0897
# iteration: 9 of max_iter: 50, perplexity: 1515.6519
# iteration: 10 of max_iter: 50, perplexity: 1514.5505
# iteration: 15 of max_iter: 50, perplexity: 1511.7782
# iteration: 16 of max_iter: 50, perplexity: 1511.4006
# iteration: 17 of max_iter: 50, perplexity: 1511.1495
# iteration: 18 of max_iter: 50, perplexity: 1510.9151
# iteration: 19 of max_iter: 50, perplexity: 1510.7403
# iteration: 20 of max_iter: 50, perplexity: 1510.6029
# iteration: 21 of max_iter: 50, perplexity: 1510.4800
# iteration: 22 of max_iter: 50, perplexity: 1510.3897
# done in 543.307s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1635.5337
# iteration: 2 of max_iter: 50, perplexity: 1552.3164
# iteration: 3 of max_iter: 50, perplexity: 1519.8347
# iteration: 4 of max_iter: 50, perplexity: 1503.2922
# iteration: 5 of max_iter: 50, perplexity: 1493.3575
# iteration: 6 of max_iter: 50, perplexity: 1486.9188
# iteration: 7 of max_iter: 50, perplexity: 1482.4630
# iteration: 8 of max_iter: 50, perplexity: 1479.2348
# iteration: 9 of max_iter: 50, perplexity: 1476.8144
# iteration: 10 of max_iter: 50, perplexity: 1475.0046
# iteration: 11 of max_iter: 50, perplexity: 1473.5720
# iteration: 12 of max_iter: 50, perplexity: 1472.3638
# iteration: 13 of max_iter: 50, perplexity: 1471.4023
# iteration: 14 of max_iter: 50, perplexity: 1470.5892
# iteration: 15 of max_iter: 50, perplexity: 1469.8967
# iteration: 16 of max_iter: 50, perplexity: 1469.2996
# iteration: 17 of max_iter: 50, perplexity: 1468.7750
# iteration: 18 of max_iter: 50, perplexity: 1468.2964
# iteration: 19 of max_iter: 50, perplexity: 1467.8753
# iteration: 20 of max_iter: 50, perplexity: 1467.4914
# iteration: 21 of max_iter: 50, perplexity: 1467.1641
# iteration: 22 of max_iter: 50, perplexity: 1466.8760
# iteration: 23 of max_iter: 50, perplexity: 1466.6194
# iteration: 24 of max_iter: 50, perplexity: 1466.3798
# iteration: 25 of max_iter: 50, perplexity: 1466.1680
# iteration: 26 of max_iter: 50, perplexity: 1465.9705
# iteration: 27 of max_iter: 50, perplexity: 1465.7742
# iteration: 28 of max_iter: 50, perplexity: 1465.5940
# iteration: 29 of max_iter: 50, perplexity: 1465.4411
# iteration: 30 of max_iter: 50, perplexity: 1465.2947
# iteration: 31 of max_iter: 50, perplexity: 1465.1369
# iteration: 32 of max_iter: 50, perplexity: 1465.0095
# iteration: 33 of max_iter: 50, perplexity: 1464.9036
# iteration: 34 of max_iter: 50, perplexity: 1464.7898
# iteration: 35 of max_iter: 50, perplexity: 1464.6949
# done in 893.980s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1678.7648
# iteration: 2 of max_iter: 50, perplexity: 1588.9882
# iteration: 3 of max_iter: 50, perplexity: 1551.0235
# iteration: 4 of max_iter: 50, perplexity: 1529.8880
# iteration: 5 of max_iter: 50, perplexity: 1516.3464
# iteration: 6 of max_iter: 50, perplexity: 1506.8967
# iteration: 7 of max_iter: 50, perplexity: 1500.0628
# iteration: 8 of max_iter: 50, perplexity: 1494.9603
# iteration: 9 of max_iter: 50, perplexity: 1490.9753
# iteration: 10 of max_iter: 50, perplexity: 1487.7005
# iteration: 11 of max_iter: 50, perplexity: 1485.0052
# iteration: 12 of max_iter: 50, perplexity: 1482.7688
# iteration: 13 of max_iter: 50, perplexity: 1480.8846
# iteration: 14 of max_iter: 50, perplexity: 1479.2638
# iteration: 15 of max_iter: 50, perplexity: 1477.8522
# iteration: 16 of max_iter: 50, perplexity: 1476.6087
# iteration: 17 of max_iter: 50, perplexity: 1475.5101
# iteration: 18 of max_iter: 50, perplexity: 1474.5253
# iteration: 19 of max_iter: 50, perplexity: 1473.6302
# iteration: 20 of max_iter: 50, perplexity: 1472.8132
# iteration: 21 of max_iter: 50, perplexity: 1472.0510
# iteration: 27 of max_iter: 50, perplexity: 1468.2562
# iteration: 28 of max_iter: 50, perplexity: 1467.7379
# iteration: 29 of max_iter: 50, perplexity: 1467.2510
# iteration: 30 of max_iter: 50, perplexity: 1466.7977
# iteration: 31 of max_iter: 50, perplexity: 1466.3754
# iteration: 32 of max_iter: 50, perplexity: 1465.9813
# iteration: 33 of max_iter: 50, perplexity: 1465.6130
# iteration: 34 of max_iter: 50, perplexity: 1465.2700
# iteration: 35 of max_iter: 50, perplexity: 1464.9479
# iteration: 36 of max_iter: 50, perplexity: 1464.6465
# iteration: 37 of max_iter: 50, perplexity: 1464.3644
# iteration: 38 of max_iter: 50, perplexity: 1464.1006
# iteration: 39 of max_iter: 50, perplexity: 1463.8504
# iteration: 40 of max_iter: 50, perplexity: 1463.6163
# iteration: 41 of max_iter: 50, perplexity: 1463.3966
# iteration: 42 of max_iter: 50, perplexity: 1463.1902
# iteration: 43 of max_iter: 50, perplexity: 1462.9973
# iteration: 44 of max_iter: 50, perplexity: 1462.8141
# iteration: 45 of max_iter: 50, perplexity: 1462.6404
# iteration: 46 of max_iter: 50, perplexity: 1462.4757
# iteration: 47 of max_iter: 50, perplexity: 1462.3208
# iteration: 48 of max_iter: 50, perplexity: 1462.1744
# iteration: 49 of max_iter: 50, perplexity: 1462.0357
# iteration: 50 of max_iter: 50, perplexity: 1461.9034
# done in 1325.481s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1683.8401
# iteration: 2 of max_iter: 50, perplexity: 1585.9036
# iteration: 3 of max_iter: 50, perplexity: 1544.0524
# iteration: 4 of max_iter: 50, perplexity: 1521.2033
# iteration: 5 of max_iter: 50, perplexity: 1506.8357
# iteration: 6 of max_iter: 50, perplexity: 1496.9870
# iteration: 7 of max_iter: 50, perplexity: 1489.8890
# iteration: 8 of max_iter: 50, perplexity: 1484.5406
# iteration: 9 of max_iter: 50, perplexity: 1480.3990
# iteration: 10 of max_iter: 50, perplexity: 1477.0933
# iteration: 11 of max_iter: 50, perplexity: 1474.4080
# iteration: 12 of max_iter: 50, perplexity: 1472.1767
# iteration: 13 of max_iter: 50, perplexity: 1470.2983
# iteration: 14 of max_iter: 50, perplexity: 1468.6909
# iteration: 15 of max_iter: 50, perplexity: 1467.2957
# iteration: 16 of max_iter: 50, perplexity: 1466.0739
# iteration: 17 of max_iter: 50, perplexity: 1464.9915
# iteration: 18 of max_iter: 50, perplexity: 1464.0219
# iteration: 19 of max_iter: 50, perplexity: 1463.1447
# iteration: 20 of max_iter: 50, perplexity: 1462.3461
# iteration: 21 of max_iter: 50, perplexity: 1461.6163
# iteration: 22 of max_iter: 50, perplexity: 1460.9468
# iteration: 23 of max_iter: 50, perplexity: 1460.3305
# iteration: 24 of max_iter: 50, perplexity: 1459.7602
# iteration: 25 of max_iter: 50, perplexity: 1459.2304
# iteration: 26 of max_iter: 50, perplexity: 1458.7365
# iteration: 27 of max_iter: 50, perplexity: 1458.2737
# iteration: 28 of max_iter: 50, perplexity: 1457.8395
# iteration: 29 of max_iter: 50, perplexity: 1457.4313
# iteration: 30 of max_iter: 50, perplexity: 1457.0480
# iteration: 31 of max_iter: 50, perplexity: 1456.6883
# iteration: 32 of max_iter: 50, perplexity: 1456.3503
# iteration: 33 of max_iter: 50, perplexity: 1456.0323
# iteration: 34 of max_iter: 50, perplexity: 1455.7336
# iteration: 35 of max_iter: 50, perplexity: 1455.4530
# iteration: 36 of max_iter: 50, perplexity: 1455.1891
# iteration: 37 of max_iter: 50, perplexity: 1454.9410
# iteration: 38 of max_iter: 50, perplexity: 1454.7072
# iteration: 39 of max_iter: 50, perplexity: 1454.4860
# iteration: 40 of max_iter: 50, perplexity: 1454.2761
# iteration: 41 of max_iter: 50, perplexity: 1454.0757
# iteration: 42 of max_iter: 50, perplexity: 1453.8828
# iteration: 43 of max_iter: 50, perplexity: 1453.6978
# iteration: 44 of max_iter: 50, perplexity: 1453.5200
# iteration: 50 of max_iter: 50, perplexity: 1452.5929
# done in 1185.555s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1667.2536
# iteration: 2 of max_iter: 50, perplexity: 1567.7948
# iteration: 3 of max_iter: 50, perplexity: 1521.4828
# iteration: 4 of max_iter: 50, perplexity: 1495.4261
# iteration: 5 of max_iter: 50, perplexity: 1478.7506
# iteration: 6 of max_iter: 50, perplexity: 1467.1818
# iteration: 7 of max_iter: 50, perplexity: 1458.7508
# iteration: 8 of max_iter: 50, perplexity: 1452.4079
# iteration: 9 of max_iter: 50, perplexity: 1447.4833
# iteration: 10 of max_iter: 50, perplexity: 1443.5597
# iteration: 11 of max_iter: 50, perplexity: 1440.3666
# iteration: 12 of max_iter: 50, perplexity: 1437.7084
# iteration: 13 of max_iter: 50, perplexity: 1435.4660
# iteration: 14 of max_iter: 50, perplexity: 1433.5452
# iteration: 15 of max_iter: 50, perplexity: 1431.9043
# iteration: 16 of max_iter: 50, perplexity: 1430.4874
# iteration: 17 of max_iter: 50, perplexity: 1429.2475
# iteration: 18 of max_iter: 50, perplexity: 1428.1510
# iteration: 19 of max_iter: 50, perplexity: 1427.1729
# iteration: 20 of max_iter: 50, perplexity: 1426.2944
# iteration: 21 of max_iter: 50, perplexity: 1425.5011
# iteration: 22 of max_iter: 50, perplexity: 1424.7818
# iteration: 23 of max_iter: 50, perplexity: 1424.1267
# iteration: 24 of max_iter: 50, perplexity: 1423.5275
# iteration: 25 of max_iter: 50, perplexity: 1422.9771
# iteration: 26 of max_iter: 50, perplexity: 1422.4693
# iteration: 27 of max_iter: 50, perplexity: 1422.0001
# iteration: 28 of max_iter: 50, perplexity: 1421.5658
# iteration: 29 of max_iter: 50, perplexity: 1421.1628
# iteration: 30 of max_iter: 50, perplexity: 1420.7878
# iteration: 31 of max_iter: 50, perplexity: 1420.4378
# iteration: 32 of max_iter: 50, perplexity: 1420.1104
# iteration: 33 of max_iter: 50, perplexity: 1419.8035
# iteration: 34 of max_iter: 50, perplexity: 1419.5149
# iteration: 35 of max_iter: 50, perplexity: 1419.2428
# iteration: 36 of max_iter: 50, perplexity: 1418.9854
# iteration: 37 of max_iter: 50, perplexity: 1418.7411
# iteration: 38 of max_iter: 50, perplexity: 1418.5087
# iteration: 39 of max_iter: 50, perplexity: 1418.2872
# iteration: 40 of max_iter: 50, perplexity: 1418.0759
# iteration: 41 of max_iter: 50, perplexity: 1417.8742
# iteration: 42 of max_iter: 50, perplexity: 1417.6815
# iteration: 43 of max_iter: 50, perplexity: 1417.4972
# iteration: 44 of max_iter: 50, perplexity: 1417.3205
# iteration: 45 of max_iter: 50, perplexity: 1417.1510
# iteration: 46 of max_iter: 50, perplexity: 1416.9883
# iteration: 47 of max_iter: 50, perplexity: 1416.8321
# iteration: 48 of max_iter: 50, perplexity: 1416.6821
# iteration: 49 of max_iter: 50, perplexity: 1416.5380
# iteration: 50 of max_iter: 50, perplexity: 1416.3994
# done in 1059.356s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1653.3356
# iteration: 2 of max_iter: 50, perplexity: 1550.4862
# iteration: 3 of max_iter: 50, perplexity: 1504.0549
# iteration: 4 of max_iter: 50, perplexity: 1478.6854
# iteration: 5 of max_iter: 50, perplexity: 1462.9858
# iteration: 6 of max_iter: 50, perplexity: 1452.3662
# iteration: 7 of max_iter: 50, perplexity: 1444.7397
# iteration: 8 of max_iter: 50, perplexity: 1439.0117
# iteration: 9 of max_iter: 50, perplexity: 1434.5632
# iteration: 10 of max_iter: 50, perplexity: 1431.0179
# iteration: 11 of max_iter: 50, perplexity: 1428.1333
# iteration: 12 of max_iter: 50, perplexity: 1425.7425
# iteration: 13 of max_iter: 50, perplexity: 1423.7297
# iteration: 14 of max_iter: 50, perplexity: 1422.0107
# iteration: 15 of max_iter: 50, perplexity: 1420.5213
# iteration: 16 of max_iter: 50, perplexity: 1419.2159
# iteration: 17 of max_iter: 50, perplexity: 1418.0617
# iteration: 18 of max_iter: 50, perplexity: 1417.0336
# iteration: 19 of max_iter: 50, perplexity: 1416.1116
# iteration: 20 of max_iter: 50, perplexity: 1415.2813
# iteration: 21 of max_iter: 50, perplexity: 1414.5313
# iteration: 22 of max_iter: 50, perplexity: 1413.8507
# iteration: 23 of max_iter: 50, perplexity: 1413.2303
# iteration: 24 of max_iter: 50, perplexity: 1412.6626
# iteration: 25 of max_iter: 50, perplexity: 1412.1411
# iteration: 26 of max_iter: 50, perplexity: 1411.6604
# iteration: 32 of max_iter: 50, perplexity: 1409.4228
# iteration: 33 of max_iter: 50, perplexity: 1409.1302
# iteration: 34 of max_iter: 50, perplexity: 1408.8545
# iteration: 35 of max_iter: 50, perplexity: 1408.5938
# iteration: 36 of max_iter: 50, perplexity: 1408.3467
# iteration: 37 of max_iter: 50, perplexity: 1408.1120
# iteration: 38 of max_iter: 50, perplexity: 1407.8888
# iteration: 39 of max_iter: 50, perplexity: 1407.6762
# iteration: 40 of max_iter: 50, perplexity: 1407.4735
# iteration: 41 of max_iter: 50, perplexity: 1407.2803
# iteration: 42 of max_iter: 50, perplexity: 1407.0959
# iteration: 43 of max_iter: 50, perplexity: 1406.9199
# iteration: 44 of max_iter: 50, perplexity: 1406.7517
# iteration: 45 of max_iter: 50, perplexity: 1406.5910
# iteration: 46 of max_iter: 50, perplexity: 1406.4371
# iteration: 47 of max_iter: 50, perplexity: 1406.2897
# iteration: 48 of max_iter: 50, perplexity: 1406.1481
# iteration: 49 of max_iter: 50, perplexity: 1406.0121
# iteration: 50 of max_iter: 50, perplexity: 1405.8812
# done in 999.331s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1682.8522
# iteration: 2 of max_iter: 50, perplexity: 1567.5911
# iteration: 3 of max_iter: 50, perplexity: 1516.1171
# iteration: 4 of max_iter: 50, perplexity: 1487.7689
# iteration: 5 of max_iter: 50, perplexity: 1470.2383
# iteration: 6 of max_iter: 50, perplexity: 1458.5025
# iteration: 7 of max_iter: 50, perplexity: 1450.1383
# iteration: 8 of max_iter: 50, perplexity: 1443.8681
# iteration: 9 of max_iter: 50, perplexity: 1438.9944
# iteration: 10 of max_iter: 50, perplexity: 1435.1069
# iteration: 11 of max_iter: 50, perplexity: 1431.9408
# iteration: 12 of max_iter: 50, perplexity: 1429.3136
# iteration: 13 of max_iter: 50, perplexity: 1427.1003
# iteration: 14 of max_iter: 50, perplexity: 1425.2100
# iteration: 15 of max_iter: 50, perplexity: 1423.5735
# iteration: 16 of max_iter: 50, perplexity: 1422.1396
# iteration: 17 of max_iter: 50, perplexity: 1420.8705
# iteration: 18 of max_iter: 50, perplexity: 1419.7382
# iteration: 19 of max_iter: 50, perplexity: 1418.7215
# iteration: 20 of max_iter: 50, perplexity: 1417.8038
# iteration: 21 of max_iter: 50, perplexity: 1416.9712
# iteration: 22 of max_iter: 50, perplexity: 1416.2120
# iteration: 23 of max_iter: 50, perplexity: 1415.5163
# iteration: 24 of max_iter: 50, perplexity: 1414.8760
# iteration: 25 of max_iter: 50, perplexity: 1414.2845
# iteration: 26 of max_iter: 50, perplexity: 1413.7368
# iteration: 27 of max_iter: 50, perplexity: 1413.2284
# iteration: 28 of max_iter: 50, perplexity: 1412.7554
# iteration: 29 of max_iter: 50, perplexity: 1412.3146
# iteration: 30 of max_iter: 50, perplexity: 1411.9030
# iteration: 31 of max_iter: 50, perplexity: 1411.5182
# iteration: 32 of max_iter: 50, perplexity: 1411.1576
# iteration: 33 of max_iter: 50, perplexity: 1410.8191
# iteration: 34 of max_iter: 50, perplexity: 1410.5007
# iteration: 35 of max_iter: 50, perplexity: 1410.2008
# iteration: 36 of max_iter: 50, perplexity: 1409.9178
# iteration: 37 of max_iter: 50, perplexity: 1409.6503
# iteration: 38 of max_iter: 50, perplexity: 1409.3970
# iteration: 39 of max_iter: 50, perplexity: 1409.1566
# iteration: 40 of max_iter: 50, perplexity: 1408.9280
# iteration: 41 of max_iter: 50, perplexity: 1408.7102
# iteration: 42 of max_iter: 50, perplexity: 1408.5026
# iteration: 43 of max_iter: 50, perplexity: 1408.3044
# iteration: 44 of max_iter: 50, perplexity: 1408.1152
# iteration: 45 of max_iter: 50, perplexity: 1407.9343
# iteration: 46 of max_iter: 50, perplexity: 1407.7615
# iteration: 47 of max_iter: 50, perplexity: 1407.5963
# iteration: 48 of max_iter: 50, perplexity: 1407.4382
# iteration: 49 of max_iter: 50, perplexity: 1407.2869
# iteration: 50 of max_iter: 50, perplexity: 1407.1419
# done in 934.782s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1605.5825
# iteration: 2 of max_iter: 50, perplexity: 1539.8634
# iteration: 3 of max_iter: 50, perplexity: 1514.2077
# iteration: 4 of max_iter: 50, perplexity: 1500.2846
# iteration: 5 of max_iter: 50, perplexity: 1492.7560
# iteration: 6 of max_iter: 50, perplexity: 1488.3902
# iteration: 7 of max_iter: 50, perplexity: 1485.3260
# iteration: 8 of max_iter: 50, perplexity: 1483.2994
# iteration: 9 of max_iter: 50, perplexity: 1481.7182
# iteration: 10 of max_iter: 50, perplexity: 1480.6382
# iteration: 11 of max_iter: 50, perplexity: 1479.9714
# iteration: 12 of max_iter: 50, perplexity: 1479.3370
# iteration: 13 of max_iter: 50, perplexity: 1478.9155
# iteration: 14 of max_iter: 50, perplexity: 1478.7006
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1602.2171
# iteration: 2 of max_iter: 50, perplexity: 1529.5834
# iteration: 3 of max_iter: 50, perplexity: 1499.9005
# iteration: 4 of max_iter: 50, perplexity: 1483.8807
# iteration: 5 of max_iter: 50, perplexity: 1474.6127
# iteration: 6 of max_iter: 50, perplexity: 1468.6322
# iteration: 7 of max_iter: 50, perplexity: 1464.4918
# iteration: 8 of max_iter: 50, perplexity: 1461.5046
# iteration: 9 of max_iter: 50, perplexity: 1459.3353
# iteration: 10 of max_iter: 50, perplexity: 1457.6720
# iteration: 11 of max_iter: 50, perplexity: 1456.3882
# iteration: 12 of max_iter: 50, perplexity: 1455.3643
# iteration: 13 of max_iter: 50, perplexity: 1454.5423
# iteration: 14 of max_iter: 50, perplexity: 1453.8713
# iteration: 15 of max_iter: 50, perplexity: 1453.3186
# iteration: 16 of max_iter: 50, perplexity: 1452.8493
# iteration: 17 of max_iter: 50, perplexity: 1452.4276
# iteration: 18 of max_iter: 50, perplexity: 1452.0604
# iteration: 19 of max_iter: 50, perplexity: 1451.7214
# iteration: 20 of max_iter: 50, perplexity: 1451.4382
# iteration: 21 of max_iter: 50, perplexity: 1451.2139
# iteration: 22 of max_iter: 50, perplexity: 1450.9977
# iteration: 23 of max_iter: 50, perplexity: 1450.8113
# iteration: 24 of max_iter: 50, perplexity: 1450.6306
# iteration: 25 of max_iter: 50, perplexity: 1450.4700
# iteration: 26 of max_iter: 50, perplexity: 1450.3217
# iteration: 27 of max_iter: 50, perplexity: 1450.2090
# iteration: 28 of max_iter: 50, perplexity: 1450.0804
# iteration: 29 of max_iter: 50, perplexity: 1449.9697
# iteration: 30 of max_iter: 50, perplexity: 1449.8645
# iteration: 31 of max_iter: 50, perplexity: 1449.7699
# done in 774.309s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1650.0549
# iteration: 2 of max_iter: 50, perplexity: 1573.0515
# iteration: 3 of max_iter: 50, perplexity: 1539.5811
# iteration: 4 of max_iter: 50, perplexity: 1520.2694
# iteration: 5 of max_iter: 50, perplexity: 1507.6048
# iteration: 6 of max_iter: 50, perplexity: 1498.8098
# iteration: 7 of max_iter: 50, perplexity: 1492.2767
# iteration: 8 of max_iter: 50, perplexity: 1487.3578
# iteration: 9 of max_iter: 50, perplexity: 1483.5770
# iteration: 10 of max_iter: 50, perplexity: 1480.5658
# iteration: 11 of max_iter: 50, perplexity: 1478.1069
# iteration: 12 of max_iter: 50, perplexity: 1476.0703
# iteration: 13 of max_iter: 50, perplexity: 1474.3358
# iteration: 14 of max_iter: 50, perplexity: 1472.8295
# iteration: 15 of max_iter: 50, perplexity: 1471.4877
# iteration: 16 of max_iter: 50, perplexity: 1470.2727
# iteration: 17 of max_iter: 50, perplexity: 1469.1696
# iteration: 18 of max_iter: 50, perplexity: 1468.1695
# iteration: 19 of max_iter: 50, perplexity: 1467.2627
# iteration: 20 of max_iter: 50, perplexity: 1466.4345
# iteration: 21 of max_iter: 50, perplexity: 1465.6741
# iteration: 22 of max_iter: 50, perplexity: 1464.9781
# iteration: 23 of max_iter: 50, perplexity: 1464.3369
# iteration: 24 of max_iter: 50, perplexity: 1463.7478
# iteration: 25 of max_iter: 50, perplexity: 1463.2106
# iteration: 29 of max_iter: 50, perplexity: 1461.4701
# iteration: 30 of max_iter: 50, perplexity: 1461.1185
# iteration: 31 of max_iter: 50, perplexity: 1460.7940
# iteration: 32 of max_iter: 50, perplexity: 1460.4966
# iteration: 33 of max_iter: 50, perplexity: 1460.2203
# iteration: 34 of max_iter: 50, perplexity: 1459.9646
# iteration: 35 of max_iter: 50, perplexity: 1459.7238
# iteration: 36 of max_iter: 50, perplexity: 1459.5008
# iteration: 37 of max_iter: 50, perplexity: 1459.2898
# iteration: 38 of max_iter: 50, perplexity: 1459.0907
# iteration: 39 of max_iter: 50, perplexity: 1458.9026
# iteration: 40 of max_iter: 50, perplexity: 1458.7248
# iteration: 41 of max_iter: 50, perplexity: 1458.5557
# iteration: 42 of max_iter: 50, perplexity: 1458.3960
# iteration: 43 of max_iter: 50, perplexity: 1458.2436
# iteration: 44 of max_iter: 50, perplexity: 1458.0993
# iteration: 45 of max_iter: 50, perplexity: 1457.9609
# iteration: 46 of max_iter: 50, perplexity: 1457.8290
# iteration: 47 of max_iter: 50, perplexity: 1457.7033
# iteration: 48 of max_iter: 50, perplexity: 1457.5829
# iteration: 49 of max_iter: 50, perplexity: 1457.4677
# iteration: 50 of max_iter: 50, perplexity: 1457.3570
# done in 1667.153s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1653.3669
# iteration: 2 of max_iter: 50, perplexity: 1569.9235
# iteration: 3 of max_iter: 50, perplexity: 1534.2796
# iteration: 4 of max_iter: 50, perplexity: 1514.4845
# iteration: 5 of max_iter: 50, perplexity: 1502.0403
# iteration: 6 of max_iter: 50, perplexity: 1493.6092
# iteration: 7 of max_iter: 50, perplexity: 1487.5498
# iteration: 8 of max_iter: 50, perplexity: 1482.9921
# iteration: 9 of max_iter: 50, perplexity: 1479.4393
# iteration: 10 of max_iter: 50, perplexity: 1476.6019
# iteration: 11 of max_iter: 50, perplexity: 1474.2817
# iteration: 12 of max_iter: 50, perplexity: 1472.3425
# iteration: 13 of max_iter: 50, perplexity: 1470.6941
# iteration: 14 of max_iter: 50, perplexity: 1469.2758
# iteration: 15 of max_iter: 50, perplexity: 1468.0450
# iteration: 16 of max_iter: 50, perplexity: 1466.9695
# iteration: 17 of max_iter: 50, perplexity: 1466.0172
# iteration: 18 of max_iter: 50, perplexity: 1465.1669
# iteration: 19 of max_iter: 50, perplexity: 1464.4012
# iteration: 20 of max_iter: 50, perplexity: 1463.7075
# iteration: 21 of max_iter: 50, perplexity: 1463.0754
# iteration: 22 of max_iter: 50, perplexity: 1462.4956
# iteration: 23 of max_iter: 50, perplexity: 1461.9624
# iteration: 24 of max_iter: 50, perplexity: 1461.4708
# iteration: 25 of max_iter: 50, perplexity: 1461.0179
# iteration: 26 of max_iter: 50, perplexity: 1460.5993
# iteration: 27 of max_iter: 50, perplexity: 1460.2124
# iteration: 28 of max_iter: 50, perplexity: 1459.8538
# iteration: 29 of max_iter: 50, perplexity: 1459.5194
# iteration: 30 of max_iter: 50, perplexity: 1459.2056
# iteration: 31 of max_iter: 50, perplexity: 1458.9085
# iteration: 32 of max_iter: 50, perplexity: 1458.6276
# iteration: 33 of max_iter: 50, perplexity: 1458.3627
# iteration: 34 of max_iter: 50, perplexity: 1458.1117
# iteration: 35 of max_iter: 50, perplexity: 1457.8690
# iteration: 40 of max_iter: 50, perplexity: 1456.8403
# iteration: 41 of max_iter: 50, perplexity: 1456.6675
# iteration: 42 of max_iter: 50, perplexity: 1456.5036
# iteration: 43 of max_iter: 50, perplexity: 1456.3476
# iteration: 44 of max_iter: 50, perplexity: 1456.1978
# iteration: 45 of max_iter: 50, perplexity: 1456.0543
# iteration: 46 of max_iter: 50, perplexity: 1455.9178
# iteration: 47 of max_iter: 50, perplexity: 1455.7880
# iteration: 48 of max_iter: 50, perplexity: 1455.6643
# iteration: 49 of max_iter: 50, perplexity: 1455.5465
# iteration: 50 of max_iter: 50, perplexity: 1455.4345
# done in 1443.077s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1635.6542
# iteration: 2 of max_iter: 50, perplexity: 1551.7255
# iteration: 3 of max_iter: 50, perplexity: 1512.8115
# iteration: 4 of max_iter: 50, perplexity: 1490.4910
# iteration: 5 of max_iter: 50, perplexity: 1476.0078
# iteration: 6 of max_iter: 50, perplexity: 1465.8912
# iteration: 7 of max_iter: 50, perplexity: 1458.5423
# iteration: 8 of max_iter: 50, perplexity: 1453.0076
# iteration: 9 of max_iter: 50, perplexity: 1448.7146
# iteration: 10 of max_iter: 50, perplexity: 1445.2894
# iteration: 11 of max_iter: 50, perplexity: 1442.5012
# iteration: 12 of max_iter: 50, perplexity: 1440.1981
# iteration: 13 of max_iter: 50, perplexity: 1438.2921
# iteration: 14 of max_iter: 50, perplexity: 1436.6927
# iteration: 15 of max_iter: 50, perplexity: 1435.3284
# iteration: 16 of max_iter: 50, perplexity: 1434.1492
# iteration: 17 of max_iter: 50, perplexity: 1433.1170
# iteration: 18 of max_iter: 50, perplexity: 1432.2033
# iteration: 19 of max_iter: 50, perplexity: 1431.3871
# iteration: 20 of max_iter: 50, perplexity: 1430.6514
# iteration: 21 of max_iter: 50, perplexity: 1429.9842
# iteration: 22 of max_iter: 50, perplexity: 1429.3765
# iteration: 23 of max_iter: 50, perplexity: 1428.8204
# iteration: 24 of max_iter: 50, perplexity: 1428.3092
# iteration: 25 of max_iter: 50, perplexity: 1427.8374
# iteration: 26 of max_iter: 50, perplexity: 1427.4026
# iteration: 27 of max_iter: 50, perplexity: 1427.0015
# iteration: 28 of max_iter: 50, perplexity: 1426.6313
# iteration: 29 of max_iter: 50, perplexity: 1426.2890
# iteration: 30 of max_iter: 50, perplexity: 1425.9714
# iteration: 31 of max_iter: 50, perplexity: 1425.6759
# iteration: 32 of max_iter: 50, perplexity: 1425.3998
# iteration: 33 of max_iter: 50, perplexity: 1425.1409
# iteration: 34 of max_iter: 50, perplexity: 1424.8974
# iteration: 35 of max_iter: 50, perplexity: 1424.6676
# iteration: 36 of max_iter: 50, perplexity: 1424.4502
# iteration: 37 of max_iter: 50, perplexity: 1424.2443
# iteration: 38 of max_iter: 50, perplexity: 1424.0492
# iteration: 39 of max_iter: 50, perplexity: 1423.8640
# iteration: 40 of max_iter: 50, perplexity: 1423.6882
# iteration: 41 of max_iter: 50, perplexity: 1423.5212
# iteration: 42 of max_iter: 50, perplexity: 1423.3624
# iteration: 43 of max_iter: 50, perplexity: 1423.2111
# iteration: 44 of max_iter: 50, perplexity: 1423.0668
# iteration: 45 of max_iter: 50, perplexity: 1422.9289
# iteration: 46 of max_iter: 50, perplexity: 1422.7968
# iteration: 47 of max_iter: 50, perplexity: 1422.6703
# iteration: 48 of max_iter: 50, perplexity: 1422.5490
# iteration: 49 of max_iter: 50, perplexity: 1422.4327
# iteration: 50 of max_iter: 50, perplexity: 1422.3212
# done in 1125.519s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1619.5842
# iteration: 2 of max_iter: 50, perplexity: 1531.5625
# iteration: 3 of max_iter: 50, perplexity: 1493.4236
# iteration: 4 of max_iter: 50, perplexity: 1472.7505
# iteration: 5 of max_iter: 50, perplexity: 1459.8978
# iteration: 6 of max_iter: 50, perplexity: 1451.2066
# iteration: 7 of max_iter: 50, perplexity: 1444.9917
# iteration: 8 of max_iter: 50, perplexity: 1440.3354
# iteration: 9 of max_iter: 50, perplexity: 1436.7191
# iteration: 10 of max_iter: 50, perplexity: 1433.8390
# iteration: 11 of max_iter: 50, perplexity: 1431.4984
# iteration: 12 of max_iter: 50, perplexity: 1429.5596
# iteration: 13 of max_iter: 50, perplexity: 1427.9299
# iteration: 14 of max_iter: 50, perplexity: 1426.5410
# iteration: 20 of max_iter: 50, perplexity: 1421.1367
# iteration: 21 of max_iter: 50, perplexity: 1420.5287
# iteration: 22 of max_iter: 50, perplexity: 1419.9714
# iteration: 23 of max_iter: 50, perplexity: 1419.4591
# iteration: 24 of max_iter: 50, perplexity: 1418.9876
# iteration: 25 of max_iter: 50, perplexity: 1418.5532
# iteration: 26 of max_iter: 50, perplexity: 1418.1526
# iteration: 27 of max_iter: 50, perplexity: 1417.7822
# iteration: 28 of max_iter: 50, perplexity: 1417.4388
# iteration: 29 of max_iter: 50, perplexity: 1417.1185
# iteration: 30 of max_iter: 50, perplexity: 1416.8184
# iteration: 31 of max_iter: 50, perplexity: 1416.5364
# iteration: 32 of max_iter: 50, perplexity: 1416.2707
# iteration: 33 of max_iter: 50, perplexity: 1416.0197
# iteration: 34 of max_iter: 50, perplexity: 1415.7821
# iteration: 35 of max_iter: 50, perplexity: 1415.5569
# iteration: 36 of max_iter: 50, perplexity: 1415.3427
# iteration: 37 of max_iter: 50, perplexity: 1415.1386
# iteration: 38 of max_iter: 50, perplexity: 1414.9435
# iteration: 39 of max_iter: 50, perplexity: 1414.7567
# iteration: 40 of max_iter: 50, perplexity: 1414.5776
# iteration: 41 of max_iter: 50, perplexity: 1414.4060
# iteration: 42 of max_iter: 50, perplexity: 1414.2420
# iteration: 43 of max_iter: 50, perplexity: 1414.0856
# iteration: 44 of max_iter: 50, perplexity: 1413.9364
# iteration: 45 of max_iter: 50, perplexity: 1413.7943
# iteration: 46 of max_iter: 50, perplexity: 1413.6592
# iteration: 47 of max_iter: 50, perplexity: 1413.5306
# iteration: 48 of max_iter: 50, perplexity: 1413.4083
# iteration: 49 of max_iter: 50, perplexity: 1413.2918
# iteration: 50 of max_iter: 50, perplexity: 1413.1807
# done in 1010.891s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1644.4638
# iteration: 2 of max_iter: 50, perplexity: 1543.7586
# iteration: 3 of max_iter: 50, perplexity: 1501.9523
# iteration: 4 of max_iter: 50, perplexity: 1479.5574
# iteration: 5 of max_iter: 50, perplexity: 1465.8832
# iteration: 6 of max_iter: 50, perplexity: 1456.7408
# iteration: 7 of max_iter: 50, perplexity: 1450.2066
# iteration: 8 of max_iter: 50, perplexity: 1445.3010
# iteration: 9 of max_iter: 50, perplexity: 1441.4905
# iteration: 10 of max_iter: 50, perplexity: 1438.4536
# iteration: 11 of max_iter: 50, perplexity: 1435.9810
# iteration: 12 of max_iter: 50, perplexity: 1433.9307
# iteration: 13 of max_iter: 50, perplexity: 1432.2028
# iteration: 14 of max_iter: 50, perplexity: 1430.7253
# iteration: 15 of max_iter: 50, perplexity: 1429.4462
# iteration: 16 of max_iter: 50, perplexity: 1428.3271
# iteration: 17 of max_iter: 50, perplexity: 1427.3390
# iteration: 18 of max_iter: 50, perplexity: 1426.4594
# iteration: 19 of max_iter: 50, perplexity: 1425.6708
# iteration: 20 of max_iter: 50, perplexity: 1424.9591
# iteration: 21 of max_iter: 50, perplexity: 1424.3129
# iteration: 22 of max_iter: 50, perplexity: 1423.7230
# iteration: 23 of max_iter: 50, perplexity: 1423.1819
# iteration: 24 of max_iter: 50, perplexity: 1422.6837
# iteration: 25 of max_iter: 50, perplexity: 1422.2234
# iteration: 26 of max_iter: 50, perplexity: 1421.7971
# iteration: 27 of max_iter: 50, perplexity: 1421.4012
# iteration: 28 of max_iter: 50, perplexity: 1421.0327
# iteration: 29 of max_iter: 50, perplexity: 1420.6888
# iteration: 30 of max_iter: 50, perplexity: 1420.3673
# iteration: 31 of max_iter: 50, perplexity: 1420.0659
# iteration: 32 of max_iter: 50, perplexity: 1419.7828
# iteration: 33 of max_iter: 50, perplexity: 1419.5161
# iteration: 34 of max_iter: 50, perplexity: 1419.2644
# iteration: 35 of max_iter: 50, perplexity: 1419.0265
# iteration: 36 of max_iter: 50, perplexity: 1418.8013
# iteration: 37 of max_iter: 50, perplexity: 1418.5881
# iteration: 38 of max_iter: 50, perplexity: 1418.3858
# iteration: 39 of max_iter: 50, perplexity: 1418.1939
# iteration: 40 of max_iter: 50, perplexity: 1418.0115
# iteration: 41 of max_iter: 50, perplexity: 1417.8380
# iteration: 42 of max_iter: 50, perplexity: 1417.6728
# iteration: 43 of max_iter: 50, perplexity: 1417.5152
# iteration: 44 of max_iter: 50, perplexity: 1417.3648
# iteration: 45 of max_iter: 50, perplexity: 1417.2208
# iteration: 46 of max_iter: 50, perplexity: 1417.0830
# iteration: 47 of max_iter: 50, perplexity: 1416.9508
# iteration: 48 of max_iter: 50, perplexity: 1416.8239
# iteration: 49 of max_iter: 50, perplexity: 1416.7020
# iteration: 50 of max_iter: 50, perplexity: 1416.5848
# iteration: 3 of max_iter: 50, perplexity: 1486.7690
# iteration: 4 of max_iter: 50, perplexity: 1471.9481
# iteration: 5 of max_iter: 50, perplexity: 1463.2329
# iteration: 6 of max_iter: 50, perplexity: 1457.5498
# iteration: 7 of max_iter: 50, perplexity: 1452.8319
# iteration: 8 of max_iter: 50, perplexity: 1449.1716
# iteration: 9 of max_iter: 50, perplexity: 1446.2378
# iteration: 10 of max_iter: 50, perplexity: 1444.1018
# iteration: 11 of max_iter: 50, perplexity: 1442.4866
# iteration: 12 of max_iter: 50, perplexity: 1440.9340
# iteration: 13 of max_iter: 50, perplexity: 1439.4560
# iteration: 14 of max_iter: 50, perplexity: 1438.2883
# iteration: 15 of max_iter: 50, perplexity: 1437.4661
# iteration: 16 of max_iter: 50, perplexity: 1436.7570
# iteration: 17 of max_iter: 50, perplexity: 1436.1357
# iteration: 18 of max_iter: 50, perplexity: 1435.7070
# iteration: 19 of max_iter: 50, perplexity: 1435.1569
# iteration: 20 of max_iter: 50, perplexity: 1434.4506
# iteration: 21 of max_iter: 50, perplexity: 1433.6060
# iteration: 22 of max_iter: 50, perplexity: 1433.0068
# iteration: 23 of max_iter: 50, perplexity: 1432.5161
# iteration: 24 of max_iter: 50, perplexity: 1432.0893
# iteration: 25 of max_iter: 50, perplexity: 1431.6566
# iteration: 26 of max_iter: 50, perplexity: 1431.3213
# iteration: 27 of max_iter: 50, perplexity: 1431.0666
# iteration: 28 of max_iter: 50, perplexity: 1430.8697
# iteration: 29 of max_iter: 50, perplexity: 1430.6703
# iteration: 30 of max_iter: 50, perplexity: 1430.4503
# iteration: 31 of max_iter: 50, perplexity: 1430.2317
# iteration: 32 of max_iter: 50, perplexity: 1430.0419
# iteration: 33 of max_iter: 50, perplexity: 1429.8400
# iteration: 34 of max_iter: 50, perplexity: 1429.6003
# iteration: 35 of max_iter: 50, perplexity: 1429.4254
# iteration: 36 of max_iter: 50, perplexity: 1429.2478
# iteration: 37 of max_iter: 50, perplexity: 1429.0682
# iteration: 38 of max_iter: 50, perplexity: 1428.9367
# iteration: 39 of max_iter: 50, perplexity: 1428.8398
# done in 969.194s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1589.7248
# iteration: 2 of max_iter: 50, perplexity: 1519.6018
# iteration: 3 of max_iter: 50, perplexity: 1490.4346
# iteration: 4 of max_iter: 50, perplexity: 1474.4665
# iteration: 5 of max_iter: 50, perplexity: 1464.1777
# iteration: 6 of max_iter: 50, perplexity: 1457.2610
# iteration: 7 of max_iter: 50, perplexity: 1452.4240
# iteration: 8 of max_iter: 50, perplexity: 1448.8771
# iteration: 9 of max_iter: 50, perplexity: 1446.2402
# iteration: 10 of max_iter: 50, perplexity: 1444.1833
# iteration: 11 of max_iter: 50, perplexity: 1442.5317
# iteration: 12 of max_iter: 50, perplexity: 1441.2245
# iteration: 13 of max_iter: 50, perplexity: 1440.0867
# iteration: 14 of max_iter: 50, perplexity: 1439.0945
# iteration: 15 of max_iter: 50, perplexity: 1438.1335
# iteration: 16 of max_iter: 50, perplexity: 1437.2946
# iteration: 17 of max_iter: 50, perplexity: 1436.5053
# iteration: 18 of max_iter: 50, perplexity: 1435.8033
# iteration: 19 of max_iter: 50, perplexity: 1435.1619
# iteration: 20 of max_iter: 50, perplexity: 1434.6039
# iteration: 21 of max_iter: 50, perplexity: 1434.0995
# iteration: 22 of max_iter: 50, perplexity: 1433.6236
# iteration: 23 of max_iter: 50, perplexity: 1433.1800
# iteration: 24 of max_iter: 50, perplexity: 1432.7941
# iteration: 25 of max_iter: 50, perplexity: 1432.4140
# iteration: 26 of max_iter: 50, perplexity: 1432.0410
# iteration: 27 of max_iter: 50, perplexity: 1431.6650
# iteration: 28 of max_iter: 50, perplexity: 1431.2769
# iteration: 29 of max_iter: 50, perplexity: 1430.9327
# iteration: 33 of max_iter: 50, perplexity: 1429.8123
# iteration: 34 of max_iter: 50, perplexity: 1429.5544
# iteration: 35 of max_iter: 50, perplexity: 1429.3151
# iteration: 36 of max_iter: 50, perplexity: 1429.0877
# iteration: 37 of max_iter: 50, perplexity: 1428.8690
# iteration: 38 of max_iter: 50, perplexity: 1428.6713
# iteration: 39 of max_iter: 50, perplexity: 1428.4821
# iteration: 40 of max_iter: 50, perplexity: 1428.2929
# iteration: 41 of max_iter: 50, perplexity: 1428.1211
# iteration: 42 of max_iter: 50, perplexity: 1427.9286
# iteration: 43 of max_iter: 50, perplexity: 1427.7506
# iteration: 44 of max_iter: 50, perplexity: 1427.5936
# iteration: 45 of max_iter: 50, perplexity: 1427.4295
# iteration: 46 of max_iter: 50, perplexity: 1427.2491
# iteration: 47 of max_iter: 50, perplexity: 1427.0860
# iteration: 48 of max_iter: 50, perplexity: 1426.9304
# iteration: 49 of max_iter: 50, perplexity: 1426.7954
# iteration: 50 of max_iter: 50, perplexity: 1426.6569
# done in 1436.656s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1644.1624
# iteration: 2 of max_iter: 50, perplexity: 1572.1920
# iteration: 3 of max_iter: 50, perplexity: 1539.6241
# iteration: 4 of max_iter: 50, perplexity: 1520.1516
# iteration: 5 of max_iter: 50, perplexity: 1507.3112
# iteration: 6 of max_iter: 50, perplexity: 1498.4016
# iteration: 7 of max_iter: 50, perplexity: 1491.9016
# iteration: 8 of max_iter: 50, perplexity: 1486.8876
# iteration: 9 of max_iter: 50, perplexity: 1482.8312
# iteration: 10 of max_iter: 50, perplexity: 1479.5059
# iteration: 11 of max_iter: 50, perplexity: 1476.6769
# iteration: 12 of max_iter: 50, perplexity: 1474.1934
# iteration: 13 of max_iter: 50, perplexity: 1471.9232
# iteration: 14 of max_iter: 50, perplexity: 1469.8134
# iteration: 15 of max_iter: 50, perplexity: 1467.8797
# iteration: 16 of max_iter: 50, perplexity: 1466.1167
# iteration: 17 of max_iter: 50, perplexity: 1464.5162
# iteration: 18 of max_iter: 50, perplexity: 1463.0543
# iteration: 19 of max_iter: 50, perplexity: 1461.7179
# iteration: 20 of max_iter: 50, perplexity: 1460.4790
# iteration: 21 of max_iter: 50, perplexity: 1459.3059
# iteration: 22 of max_iter: 50, perplexity: 1458.2045
# iteration: 23 of max_iter: 50, perplexity: 1457.2012
# iteration: 24 of max_iter: 50, perplexity: 1456.2829
# iteration: 25 of max_iter: 50, perplexity: 1455.4268
# iteration: 26 of max_iter: 50, perplexity: 1454.5972
# iteration: 27 of max_iter: 50, perplexity: 1453.7688
# iteration: 28 of max_iter: 50, perplexity: 1452.9196
# iteration: 29 of max_iter: 50, perplexity: 1452.0687
# iteration: 30 of max_iter: 50, perplexity: 1451.2838
# iteration: 31 of max_iter: 50, perplexity: 1450.5682
# iteration: 32 of max_iter: 50, perplexity: 1449.9142
# iteration: 33 of max_iter: 50, perplexity: 1449.3084
# iteration: 34 of max_iter: 50, perplexity: 1448.7508
# iteration: 35 of max_iter: 50, perplexity: 1448.2403
# iteration: 40 of max_iter: 50, perplexity: 1446.1011
# iteration: 41 of max_iter: 50, perplexity: 1445.7465
# iteration: 42 of max_iter: 50, perplexity: 1445.4106
# iteration: 43 of max_iter: 50, perplexity: 1445.0924
# iteration: 44 of max_iter: 50, perplexity: 1444.7900
# iteration: 45 of max_iter: 50, perplexity: 1444.5079
# iteration: 46 of max_iter: 50, perplexity: 1444.2419
# iteration: 47 of max_iter: 50, perplexity: 1443.9898
# iteration: 48 of max_iter: 50, perplexity: 1443.7490
# iteration: 49 of max_iter: 50, perplexity: 1443.5132
# iteration: 50 of max_iter: 50, perplexity: 1443.2800
# done in 1519.897s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1647.9004
# iteration: 2 of max_iter: 50, perplexity: 1571.3332
# iteration: 3 of max_iter: 50, perplexity: 1538.5290
# iteration: 4 of max_iter: 50, perplexity: 1520.2498
# iteration: 5 of max_iter: 50, perplexity: 1508.6901
# iteration: 6 of max_iter: 50, perplexity: 1500.7241
# iteration: 7 of max_iter: 50, perplexity: 1494.9513
# iteration: 8 of max_iter: 50, perplexity: 1490.5955
# iteration: 9 of max_iter: 50, perplexity: 1487.1982
# iteration: 10 of max_iter: 50, perplexity: 1484.4676
# iteration: 11 of max_iter: 50, perplexity: 1482.1802
# iteration: 12 of max_iter: 50, perplexity: 1480.2578
# iteration: 13 of max_iter: 50, perplexity: 1478.6248
# iteration: 14 of max_iter: 50, perplexity: 1477.2097
# iteration: 15 of max_iter: 50, perplexity: 1475.9731
# iteration: 16 of max_iter: 50, perplexity: 1474.8806
# iteration: 17 of max_iter: 50, perplexity: 1473.9016
# iteration: 18 of max_iter: 50, perplexity: 1473.0066
# iteration: 19 of max_iter: 50, perplexity: 1472.1842
# iteration: 20 of max_iter: 50, perplexity: 1471.4284
# iteration: 21 of max_iter: 50, perplexity: 1470.7389
# iteration: 22 of max_iter: 50, perplexity: 1470.1140
# iteration: 23 of max_iter: 50, perplexity: 1469.5459
# iteration: 24 of max_iter: 50, perplexity: 1469.0240
# iteration: 25 of max_iter: 50, perplexity: 1468.5418
# iteration: 26 of max_iter: 50, perplexity: 1468.0934
# iteration: 27 of max_iter: 50, perplexity: 1467.6768
# iteration: 28 of max_iter: 50, perplexity: 1467.2895
# iteration: 29 of max_iter: 50, perplexity: 1466.9281
# iteration: 30 of max_iter: 50, perplexity: 1466.5876
# iteration: 31 of max_iter: 50, perplexity: 1466.2667
# iteration: 32 of max_iter: 50, perplexity: 1465.9636
# iteration: 33 of max_iter: 50, perplexity: 1465.6772
# iteration: 34 of max_iter: 50, perplexity: 1465.4059
# iteration: 35 of max_iter: 50, perplexity: 1465.1477
# iteration: 36 of max_iter: 50, perplexity: 1464.9025
# iteration: 37 of max_iter: 50, perplexity: 1464.6687
# iteration: 38 of max_iter: 50, perplexity: 1464.4459
# iteration: 39 of max_iter: 50, perplexity: 1464.2318
# iteration: 40 of max_iter: 50, perplexity: 1464.0267
# iteration: 41 of max_iter: 50, perplexity: 1463.8310
# iteration: 42 of max_iter: 50, perplexity: 1463.6443
# iteration: 43 of max_iter: 50, perplexity: 1463.4654
# iteration: 44 of max_iter: 50, perplexity: 1463.2937
# iteration: 45 of max_iter: 50, perplexity: 1463.1288
# iteration: 46 of max_iter: 50, perplexity: 1462.9698
# iteration: 47 of max_iter: 50, perplexity: 1462.8161
# iteration: 48 of max_iter: 50, perplexity: 1462.6674
# iteration: 49 of max_iter: 50, perplexity: 1462.5236
# iteration: 50 of max_iter: 50, perplexity: 1462.3845
# done in 1275.039s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1631.1887
# iteration: 2 of max_iter: 50, perplexity: 1556.8661
# iteration: 7 of max_iter: 50, perplexity: 1471.4922
# iteration: 8 of max_iter: 50, perplexity: 1466.3827
# iteration: 9 of max_iter: 50, perplexity: 1462.2446
# iteration: 10 of max_iter: 50, perplexity: 1458.6641
# iteration: 11 of max_iter: 50, perplexity: 1455.6580
# iteration: 12 of max_iter: 50, perplexity: 1453.2020
# iteration: 13 of max_iter: 50, perplexity: 1451.1386
# iteration: 14 of max_iter: 50, perplexity: 1449.3722
# iteration: 15 of max_iter: 50, perplexity: 1447.8550
# iteration: 16 of max_iter: 50, perplexity: 1446.5431
# iteration: 17 of max_iter: 50, perplexity: 1445.3950
# iteration: 18 of max_iter: 50, perplexity: 1444.3755
# iteration: 19 of max_iter: 50, perplexity: 1443.4538
# iteration: 20 of max_iter: 50, perplexity: 1442.6154
# iteration: 21 of max_iter: 50, perplexity: 1441.8534
# iteration: 22 of max_iter: 50, perplexity: 1441.1595
# iteration: 23 of max_iter: 50, perplexity: 1440.5259
# iteration: 24 of max_iter: 50, perplexity: 1439.9432
# iteration: 25 of max_iter: 50, perplexity: 1439.4016
# iteration: 26 of max_iter: 50, perplexity: 1438.8935
# iteration: 27 of max_iter: 50, perplexity: 1438.4157
# iteration: 28 of max_iter: 50, perplexity: 1437.9677
# iteration: 29 of max_iter: 50, perplexity: 1437.5501
# iteration: 30 of max_iter: 50, perplexity: 1437.1620
# iteration: 31 of max_iter: 50, perplexity: 1436.8014
# iteration: 32 of max_iter: 50, perplexity: 1436.4650
# iteration: 33 of max_iter: 50, perplexity: 1436.1505
# iteration: 34 of max_iter: 50, perplexity: 1435.8554
# iteration: 35 of max_iter: 50, perplexity: 1435.5773
# iteration: 36 of max_iter: 50, perplexity: 1435.3137
# iteration: 37 of max_iter: 50, perplexity: 1435.0625
# iteration: 38 of max_iter: 50, perplexity: 1434.8230
# iteration: 39 of max_iter: 50, perplexity: 1434.5956
# iteration: 40 of max_iter: 50, perplexity: 1434.3796
# iteration: 41 of max_iter: 50, perplexity: 1434.1744
# iteration: 42 of max_iter: 50, perplexity: 1433.9791
# iteration: 43 of max_iter: 50, perplexity: 1433.7928
# iteration: 44 of max_iter: 50, perplexity: 1433.6150
# iteration: 45 of max_iter: 50, perplexity: 1433.4453
# iteration: 46 of max_iter: 50, perplexity: 1433.2830
# iteration: 47 of max_iter: 50, perplexity: 1433.1276
# iteration: 48 of max_iter: 50, perplexity: 1432.9785
# iteration: 49 of max_iter: 50, perplexity: 1432.8350
# iteration: 50 of max_iter: 50, perplexity: 1432.6965
# done in 1127.929s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1613.7952
# iteration: 2 of max_iter: 50, perplexity: 1534.1070
# iteration: 3 of max_iter: 50, perplexity: 1500.2881
# iteration: 4 of max_iter: 50, perplexity: 1482.0287
# iteration: 5 of max_iter: 50, perplexity: 1470.7569
# iteration: 6 of max_iter: 50, perplexity: 1463.1238
# iteration: 7 of max_iter: 50, perplexity: 1457.6205
# iteration: 8 of max_iter: 50, perplexity: 1453.4915
# iteration: 9 of max_iter: 50, perplexity: 1450.3044
# iteration: 10 of max_iter: 50, perplexity: 1447.7812
# iteration: 11 of max_iter: 50, perplexity: 1445.7387
# iteration: 12 of max_iter: 50, perplexity: 1444.0531
# iteration: 13 of max_iter: 50, perplexity: 1442.6349
# iteration: 14 of max_iter: 50, perplexity: 1441.4189
# iteration: 15 of max_iter: 50, perplexity: 1440.3618
# iteration: 16 of max_iter: 50, perplexity: 1439.4340
# iteration: 17 of max_iter: 50, perplexity: 1438.6125
# iteration: 18 of max_iter: 50, perplexity: 1437.8799
# iteration: 19 of max_iter: 50, perplexity: 1437.2218
# iteration: 20 of max_iter: 50, perplexity: 1436.6258
# iteration: 21 of max_iter: 50, perplexity: 1436.0814
# iteration: 22 of max_iter: 50, perplexity: 1435.5807
# iteration: 23 of max_iter: 50, perplexity: 1435.1183
# iteration: 24 of max_iter: 50, perplexity: 1434.6912
# iteration: 25 of max_iter: 50, perplexity: 1434.2961
# iteration: 26 of max_iter: 50, perplexity: 1433.9301
# iteration: 27 of max_iter: 50, perplexity: 1433.5904
# iteration: 28 of max_iter: 50, perplexity: 1433.2746
# iteration: 29 of max_iter: 50, perplexity: 1432.9806
# iteration: 30 of max_iter: 50, perplexity: 1432.7064
# iteration: 31 of max_iter: 50, perplexity: 1432.4501
# iteration: 32 of max_iter: 50, perplexity: 1432.2099
# iteration: 33 of max_iter: 50, perplexity: 1431.9843
# iteration: 34 of max_iter: 50, perplexity: 1431.7721
# iteration: 35 of max_iter: 50, perplexity: 1431.5721
# iteration: 36 of max_iter: 50, perplexity: 1431.3835
# iteration: 37 of max_iter: 50, perplexity: 1431.2054
# iteration: 38 of max_iter: 50, perplexity: 1431.0371
# iteration: 39 of max_iter: 50, perplexity: 1430.8776
# iteration: 40 of max_iter: 50, perplexity: 1430.7263
# iteration: 41 of max_iter: 50, perplexity: 1430.5826
# iteration: 42 of max_iter: 50, perplexity: 1430.4457
# iteration: 43 of max_iter: 50, perplexity: 1430.3152
# iteration: 44 of max_iter: 50, perplexity: 1430.1906
# iteration: 45 of max_iter: 50, perplexity: 1430.0713
# iteration: 46 of max_iter: 50, perplexity: 1429.9571
# iteration: 47 of max_iter: 50, perplexity: 1429.8476
# iteration: 48 of max_iter: 50, perplexity: 1429.7426
# iteration: 49 of max_iter: 50, perplexity: 1429.6416
# iteration: 50 of max_iter: 50, perplexity: 1429.5445
# done in 1050.923s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1635.4844
# iteration: 2 of max_iter: 50, perplexity: 1544.0757
# iteration: 3 of max_iter: 50, perplexity: 1507.6084
# iteration: 4 of max_iter: 50, perplexity: 1488.4868
# iteration: 5 of max_iter: 50, perplexity: 1476.9248
# iteration: 6 of max_iter: 50, perplexity: 1469.2089
# iteration: 7 of max_iter: 50, perplexity: 1463.7079
# iteration: 8 of max_iter: 50, perplexity: 1459.6012
# iteration: 9 of max_iter: 50, perplexity: 1456.4263
# iteration: 10 of max_iter: 50, perplexity: 1453.9010
# iteration: 11 of max_iter: 50, perplexity: 1451.8425
# iteration: 12 of max_iter: 50, perplexity: 1450.1282
# iteration: 13 of max_iter: 50, perplexity: 1448.6765
# iteration: 14 of max_iter: 50, perplexity: 1447.4307
# iteration: 15 of max_iter: 50, perplexity: 1446.3503
# iteration: 16 of max_iter: 50, perplexity: 1445.4052
# iteration: 17 of max_iter: 50, perplexity: 1444.5718
# iteration: 18 of max_iter: 50, perplexity: 1443.8317
# iteration: 19 of max_iter: 50, perplexity: 1443.1696
# iteration: 20 of max_iter: 50, perplexity: 1442.5735
# iteration: 21 of max_iter: 50, perplexity: 1442.0337
# iteration: 22 of max_iter: 50, perplexity: 1441.5423
# iteration: 23 of max_iter: 50, perplexity: 1441.0928
# iteration: 24 of max_iter: 50, perplexity: 1440.6800
# iteration: 25 of max_iter: 50, perplexity: 1440.2995
# iteration: 26 of max_iter: 50, perplexity: 1439.9476
# iteration: 27 of max_iter: 50, perplexity: 1439.6210
# iteration: 28 of max_iter: 50, perplexity: 1439.3171
# iteration: 29 of max_iter: 50, perplexity: 1439.0336
# iteration: 30 of max_iter: 50, perplexity: 1438.7684
# iteration: 31 of max_iter: 50, perplexity: 1438.5199
# iteration: 32 of max_iter: 50, perplexity: 1438.2866
# iteration: 33 of max_iter: 50, perplexity: 1438.0673
# iteration: 34 of max_iter: 50, perplexity: 1437.8606
# iteration: 35 of max_iter: 50, perplexity: 1437.6657
# iteration: 36 of max_iter: 50, perplexity: 1437.4815
# iteration: 37 of max_iter: 50, perplexity: 1437.3072
# iteration: 38 of max_iter: 50, perplexity: 1437.1421
# iteration: 39 of max_iter: 50, perplexity: 1436.9854
# iteration: 40 of max_iter: 50, perplexity: 1436.8364
# iteration: 41 of max_iter: 50, perplexity: 1436.6946
# iteration: 42 of max_iter: 50, perplexity: 1436.5596
# iteration: 43 of max_iter: 50, perplexity: 1436.4306
# iteration: 44 of max_iter: 50, perplexity: 1436.3074
# iteration: 45 of max_iter: 50, perplexity: 1436.1896
# iteration: 46 of max_iter: 50, perplexity: 1436.0767
# iteration: 47 of max_iter: 50, perplexity: 1435.9684
# iteration: 48 of max_iter: 50, perplexity: 1435.8644
# iteration: 49 of max_iter: 50, perplexity: 1435.7644
# done in 965.856s.
# Fitting LDA models with tf features, n_samples=88481 and n_features=5100
# iteration: 1 of max_iter: 50, perplexity: 1570.6919
# iteration: 2 of max_iter: 50, perplexity: 1503.7139
# iteration: 3 of max_iter: 50, perplexity: 1475.7122
# iteration: 4 of max_iter: 50, perplexity: 1460.5632
# iteration: 5 of max_iter: 50, perplexity: 1451.0180
# iteration: 6 of max_iter: 50, perplexity: 1444.4273
# iteration: 7 of max_iter: 50, perplexity: 1439.4571
# iteration: 8 of max_iter: 50, perplexity: 1436.0518
# iteration: 9 of max_iter: 50, perplexity: 1433.3714
# iteration: 10 of max_iter: 50, perplexity: 1431.0577
# iteration: 11 of max_iter: 50, perplexity: 1428.9141
# iteration: 12 of max_iter: 50, perplexity: 1427.4503
# iteration: 13 of max_iter: 50, perplexity: 1426.2329
# iteration: 14 of max_iter: 50, perplexity: 1425.2725
# iteration: 15 of max_iter: 50, perplexity: 1424.4396
# iteration: 16 of max_iter: 50, perplexity: 1423.7945
# iteration: 17 of max_iter: 50, perplexity: 1423.2381

# %% [markdown]
# ### results

# %%
tmp_results

# %% [markdown]
# ### プロフィールを

# %%
def get_top_prof (topic_idx, top_n = 100):
    
    topics = lda.transform(X)
    prof_idx_list = topics[:, topic_idx].argsort()[:-top_n - 1:-1]
    return [docs[d] for d in prof_idx_list]

# %%
# get_top_prof(0, 20)

# %%
# get_top_prof(1, 20)

# %%
# get_top_prof(2, 20)

# %%
# get_top_prof(3, 20)

# %%
# get_top_prof(4, 20)

# %%
# get_top_prof(5, 20)

# %%
nownow_file = (datetime.datetime.now() + datetime.timedelta(hours=9) ).strftime('%m%d_%H%M')+"topic_modeling.ipynb"

# !cp ./topic_modeling.ipynb ./jupyter_backup_for_param/$nownow_file

# %%
file_name = (datetime.datetime.now() + datetime.timedelta(hours=9) ) .strftime('%m%d_%H%M')+"_output.txt"
