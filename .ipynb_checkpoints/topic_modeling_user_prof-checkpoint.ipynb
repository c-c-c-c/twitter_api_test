# %% [markdown]
# <a href="https://colab.research.google.com/github/tomonari-masada/course-nlp2020/blob/master/11_topic_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 標準使用ライブラリー
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')
import gc
import os
import shutil
from icecream import ic
from tqdm import tqdm_notebook as tqdm 

# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# 追記
import json
import datetime
import math
plt.style.use('dark_background')

# debug
#%pdb on

import pixiedust #%pixie_debugger

# tfがエラーはかないため
# tfがエラーはかないため
#import tensorflow as tf
#import os
#os.environ["CUDA_VISIBLE_DEVICES"]="5"
#physical_devices = tf.config.experimental.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.19</span>
#         </div>

# %%
import pandas as pd
import re
import emoji
from wordcloud import WordCloud, STOPWORDS

df = pd.read_csv("./result0605.csv", engine='python')

type(df["description"])
docs = df["description"].to_list()

# %%
print(len(docs))
# Out:
# 93794

# %%
print(docs[0][:1000])
# Out:
# 漫画、アニメ、声優垢。 RT多め気ままに呟きます。伏線系の漫画好き。古川慎さん・小林裕介さん・河西健吾さん ・田丸篤志さん推し

# %% [markdown]
# ### Neologdを使ってtokenizeする

# %%
docs
# Out:
# ['漫画、アニメ、声優垢。 RT多め気ままに呟きます。伏線系の漫画好き。古川慎さん・小林裕介さん・河西健吾さん ・田丸篤志さん推し',
#  'D垢。プリンセスよく描いてけど…たまに違うものも描きます。手遅めですがよろしくお願いします🙇🙇 ※名前の読み方は自由なんで好きなように読んでください 最近は低浮上なので…別の絵垢 →@ri_ri_ri_ri_on',
#  '𝖒𝖔𝖔𝖓𝖎𝖆𝖓 ♤  𝔣𝔱𝔦𝔰𝔩𝔞𝔫𝔡  ♢ 𝖒𝖎𝖞𝖆𝖛𝖎  ♧  𝔥𝔬𝔦𝔷𝔢𝔯  ♡  𝖇𝖇𝖟  ✩  𝔪𝔢𝔩𝔩𝔬𝔴𝔪𝔬𝔱𝔦𝔣\n˗ˏˋ⋆·˚ ༘ * アララカタブラツルリンコｫォォオ!!✩‧₊˚´ˎ˗.',
#  'ENHYPEN、アニメ・漫画 ゲーム関連でTwitter使ってるので、それ以外は無反応です、、',
#  '【心にゆとりと潤いを💞】目指すのは学校の保健室のような場所・ホッと一息つける場所｜あなたの幸せを願っています｜職業:音楽の講師｜《自分磨き中》自分らしくあるためのツイート｜思った事を呟きます｜時々ドジ有り｜🐶2匹と🐈4匹がいます🐾',
#  '過去にジャパリカート動画、TSUMURI KART(VRChat)など作ったり、ワリスノ(MK8DX)一位だったりした人。\n社会に出てから疲れてる。\n配信→https://t.co/FJoitl8JHE\n\nヘッダの猫の飼い主→@___smmmmm',
#  '🔥🎴・💎⚡️・⚡️🎴・👹🎴主の雑多垢🙏 成人20⬆️ic:自作 hd:@kmtmiu_ 様よりフリーヘッダー',
#  'カクヨムとなろうとマグネットで文体軽めの小説を書いています。お暇なときに覗いて頂ければ感謝です。小説家になろうhttps://t.co/m5g1Z7QKZH カクヨム https://t.co/zzkalYriZU 無言フォローにて失礼します。',
#  '椛クラスタ多方面クソリプ型特攻兵器お祭り野郎/TRPG/ベイブレード/野良売り子やります/アイコンはふぇのめにょもけさん（@monyomoke）さんに書いてもらいました。（https://t.co/dG1aDtgx56）/',
#  '錆兎さんのチャンネルにハマってます(๑•̀ㅂ•́)و✧継ぐチョコ🍫(*´³`*) ㄘゅ気軽に話しかけてね❤ アイコン@_mimicha_zzzみみたん♡ヘッダー@SiN_190609 シンさん(*^^*)',
#  nan,
#  '8enz0です。べんぞうと読みます。\n\n2020/12/28 Youtubeはじめました。',
#  'お絵描きおじさん。2児の父。',
#  '❦Just see tweets everything.❦My world is my world, but you can come in if you honor each other. ❦เปิดทวิตเพื่อตามและบ่น❦',
#  'ゲームとミラジーノが好きなクサガメの世話係。RT、いいね多いよ。最近は鬼滅と呪術とウマ娘とFF14 。水柱と夏油とその中の人推し。',
#  '推しキャラコスでピアノ即興演奏します❤️✨\nフォロー友好的♪コメ＆いいね＆RTお迎え💕\n鬼滅、FGO、エヴァ、セラムン、とある、炎炎、約ネバ、SAO、凪あす、空の境界、銀魂、文豪、グラブル、夏目、ジブリ、るろ剣❤️愛猫はノルウェージャン♀🐱ピアノ奏者、経営者、教育者。即興と作曲🎹お酒と肉と蛤と鰻と猫が大好き💕',
#  '映画見て感想呟いたり、プラモデル作ったりするアカウント。映画見て感想を呟かなかったり、プラモデルを作らない時もあるアカウント。',
#  '音楽とお酒と塩顔の男が好きです',
#  '成人済/腐/なんでも許せる方向け/通知off/たまに絵を描きます\nフォロー前に必読▶【https://t.co/WDqPcbj5kq】※Repost is prohibited.転載禁止。',
#  '元北海道、北陸。現愛知県民。痛車大好きな人。GD２(天体のメソッド仕様)→ラブライブ痛車乗り(ほのりん仕様)のフィット(GE8)\u3000ミラカスタム(島田愛里寿仕様)  ドールオーナー、ラスバレ、フォローはフォローはお気軽にどうぞ',
#  '趣味用ですな。\n好きなモノを好きなようにながめたい。\n鬼滅の刃、Dr.STONE、約束のネバーランドにハマりました。\n\nさぁ大変なことになりましたぞ！',
#  '元仮面女子・元アリス十番・元アーマーガールズ・元チェリーブロッサム・元肉汁ガールズ・元ぱー研!・元スライムガールズ・八重歯・楠木まゆ(卒業して芸能活動からは引退済)(@mau____1013)推し・元サッカードイツ代表・闘将 ローター・マテウス氏を尊敬しています！',
#  'ゆずとかゆずくんって呼ばれるの好きです／#専門学生(介護福祉学科)／ #寮 で暮らしてます／絡みたいと思っている人にしかいいね押しません／荒野行動( #global民)／アニメ・漫画好き／将棋ウォーズ２級／プロセカ／ごく稀に病むときあります() 推しマ→ 🌌💤・🎐🍒 アイコン(@ALkXEu229pq1EKQ)',
#  '成人済みの一般人兼オタク兼腐女子12y | TW,JP,EN | Vegetarian | よろしくね！꒰(๑´•.̫ • `๑)꒱',
#  '特オタでロボオタで80年代ジャンプオタなおっさん。その昔、ロックスターになりたかった（歌を歌う係を任されていた）クウガ、響鬼、ガンダムと古いサンライズ作品、聖闘士星矢が好物。 職業:会社を経営しております 目標にする経営者:竹尾ワッ太',
#  '98line❣️',
#  '平針 名・栄 鳴海・大曽根 千種！\nYouTube活動してます！\n3人と流行を取り入れたイラストを沢山お送りしてます！是非遊びに来て下さいね^^*',
#  '愛知、apex、ガンダム、グラブルvs        その他 イラストRT多いので許して                 結目ユイおたく\u3000',
#  'ジョジョが好きです。GNCT卒業生。好きなソシャゲはFGO。呪術廻戦が楽しすぎて新巻が待ち遠しい。\nやたら赤い奴をすきになる。',
#  '寝ても覚めても徳島ヴォルティス大好き！サポーター歴１7年目！Ｊ１定着へ！もう中年おっさんですが情熱は変わりません💪気軽に声をかけてね😉\n#浜下瑛',
#  '一人娘に甘めな母。難しいことは良くわかってなくて、すみません🤣💦 親子で鬼滅の刃にハマっております(母→実弥 娘→善逸くん、伊黒さん) ✨✨家族の癒し💕柴犬🐕海(カイ)♂(袋井市 芝田荘出身)',
#  '声優さんのイベントの感想など ごちうさシャロ＊アイマス蘭子 楓 琴葉＊ウマ娘ゴルシ',
#  '鬼滅の刃の時透無一郎くん推しです❤むいちろ好きすぎて頭おかしいです🥺🤲 むいに全てを捧げます…💕無言フォロー、タメ大歓迎なので気軽に絡んで下さい☺✨鬼滅垢でしたら基本フォロバさせて頂きます😊✨推し同盟▷▶▷（@le_ciel_hyde_）',
#  'さぬき でーす！第5人格、ツイステ、とうらぶ、鬼滅、呪術、Skyなどなど… お絵描きします。(@Nekosaki_Alice) →夢・腐垢。。。無言フォロー失礼します(●︎´▽︎`●︎) /@OIMYK_1124',
#  '♡GOOD MORNING ☆ GOODNIGHT ☆HAPPY BIRTHDAY♡',
#  '趣味はやおいを少々。日常メインたまに二次創作。ツイフィのお目通し推奨。昭和末期生まれ。番組実況有〼。',
#  'スピリチュアル系・歴史系物書き（風吹しづる）エロ系（槌屋ほむら）、ヒーラー、建築設計屋さんはおまけ。',
#  'カラーと申します。声真似動画を趣味で作ってます。《Like:FGO 特撮 プリキュア メガテン 呪術 ウマ娘 時々声真似 中/村/悠/一s声真似兼FGO作品他のキャラ声真似 》トレーナーとして、ウマ娘より強そーな中村さんキャラを探す日々←',
#  'オスネコです。全身が白色です。頭のてっぺんだけ黒い毛が少し混ざってます。まったく同じ色のネコを見たことがあるのですが、珍しくないのかしら。しっぽはリボンではなくて包帯です。',
#  nan,
#  '3Dのさくひんつくってるひと ちーむ:［@Heart_F_clan］ せんぞく:［@GxxxxxxxU］［@Zeno_af］りすぺくと:［@BoBoBoBoin_n］:［@toroch_］💓［@2525papico_ ］デバイス:https://t.co/sULkcWgFRr ふぁんま🎩',
#  '女子高生です(揺るがぬ意思)',
#  '歴史が好物のゲーム垢(たまに日常)無双/モンハン/APEX/fgo/原神 etc... 無言フォロー失礼⚠️腐ってる大学生(18↑) @caffeinenoboku ←第五ツイステあんスタ ツイフィ→https://t.co/QHijO4u70o',
#  '#欅坂46 山崎天 土生瑞穂 平手友梨奈\n#日向坂46 丹生明里 佐々木美玲 #乃木坂46 佐藤楓 梅澤美波 #すとぷり 💗くん\nｱﾆｦﾀ.🚺.07.LINE交換✕🙏💦\nDM返信遅いです',
#  '草花♡散歩♡音楽♡綺麗な写真♡\n美味しいご飯♡twitter初心者です宜しくお願い致します\u3000無言フォロー失礼します',
#  '映画やアニメを観るのが好きです。 最近は洋画沼に浸っております。 腐ってます…',
#  '🐸😈 Visual Kei Jrock  // kpop // Bands// Anime  (.ΦωΦ.)🐸😈 🇦🇷🇯🇵',
#  '私は白鈴！「はくりん」って読むよ！ゲームとボイロが大好きなスケベ絵RTマン！たまに動画を投稿してるよ！',
#  'Main @Xkun1026 Who are you ?',
#  'ヤンバルクイナ\n誕生日はヤンバルクイナが発見され命名された日',
#  '👀 ESP/ENG 👀\n                         ❌ Spoilers Ahead ❌',
#  '迷ったらストラト星人と戦ってる',
#  nan,
#  'キノコ嫌いなトウカのもり所属の大学生。アニメ/デュエルマスターズ/ポケモン/ゆずソフト/カラオケ 在原七海一神教。',
#  '☆宮野真守激推し！！マモクラ仲間募集中です\\(* ¨̮*)/\\(*¨̮ *)/🍍☆.｡.:*・🍍☆.｡.:*・🍍☆.｡.:*【☆お取り引きついて】ゆうちょ対応。譲渡、交換、買い取り経験有ります。成人済み',
#  nan,
#  'リトルトゥース☝️おひさま☀️丹生ちゃん推し🐸🥕',
#  '小学生の時に出会ったTHE ALFEEが大好きです💖\n映画好き🎥特に”カメ止め🧟\u200d♀️”と”スペアク👐”が最高💕💕\nただ今”鬼滅の刃”にハマり中🤗/燕党/リラックマ🐻/可愛いもの/星/ビーズ手芸/美味しいもの好き🌼💕',
#  '最近はウイイレしてます！',
#  '⭐トットこジエリッヒダンテ\u3000大阪27期\u3000西も東も\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n🌼吉本坂\u3000ﾀﾀﾞﾁｬﾝﾋﾅﾀﾁｬﾝ ﾅｵﾁｬﾝ ﾃｯﾁｬﾝ',
#  'あ',
#  'ラブライブ→凛ちゃん､丸ちゃん バンドリ→@banndori_sayaプロセカ→こはねちゃん、腐女子。流れ星☆SPF(FPS)ガチ初心者（APEX、ライズ）。ヘッダー→リアトコ@_ReaToko_',
#  '二次アカです/志崎樺音さんを応援しています #のんフィル/Roseliaは人生/ハピアラはいいぞぉ/白金燐子さん＆渡月麗さん推し/バンドリとD4DJが多めです/ときたまアニメ/たまにパズドラ/今年こそ日本一⚾🐰',
#  '役者。たまに構成作家。まれにイベントや広告のプランナー。時々、商店街の広報。昔、余分三兄弟の糖分。5年前、ショッカー部長。18年前、東京モーターショーCMコンテスト準グラ受賞。難しい事抜きに、ゆる〜くつぶやきたいと思います。sas応援団会員。桑田佳祐推し。 office yamajam 代表取締役社長 へそり運営',
#  '釣り(今はジギング)と音楽(HM・HR)が大好きな二児の父です。軽い気持ちでバスケ沼に片足突っ込んだら抜けれなくなり…家族でスサノオマジックを応援してます！松江シティFCも応援中です。子供達もミニバス奮闘中！無言フォローすいません(((^^;)無言フォロー大歓迎です(^-^ゞ',
#  '🇨🇳中国人です 。どうぶつの森❤️ 中国人，动物之森❤️平川大輔',
#  '🦄姫ぷぅ🐯←ミラティブ配信してます💖 ポケモン🌟モンハン🌟シノアリス🌟モンスト🌟頑張ってます❣️下手すぎて常に姫プレイ⁄(⁄ ⁄•⁄ω⁄•⁄ ⁄)⁄ﾃﾚﾃﾚ',
#  'ドラえもんやクレヨンしんちゃんの感動シーンで泣く😢涙もろい子供６人の父親🤗トレーラーヘッドのボルボに箱乗せた日本に１台と言われるトラック乗って大阪の冷蔵庫回ってます🌟\n❤安室奈美恵♥️＝神＝\n❤@AimyonGtter♥️\n✨Fateセイバー✨🔥煉獄杏寿郎🔥',
#  '好き → 料理🍳旅行✈️グルメ🍲コスメ💄お酒🥃サッカー⚽️アメコミ🧜🏽\u200d♂️あつ森🐶ドラクエ🐦パソコン💻音楽🎸柴犬🐕 当選したら→ #きんとん当選 色々な企業様とご縁がありますように👼 無言フォロー歓迎です！！\n最近ハムちゃん飼い始めました( ^ω^ )',
#  '我妻善逸を吸って生きています。',
#  'サムネもヘッダーも妻（@Akaki_Kon129）が描きました\n\nあつ森:夢番地\u3000DA-6065-5291-8078\n\u3000\u3000\nモンハン、スプラ2、リングフィット、フィットボクシングやってます\n\u3000\u3000\nマリオオデッセイ:写真コンテスト銀賞3回受賞\u3000\u3000\nスマブラSP:第1回写真コンテスト採用',
#  'FANKS。笑いの神様と負けの神様に取り憑かれ中。まえで、うら、ずく。無言フォロー即ブロックします（例外有り）ごめんなさい。',
#  'once&withUです♡是非絡みましょう！\n優しい専属加工師！→ ︎@HONO71523432 たくさん絡んでくれる！ ︎→@HN45007630 めっちゃ話しやすい！→ ︎@Nanashichan324\n~ヘッダー専属加工師さんが制作してくれました~',
#  '20↑腐ってます。ROM専',
#  'ウマ娘やるマン。あと漫画とか特撮ヒーローとかアメコミヒーローとか食玩とかオモチャとか子供の事とか。ハイローも好き。FGOやスタァライト、アサルトリリィも。昔WTRPGやってました。',
#  '初マタ→育児アカへ🙋\u200d♀️ 情報収集と思考整理のため専用のアカウント作りました 2/21無事に女の子出産しました🎀',
#  "アニメ系とゲームが大好きな専門校生です\n東方とか好きです。\n音ゲーを少しやってまーす\n趣味は音ゲーとクレーンゲームです(*'ヮ'*)",
#  '📸奈良のことばかり🦌/奈良が好きすぎる！🥰#奈良が好きな人と繋がりたい \n\n❤️☞夏目友人帳.ノラガミ.鬼滅の刃😃\n無言フォローすみません🙏🏻💦',
#  '幼児２人の母/睡眠時間は確保したい/時短勤務中/活字でも漫画でも本を読むのが好き/イラスト集も好き/プラレール楽しい/踏切も楽しい/何かに没頭できる時間って素晴らしいよね✨',
#  '雑多なゲーム垢。FGO/メギド72/グラブル/アイギス/崩壊3rd/MtGAなど。\n統べ済、極め2、賢者2。神石は水と闇。最近デレステの履修始めました。',
#  '逃げシスが好き過ぎるへんたいふしんしゃトレーナー。ナナシスとかアイマスとかドラクエ10好き。サッカー♦️も良く見ます。前世で絵描きしてました（',
#  '🐼AAA(SHINJIRO ATAE推し💙)\n関ジャニ∞\n鬼滅の刃\nセーラームーン\netc..\n\nいろいろツイート･RTします💡\n\nたまに疲労困憊で病みツイートしたりしますがご了承下さい😥',
#  '絵を描きます。またの名をディルムッド翁。絵はモーメントに纏めてありますアイコンは自前絵。小説も歌も勉強中、アイアンサーガ（机动战队）ウマ娘。無差別RT多め。私のイラスト無断転載禁止です。Unauthorized reproduction prohibited',
#  '懸賞垢🎁新社会人👩\u200d🎓ブルベ夏🌻好きなもの→コスメ💄サンリオ🐰特撮⚔️声優🎙邦ロック/V系🥁お笑い👯アイドル🎀 当選したときは #ろろの当選報告 で報告します！夢はデパコス当選🥺💭気軽にフォローして下さい🧸懸賞垢さんはフォロバします✨敬語ポイ🙆\u200d♀️ #懸賞垢さんと繋がりたい',
#  '北海道江別市在住。江別・野幌・大麻地区の情報発信サイト「えべナビ！」を運営（月間最高57.4万アクセス 累計1,300万PV超）。管理人は育児中40代。旅、鉄道、廃線跡、廃墟、古い建物、読書等が趣味。ブログ講師・Webコンサル業。フォローお気軽にどぞ！(^^)フォロー返しは気まぐれ。鍵垢は基本フォロー返ししてません',
#  '〝セレブ〟の最上級、最高・究極に達したセレブのことを、人は〝セレベスト〟と呼ぶ! 勢いＭＡＸの作者が一筆一筆に魂を込めて描き荒らす、究極セレブたちの天下取り!! セレベストたちの合戦「おもてなし」で相手を屈服させ、究極セレブ界の頂点を目指せ!!',
#  '役者🕊脚本勉強中✍熊本県出身農家の娘🧸お洒落に生きたい田舎者🌾',
#  '八雲紫と西行寺幽々子、フェローチェ(アニメのは除く)、お姫様、ドレス、雑コラ作りなどが好きです。妄想絵とか出すことも…。固定ツイートは毎回変化するかも?\n\n他に好きなキャラ:ミュウツー、シルヴァディ、マッシブーン、サザンドラ、ピーチ姫、デイジー姫、ロゼッタなど\n\nPixivやってます',
#  '好きなものに囲まれてたい💮',
#  'FF7ｸﾗｽﾀ/DMCｸﾗｽﾀ/ｸﾗｳﾄﾞとﾊﾞｰｼﾞﾙ好き/FF7全ｼﾘｰｽﾞ小説も/ 5,8～10-2,12～13-3,15,零式/ﾊﾞｲｵ,DMC1～5(SE含),ﾆｰｱ, 等/※成人済の腐女とある大学🏥勤務/ｺｽﾌﾟﾚたまに/DMC兄弟愛/ﾈﾛVも良し 地雷なし何でも美味し😚FFとDMCばっかり',
#  '歌い手',
#  '〈お目当て⇨〉①動物 ②科学情報 ③絵④雑事連投発散⑤この頃天文に興味あり、はやぶさ2愛炸裂中 / 〈NG⇨〉①身元判明につながる固有名詞は載せません②人格否定と攻撃には加担しません',
#  '旅、釣り、ゴルフ、登山、料理、お皿、お酒が好き。 趣味の為なら寝る間も惜しんでどこまでも行きます。日々食べる食、休日をどう楽しむか、に重きを置いて仕事も楽しんでいるおなごです。',
#  '楽しそうなことには何でも興味を持ってしまう今日この頃。\nLiSAとポケモンと日本酒が大好き。\n趣味は広く浅い。たまに人と価値観が大きくズレる。最近はAudibleBookで読書してる。\nずんだ餅は枝豆な！覚えとけ',
#  'RN(BN・FN):おさるのジョージ\n\nHBCラジオリスナーです📻',
#  '成人済♀。津田健次郎さん、櫻井孝宏さん、福山潤さん、石田彰さん、吉野裕行さん等々声優さんとアニメと漫画とラジオが大好き♡ そしてレッズサポ♡ アイコンは杏耶＠あや\u3000\u3000@ayatanponpon様作のアマビエ様です。コロナ終息を願う日々。',
#  'イケメン男子に生まれ変わりたい…背伸びないなぁ、夜更かしばっかだからか…(´・ω・｀)最低165はほしいな(☆∀☆)',
#  '多趣味。アニメ・漫画について呟くこと多々！無言フォロー失礼します🙏⚠️腐気味',
#  '癌だけど、体中痛いけど、まだまだ歌います♪',
#  "Age: 19\nGender: Female\nLikes: Anime, Japan, Cute Animals, memes, crossover, Cartoons, Music, Art, and, Other Things\nI'm a Oc",
#  '30代♀大阪在住 #ふわっち #ツイキャス #スプリットタン 🐍 配信は低浮上 🐰にしてるのは干支が兎なのです！',
#  'ニンニク醤油でお肉を食べるのが好きです',
#  '趣味はドローン空撮と車です♪あちこちで許可を頂き動画を編集、アップしてます♪相棒はDJIのMAVIC 2PRO♪FPVドローンも始めドローンレーサーを目指してます！愛機はBETAFPV 65X HD。愛車はGRヤリス（RZ HP）その他気ままに呟いてますので趣味が同じ方など気軽にフォローしてもらえると嬉しいです♪',
#  'まどか☆マギカと東方とサンホラが大好き。まどマギ議論大歓迎で、気軽に話しかけて頂いて大丈夫です(まどマギ同盟No2)。また、二次創作活動をしている方の話に興味があります。あとマミ、マミさん。まどか☆陛下のMADをニコ動に時々UPしてみたり。 アイコンは@kyokokakikakiさんから',
#  '限界腐れ雑🈕沼底𔒥回遊ヲタク夢女。\u3000\u3000\u3000(成人済) 実況垢→ @yura_906',
#  '色々と好きです\n物忘れが激しすぎ\n楽しければ何でもいいや\n最近の属性は着物ヒゲ眼鏡',
#  '政治に関してや日本の現状について考えています。NHK集金人の杜撰な対応からNHKについて知り、嫌いになりました。',
#  'リアル黄色サチコメ。\nFF11はえふえふじゅういちと読む派です。\n吉田のFF14が嫌いです。ていうか吉田が嫌いです(=ﾟωﾟ)\nSNSの『いいね』はただのブックマークだと思います。\n誤字脱字多めです。',
#  '成人済！漫画やMVを描くほぼツイステ垢です✌️※無断転載厳禁 ▼インスタ▼',
#  '※社会人 ※大人',
#  'くま好き(๑･㉨･๑)💗うさぎ好き(◍ ´꒳` ◍)💗ぴーち好きξ*‘ ｰ‘)💗24好き💋(ともだちはくま/うさまる/Kis-My-Ft2/藤ヶ谷太輔/Nissy)',
#  nan,
#  'き   た   な   い   。\nお下品な垢(雑多鬼滅多)。日常ツイも含。\n推は炭治郎くんと善逸くんと獪岳くん。上弦も好き。でも下品です。\nツイフィ読んでくださ(懇願)',
#  'コウタクRPGのコウです！色々あって実況おやすみ中😭適当に呟きます！ /イラスト/ファッション/マンガ/アニメ/ゲーム 【ゲーム実況→@koutakurpg】【相方→@koutakurpg_taku】',
#  'サモンナイト/Fate/FE/FF14/刀剣乱舞/ペルソナ/など基本アニメやゲーム中心に呟いております、ごった煮垢。 ただいまFate沼に沈んでいます。あとなんか適当に呟いたりしています。最近FF14多めガルーダ鯖在住',
#  'カフェ経営中\u3000古代エジプト史勉強中\u3000カメラ、海外旅行、インド\u3000トルコ\u3000エジプト\u3000ウズベキスタンに行く、ジョジョ、ディズニー、妖怪、寺社仏閣好き、御朱印、写真、 大江山妖(鵺) \u3000オスマントルコ外伝面白い',
#  '23age\U0001fab4Hobby:travel💼/Cafe hop☕/interior\U0001fab4/Camera📸/퍼슛사진&일상계 FUBM Free icon by @radywolf',
#  '乗り鉄(国内全鉄道完全乗車済)。FF14はラムウ鯖在住。最近はアニメに出て来る鉄道の考察をよくしています。アニ鉄好きな方のフォローお待ちしてます。',
#  '亥年♓生まれのＯ型(＋)\u3000◇本家は福島県喜多方市にござるが、拙者は生まれも育ちも港町よこはまなう\u3000◇自然を愛で、SDGsの達成と脱炭素化社会の実現を目指すでござ~る。\u3000◆なお、①あやしい投資話や②出会い系などは👹お断りし、③去る者は😔追いませんので、フォローの際にはご注意くだされ',
#  nan,
#  '新しい活躍の場を求めて似顔絵はじめました。 https://t.co/lHSsRqEZlm 日々猛勉強中！',
#  '俺の名は狂四郎、警官と教師の間に生まれた奇行種さ！\nお色気は期待しないでくれ、でかい身体だけが自慢なのさ、頼まれれば大統領だってぶん殴ってみせらあ。\n…でも飛行機だけは勘弁な。\u3000\n【ピクシブ】https://t.co/MiJifma2Nx',
#  "オニギリMTたのしかった…(悲しみ)Team 'F'に所属してるっぽい。VRChat初心者です。",
#  '推し中心で世界まわってる生活。',
#  '----手術も終わって仕事をしながら療養中。服薬つづけてまーす💊   -----\n\n\n\nテニス🎾すき /\n\n自転車🚴すき/\n\n ねこฅ(^^ฅ)すき  /  \n\n仕事💻すき  /  \n\n運試し🎯すき  /  \n\n飛行機*⋆✈すき  /\n\n #んなわけ当選報告\n#懸賞垢さんと繋がりたい',
#  '猫が大好きです。自然も大好きです。\n天瀬ひみかさんを応援しています。\nコードロジーの勉強中です。\nこれから聖三活動に励みます。\n基本無言です。',
#  '趣味の備忘録',
#  '👹腐アカウント・無限🚂でやられた・成人済 🔥右が好き・特に🎴🔥・🐥🍑 見るのは雑食 腐ではない方や18歳未満フォロー非推奨',
#  '#FGO ／#VR ／#ドローン ／#ホームシアター / #スマートホーム /#筋トレ /#旅行 /#高知 出身 / 職業モンスターハンター\nツイートは画像多め。フォロー・リムーブご自由に',
#  '赤ヘル一筋、キン肉マンを愛し特撮大好き1児のチチです😎無言フォロー失礼します🙏',
#  '台湾人です!!❤️🇹🇼\n大家好(*´ω｀*)\nよろしくお願いします💕\n鬼滅の刃&lovelive&文豪stray dogs&SK8大好き😍\n因為本人不太會日文所以幾乎都用翻譯🤣🤣\n自學好難(´；ω；｀)\nInstagram:sd_zoe0607',
#  '20↑雑多夢腐 RKRN:ﾉтﾀΞﾅ:YGO:ﾁｬﾝ(版権あり):prri:呪 ぽい https://t.co/aDlD3YyM8C 伏 https://t.co/4G3AY8b3af ⚠️本誌読 お別れB',
#  '日常やゲームに関してのんびり投稿。スロット投稿もあり。',
#  'イエス ウィー キャン😮自動売買はじめました😮｜副業でFXで作った借金を返済するぞ😮｜バズビデオで１月は２０万くらい😮｜YouTubeも やろうと考えています😮｜いつかはフリーになって自由に働くぞ😮｜ブログ😮 https://t.co/nVX7VyjVN5｜LINE@ 😮 https://t.co/Y4aegvHKkE｜',
#  'これ本垢❗【地獄常世の大魔閻妖狐】\nアイコン絵師：@cinayethayvan1様❗エヴァ、マイクラ、刀剣乱舞、第五人格、ツイステ、あんスタ、にじさんじ🌈すとぷり🍓👑好き❗歌い手様など、色々他にも大好きじゃ！',
#  '#ダーツ #モンスト コンタクトと眼鏡',
#  '成人済みの社会人♀／関東／銀魂／鬼滅／i7 /twst 呼びタメ大歓迎🙌冨岡義勇がすき🌊',
#  'ビールとミッキーが活力🍺 酒好き大歓迎♬/#モンスト 運極700↑/#ポケモンGO/モンハン/#ディズニー（TDL・TDS各単パ持ち）/#水族館 (某所年パ持ち)/ #カメラ/写真/Q-pot /ANNA SUI/#ジェラピケ/謎解き/#お酒/#料理/ビールくれなきゃ悪戯しちゃうぞっ乁(๑˙ϖ˙๑乁)ｳﾞｧｧｧ！',
#  '・20↑NLのみ\n・アイコン＆ヘッダー→ぷ～さん( @makuralove39 )',
#  '趣味は映画鑑賞。好きな映画はMCU、DCトランスフォーマー、プリキュアなど。映画当たり屋なので地雷映画も積極的に踏んでいきます。YouTubeで映画レビュー動画を投稿してます。気軽に絡んでください(^o^)',
#  '中洲の綺麗なお嬢さま方を見る為の技術系中年のアカウント\n 元々情報収集用＆テスト用垢なので色々と適当です😁 質問箱とTikTokはキーワードミュートしてますので見えてません。「過ぎたるは猶及ばざるが如し」ということでＲＴ多めの方は非表示設定にしてます\nあまり絡まないようにしてますが、知ってる内容だとリプしますー',
#  nan,
#  nan,
#  'たい焼きは頭から 第五人格 お布団の住人 鬼滅は神アニ 面白いと思った動画切取りツイートさせて頂いてます ✼ヘッダーは紙(paper)さんのイラストです！',
#  '成人済み。夢＆腐女子   あんスタ/トリスタP/カラマリ/愛時/ ヒプマイ/ヒロアカ/鬼滅/ポケモン/ツイステ',
#  'ɪɴғᴘ | 20↑ | ᴍᴀɴɢᴀ ᴍᴜsɪᴄ ᴍᴏᴠɪᴇ | ɪɴᴏᴀᴏɪ ɢɪʏᴜsʜɪɴᴏ ᴏɪsᴜɢᴀ ᴋᴀɢᴇʜɪɴᴀ ᴛᴅɪᴢ ᴋᴀᴄᴄʜᴀᴋᴏ | ᴋɴʏ ʜǫ ᴍʜᴀ ᴊᴊᴋ ᴇᴛᴄ |',
#  '#ワンオク\n#BIGBANG\n#GReeeeN\n#AAA\n#UVERworld\n#野球\n#甲子園\n#バナナマン\n#チョコレート\n#相互フォロー100',
#  'とら(最近ワンコ)、ですm(__)m\r\nアニメと音楽とアイドル(幅は広い？)をこよなく愛す\r\n変なおっさんですが、\r\nてきとーに絡んでやってください。\n篠田麻里子→峯岸みなみ/宮澤佐江→須田亜香里/山本彩→谷川愛梨→本郷柚巴/チームBⅡ',
#  'Slow artist🚶 • (🇻🇪)Esp/Eng • Multifandom• ⚠️ not spoiler free!!⚠️',
#  '目標は自作アニメ配信🔻🔻🔻',
#  '成人腐女子 お絵描き好き 模写 鬼滅の刃/D.gray-man/銀魂/約束のネバーランド/SPYFAMILY/ etc..... 気ままに投稿します😳',
#  '神谷浩史さん 入野自由さん応援\\♡/Kiramune紫赤推し✩*ﾟ/KAmiYU溺愛♡/Sphere橙♡/77様♡',
#  '今年はアクティブに生きたい。趣味はミシンとロードバイク。スヌーピー(・´｀Uとコウペンちゃん好き(・Θ・)🚴🏻\u200d♀️⇒ロードはLiv 、クロスはTREK FX3 、シューズ→fi:zi:k✨NEW、ヘルメットKASK、‧✧̣̥̇‧✦‧✧̣̥̇‧✦‧✧̣̥̇‧✦‧✧̣̥̇‧✦次回レース✩.*→無し…😭',
#  '成人腐女子/嶺二と七種と冨岡と伏黒/蘭嶺とジュン茨とさねぎゆと五伏/推しに夢も見がち/WJ最速派',
#  '✳️みやです。遥か昔に成人済の腐✳️👹さねげん・おばみつ✳️呪🐯右色々✳️本誌派ネタバレ有✳️女体化・ケモ化好き✳️転載引用複製翻訳不可✳️ 18歳以上になってからフォローしてね✳️https://t.co/tRmwG3TPwk✳️https://t.co/FSgTAEtjuu',
#  'アクティヴレイド推し妖怪',
#  'Laugh & Peace/だーうえFC/中島由貴FC/さらに向こうへ Plus ultra!!',
#  'リリカルなのは、ＤＯＧＤＡＹＳ、スーパー戦隊やガンダムなどが好きな通りすがりですよん フォローはご自由に～\u3000気ままな流れ者  ついプロは必読だ！ ちなみになりきりではない',
#  'j-rock kpop anisong ; mamamoo oneus lucy',
#  '広島→岡山→大阪→岡山 mushimaR(ムシマル)ことmatsumuraはシンガーソングライターです。 歌 ギター カメラ サッカー 文具事務用品 親バカ ただのバカ 働く男。 [セラレ@serare_info][mushimaR UNITED][MANE SEA][CRASHIKI CRASHER(S)]',
#  '成人済。詳細はツイフィ。\nアイコンは修羅さん(@lethaelweapon_7)から',
#  '旅行☆食べ歩き☆ものまね☆各種イベントプロデュースもしてます☆長渕勇次バンドのイベントプロデュースしてます🎼🎸',
#  '人生で大事なことは、おもいでエマノンとドカベンと宇宙戦艦ヤマトとエリア88と夏への扉と三匹が斬る！と戦車道に教えられた時、イデが発動した。のかもしれない。フィールド・オブ・ドリームス なんとなくローカルスポーツ、野球独立リーグ応援 観音寺 #yuyuyu もちょっぴり応援',
#  'mais改め少油になりました。激しめのオタクしてます。 広く浅く時々深くがモットーです。とっくのとうに成人済み😉',
#  '観劇や美術鑑賞、雑貨屋巡りが好き。モノ作りが好きなのでチマチマ色々やってます。  スパイス料理は勉強中。★情報収集をメインに使用していますので一方的にフォローしたりしますが、相互フォローは不要です。★',
#  'グラサンに思考をぐちゃぐちゃにされた系大神。趣味はアメコミからソシャゲまて手広く。fortniteクラン【NTKG】にゆる〜く所属中。いいね欄は魔窟。たまに描く絵は堀越先生の影響があるかも知れない',
#  'ウマ娘チーム競技場class5～6、スパロボV、DQ1',
#  '最近はFGO、プリコネ、アリスギアを遊んでることが多いです。 プラモは積んでますけど、作ってもいますよ？\u3000なおじさんです。',
#  '努力した者が全て報われるとは限らない。しかし成功した者は皆すべからく努力している。',
#  "Hi. I'm BOW. Everyone called me 'BOsu' :))",
#  'モンスト/maimai/ラーメン大好き/ススギ カプチーノ乗り 白/',
#  'ｽｷ:るーみっく、NISIOISIN、マギ、ヘタリア、堀宮。RADWIMPS、Owl City、GARNET CROW、ナノ。手ブロ厨。慢心しては駄目。好物は球磨型軽巡二番艦と伊達組。与えると悶えます。',
#  '20歳over アニメ ゲーム絵や成年絵🔞やVtuberなど描いています\n大人になってから絵描き始めたSEです✋\n絵描きさん応援傾向👍絵描きさんなら交流して良いとこ褒め合いましょう☺️\n絵柄とか気に入ってもらえたらフォローなど絡んでください😇\n絵利用はDMでご相談ください 依頼は休止中です\nプリコネ始めました😊',
#  '【2016/2/7 Start!】アメショ諸々MIX♂ギン(2002/05/20生)と保護猫茶トラ♀チャコ(2015/08/15生)･2019/8/7 保護♂つくね(2019/7/7生)･2020/6/21保護♀ミー子の4匹の猫の日常など。かなりマイペース更新。\nイラストは全部、自分で描いてます。',
#  '⚡︎お取引兼日常⚡︎',
#  'ㅤㅤㅤㅤㅤㅤㅤㅤ',
#  '●水玉ベース弾いてます●アイコンは自分のベースがモデルです●その他ご依頼等はDMまで',
#  "Q'ulle/さユり/やっこ/manaco 日常的な事やアニメの事も呟きます。Twitterでも人見知りしてしまいますが、話しかけてくれると喜びます。みゆはんと大石昌良さんも好きです。",
#  'infini Nexusメンバー/かのかり/ごちうさ/【水原千鶴を推す会N o. 78(会長代行)】/【かのかり同盟 No. 257】おすすめのアニメとか色々教えてください！加工練習中/ホロライブ好き/※ロリコンです(｡_｡*)エンカなどはDMまで〜/ヘッダー＆師匠@kameh_pad/',
#  '『えくぼは恋のおとしあな！ひまわりの妖精だいきちです！みんなのハートをバッキューん♡』推しマは🌻コンパスよく遊んでます！ボイちゃん足9クール9ソーンくん足8剣8/ミラティブ毎日配信中！毎週月曜はカラオケ🎤/ヘッダーとアイコンは甘党さん！(@082_mgmg_)',
#  'deep in paint,anime #bjyx #博君一肖 #EXOL #Kadi do not edit / repost /use my artworks',
#  nan,
#  '川崎在住のソフトエンジニアです。趣味で山登りします。百名山達成、厳冬期赤岳、西穂to奥穂、読売新道、キナバル登頂、キリマンジャロ登頂です。楽しく山に登りたいです。',
#  'KeNCHImiNと申します！\nDTMにてBGM制作を行っています！YouTubeで楽曲ご視聴いただけます。\n日々の音楽に関するつぶやきを更新していきます♪\n\ninstagram⇒https://t.co/LMA8zhgrzy…\n\nブログ⇒https://t.co/qDNhE221PT',
#  'ひろみちゃんねる・MINT SPEC・Seiraのファンですが宜しく',
#  'Dancemania, Koichi Shibata / Quiqman, DDR, Music',
#  'はっぴーあらうんど！\n最近新しくゲーム始めました(｀・ω・´)ｷﾘｯ\nD4DJメイン。プロセカは合間にプレイ\nD4DJ、ハピアラ、りんく推し\nプロセカ、25時ナイトコード、奏推し',
#  '漫画家。作業のお供はゲーム実況。ゲームするのも好き。APEXにお熱。どうぞよろしく。',
#  '自由に生きてる青いクマ',
#  '弾き語り小学生kieRa☀️10歳☀️夢はギタリスト☀️青森ギター少女☀️ライブ出演☀️ストリートライブ☀️ブルースセッション☀️\n師→ackie(AMR)&青森ギタリスト達☀基本ツイートは管理人(@lucky_stars_4)がします☀️ⓚはkieRaコメント☀️YouTube『kieRa music』',
#  '自称：クリエイティブ系サービス業。釣りと料理とMacとアニメとドラマと漫画と映画と夢枕獏の本。音楽はアジカンとスピッツとフジファブとバンプと岡村靖幸と平沢進etc...アイコンは島本和彦先生の作品中に登場した私。片渕須直監督作品、そして片渕監督次回作へ超期待！',
#  '20⬆︎ タイ人🇹🇭|⚠️たくさんRT⚠️| 夢女子💭| re! • 🦈,XS,スク夢 | ナルト • カカシ | 金カム • 尾形 | ピスメ• 沖田🍡| ヴィンサガ • アシェラッド⚔️| 刀剣乱舞🌸| ヘタリア🌍| Dグレ• 神田 | ツイステ•🦁💀🏹👑 | 黒バス • 氷❄️,紫💜',
#  '◆公式HP\nhttps://t.co/6UChgyffyC\n\n◆DVD、公演グッズ\nhttps://t.co/pSnoUBnbkS\n\n◆劇団ブログ\nhttps://t.co/LKIpbcCAaP',
#  'ぐるに帰依します🧸\n水気のあるところだと\n少し元気を取り戻す\nたぶん',
#  '最近はプロセカやってます/ワンダショにお熱/最推しは司',
#  '愛知県︎✈︎ 北海道/ mimorian / @mimori_suzuko / 酪農学園大学:循環農学類 /ラミ助、麦さんずっとLOVE / 学類クラス D1 基礎演習 農類18 健土健民班 2班',
#  '声優です。スマイルお届け屋。サバイバー。【最近の出演 / #ちびっこバスタヨ ビリー、パット / チビ列車 #ティティポ テオ、エリック、フィックス / #りぼんチャンネル / #BLスキップ】横須賀と海とお酒が好き。映像や舞台、ライブも稀に。スタ録 or 宅録はHPより、DMはお仕事のみ、私用はLINEへ♫',
#  '楽しくゲームしていく。',
# ...
#  'キメツ以外にもヒプ、金カム、鬼灯等他ジャンルもいいねします。\n無言フォローします、すいません。\n最近は、呪術にもハマり中。\n\n成人済 夢 腐 百合何でもOK\n地雷特になし',
#  nan,
#  '学校行くまでに俺羽生えてたわ(汗)',
#  'おっぱいとかわいい女の子が大好き\u3000仮面ライダー好きなラクガキ屋\n\n\n\n※下ネタも含むので18歳以下は、注意してください\n\n\n\nhttps://t.co/67ryFXy9XX',
#  '忘れられない いまさらを 胸にしまい込んで。',
#  '特にないです\n１８歳以上ではあります',
#  '主に黒猫でその他色々。黒猫はミルドレッドとリフィルとリレイが推し。素敵なアイコンとヘッダーはたてちゃん(@tateko25wiz)からいただきました！',
#  'ダーツ、酒、ゲーム、アニメが大好き😁',
#  'コロナ禍では御座いますが今入店頂けると\nとてつもなくお得な特典が御座います！！\n\n体験日から1週間\n100％バックキャンペーン！\n\n働いたら働いた分全額貰えます。\n\nこんなチャンス滅多にないの\nでこの機会に体験しませんか？',
#  'TWIN PLANET 所属｜DREAMING MONSTER（ドリモン）｜１期生｜水色担当｜貴方の永遠の姫｜元医療事務｜アニメ大好き→特に #アイカツ #プリパラ｜まぜる〜むcafé出勤｜インスタ→ayano_hime1101｜TikTok →ayano_dm｜REALITY(Vtuber)→ひめちゃん',
#  '🇯🇵大好き\n用盡全力自言自語',
#  '大学生🏄\u200d♀️ ： 文ス鬼滅呪メインの雑多垢 ： ウルトラ遅筆芸人です ： 呪本誌派 ： ネタバレはふせったーに',
#  '『来栖翔だ！』シキです！（翔ちゃんになりきってみたりしてます。）無言フォローごめんっ！(^_^;)\n(sikileonidの垢も作ったので良かったらフォローしてください！)\n声真似始めました🎵\n#シキカラオケ←このタグをつけてカラオケで歌ったのを公開してますので良かったら観てね！#シキセリフ',
#  'ただのみぃタは今日も元気🎵\n\nみんなオラに力をありがとう。\n\n結婚したい。\n幸せになりたい。\n\n\n\n↓欲しい物リスト',
#  '#ウェディングプランナー #千葉┃ルーティンワークで創られる結婚式を見て愕然。そんな現状を変えるべく業界へ┃趣味: #ブレイクダンス #ピアノ #読書┃見学前後どちらでもご結婚関連のフリー相談は下記URLのLINEからどうぞ😊 #結婚式 #ウェディング',
#  '2次元メインのリツイーター。\n良いものは良いのだ。\n※無言RT/フォロー/リストINが嫌だったら解除するのでDMください。\n※ミュートorRT非表示推奨',
#  '北関東一人住まい！\u3000日々思ったことを独断と偏見で呟いています。また、一緒に温泉などに行ってくださる方も募集中！刺激のある生活がしてみたい…',
#  '#プロセカ  #プロセカ好きさんと繋がりたい \nプロセカ大好き！よければ繋がりませんか？\nリアリティっていう配信サイトで不定期配信してます。\n\n【お別れはブロ解で】',
#  '●バイク好き\u3000●スノボ好き\u3000●アニメ好き\u3000●エロい事好き\u3000',
#  '絵を描くのが好きな者です。५✍⋆* .☆.｡.♪。.:＊・゜シャーペン画鉛筆画多め',
#  '姉さんしか勝たんだろ? 💍🐥リアル俺の🐣«@VII_Hiyoko» 👼🏼可愛い妹❤️«@Vll_Sakucya» 🍑ぼっち🍑«@Mbs_MoMotaro» ෴眉毛族෴«@TA_suke10» 🥔ポテチ連合🥔«@ZK_0717» 🍵お茶🍃«@Amacyax8»',
#  nan,
#  'ほぼ閲覧垢/歌い手/YouTuber/美容/20↑25↓',
#  '介護事業所事務員。時々絵描きます。時々LINEスタンプ作ってます。Abemaよく観ます。ひろゆきに感銘してます。日本大好きです。フォロー大歓迎。',
#  '日々のささやかなアクセントになるアクセサリーを貴方の掌へ•°✻ 一次創作物タグ➪#ExlÜte/二次創作物タグ➪#Fünmadë / 📷➪OLYMPUS PEN / アイコン➫momochy様(@momochy_)より',
#  '●マキノ・美優さん・しきにゃん担当\n★3人でオリジナルユニット「Lilium-M」を結成しました★つかさ💕美紗希💕ちとせ💕\nミリシタ→可憐担当。紬💕瑞希💕志保💕静香は訳あって特別🍀シャニ→咲耶💕恋鐘💕M→桜庭💕まいたる💕●CUE!→Moon推しのエリス(利恵)マネ',
#  'バイク乗り兼vtuber好きです！最推しは姫熊りぼんさんです！好きなものは好きとつぶやく垢です！宜しくお願いします！',
#  '素晴らしき哉、人生！（窓から飛び降りる',
#  '成人済み腐。鬼滅→煉炭、炭煉、富岡、おばみつ（基本箱推し）。聖闘士星矢Saint Seiya→無印黄金、ムウ様最愛。デザフェス、ハーメルンも。boothで黄金聖闘士モチーフの12星座宝石制作販売中。透明で光るものが好き 業者垢はブロック',
#  '血糖値を安定させるために毎日自転車かウォーキングをしています。\r\n株とFXで生活の糧にしていて\r\n毎日のんびりと過ごしています。\r\n声優が大好き、現在は洲崎西押し。\r\n阪神ファン。',
#  'エコタウン仙台荒井店オフハウスの公式アカウント誕生しました！これから、情報発信していく予定ですのでお楽しみに！ 宮城県仙台市若林区荒井一丁目10-12 TEL:022-794-9923\n#オフハウス ＃ハードオフ',
#  'しょうです。\n好き:ツインテ 色素薄い髪色\n人外好き ロボもケモノもデジモンもポケモンもモンスターも。\n女の子キャラが好きな事が多い成人済み腐女子である筈の人間モドキ\n啓蒙は捨てていこうな\nhttps://t.co/y3cVaObnue',
#  'คุยได้คับไม่กัด🥺multifandom SVT FREE! AOT HQ MHA BSD Tsurune Yaiba หมอหิน jjk มรอต twst',
#  'Add a bio to your profile',
#  '自称魔法使いの成人です。',
#  '#thirtynovupdate | #reviewthirtynov Status Order☟︎',
#  'ゲームアプリと日常の呟きが殆ど、ツイートは少なめですのでご了承下さい。趣味は猫の頭の匂いを嗅ぐ事であるが、猫アレルギーなので犬の頭で我慢している。',
#  "🌃𝟖𝟎'𝒔 𝑱𝒂𝒑𝒂𝒏𝒆𝒔𝒆 𝑪𝒊𝒕𝒚 𝒑𝒐𝒑🌃\u3000\u3000\u3000\u3000\u3000洋楽、邦楽、杉山清貴😎、竹内まりや、あぶ刑事等。E46 ALPINA B3 3.3、RB1、たまにFK7 @874RS ←パパ 紳士でありたいとトイレから呟くアカウント。",
#  '主にお取引垢ではありますが普通に呟く時もあるので仲良くしてくれたら嬉しいです\U0001f90d🕊■□▪▫■□クオズ🐥🐯',
#  '犬、猫やドラマやアニメの感想など興味あるもののことをひっそりつぶやいてます。かなり偏りがあります。成人済20↑腐 アイコンは今の推し',
#  '🔥柱好きすぎてつらい耐えられない\n虹創作を愛でる用アカ\n無断でフォローしています、コミュ障です、ごめんなさい カプ固定なし ものすごく雑食 今はほぼ鬼滅\n\nとっくの昔に成人済',
#  'ガンプラと猫が好きです。 よろしくお願いします。また ワルキューレが 好きです❗️安野家ファンクラブとじゅんな６くみファンクラブに 入会してます。 また 小松未可子さんの 大ファンです。西田望見さん(のぞみる)＆マキナ・中島ちゃんの 大ファンです。Ｍ魂会員 5年目です。',
#  '小学2年生娘と12歳愛犬子育て中のナースやってるママです❗音楽 ♬ とドライブ🚘とアイス🍦とお酒🍺と海🏖️と空🌈とディズニーとスヌーピーと楽しい話が大好きです❤️iPhoneで写真練習中📸      おうちご飯も気まぐれでアップします🍳',
#  '青森県在住のChappyです。男の子2人のママで、愛猫２頭飼っています。現在子育てで余裕がなく飼い猫を増やせませんが、かわいそうな猫達を１匹でも助けたいため無言フォロー、ツイートします。動物虐待反対！殺処分ゼロを目指します。動物、環境に優しい国にしたい。ねぶた祭り、青森大好きです。',
#  '一日三食五十品目！！わたしったら最強ね！バナナと乳製品を同時にとると脳が活性化するんですって。そして手うがは大切よね。たまに名乗りを変えるけど、かならず⑨が入るわね。ドジっ子とか落ち着き無いってよく言われるよ。戦車道は乙女のたしなみ。アイコンは蒼き艦隊ヒュウガさん。',
#  'マチカネタンホイザしか勝たん。プログノーシス、グレナディアガーズ、マルターズディオサ、ホウオウイクセル、ダイワクンナナ。プロスピ広島純正。第24回最強決定戦オリックス3位。',
#  nan,
#  'おさむ兄＆ゆう子姉育ち、ただの元おたく。ゆるっと男子二人くらい育てながらゆるっと働きマン ずっと好き：松澤由美/奥村愛子/高瀬綾/早稲田ちえ/ウレロ☆/戦国鍋/深夜ラジオ etc',
#  ...]

# %%
import subprocess
cmd='echo `mecab-config --dicdir`"/mecab-ipadic-neologd"'
path_neologd = (subprocess.Popen(cmd, stdout=subprocess.PIPE,
                           shell=True).communicate()[0]).decode('utf-8')
import MeCab
m=MeCab.Tagger("-Ochasen -d "+str(path_neologd))


def neolog_prep_text( text):
  return_words = []
  splited_text = (re.split('[\t,]', line) for line in m.parse(text).split('\n'))
  for tmp_word in splited_text :
    if (tmp_word[0] in ('EOS', '', 't', 'ー') ):
       continue 
    if not re.match( '名詞' ,tmp_word[3]  ) or tmp_word[0] in emoji.UNICODE_EMOJI["en"]:
      continue
    else:
      return_words.append(tmp_word[0])

  return return_words

# %% [markdown]
# * tokenizationの実行

# %%
from tqdm import tqdm

new_docs = list()
for doc in tqdm(docs):
  if str(doc) == "nan":
    continue
  tmp_words =  neolog_prep_text(str(doc))
  new_docs.append( tmp_words )
# Out:
# 100%|██████████| 93794/93794 [00:23<00:00, 3977.10it/s]

# %% [markdown]
# * tokenizationの結果を確認

# %%
print(new_docs[5])
# Out:
# ['過去', 'ジャパリカート', '動画', 'TSUMURI', 'KART', 'VRChat', 'ワリスノ', 'MK', '8', 'DX', '一位', 'りし', 'た人', '社会', '出て', '配信', 'https', 'co', 'FJoitl', '8', 'JHE', 'ヘッダ', '猫', '飼い主', 'smmmmm']

# %% [markdown]
# * 各文書を長い文字列で表しなおす（CountVectorizerを後で使うため）

# %%
corpus = [' '.join(doc) for doc in new_docs]

# %%
new_docs
# Out:
# [['漫画',
#   'アニメ',
#   '声優',
#   '垢',
#   'RT',
#   '多め',
#   '気まま',
#   '伏線',
#   '系',
#   '漫画',
#   '好き',
#   '古川慎',
#   'さん',
#   '小林裕介',
#   'さん',
#   '河西健吾',
#   'さん',
#   '田丸篤志',
#   'さん'],
#  ['D',
#   '垢',
#   'プリンセス',
#   'たま',
#   'もの',
#   '手遅',
#   'め',
#   'よろしくお願いします',
#   '名前',
#   '読み方',
#   '自由',
#   '好き',
#   'よう',
#   '最近',
#   '浮上',
#   '別',
#   '絵',
#   '垢',
#   'ri',
#   'ri',
#   'ri',
#   'ri',
#   'on'],
#  ['アララカタブラツルリンコｫォォオ', '₊'],
#  ['ENHYPEN', 'アニメ', '漫画', 'ゲーム', '関連', 'Twitter', 'それ', '以外', '反応'],
#  ['心',
#   'ゆとり',
#   '潤い',
#   'の',
#   '学校',
#   '保健室',
#   'よう',
#   '場所',
#   '一息',
#   '場所',
#   'あなた',
#   '幸せ',
#   '職業',
#   '音楽',
#   '講師',
#   '自分磨き',
#   '中',
#   '自分',
#   'ため',
#   'ツイート',
#   '事',
#   'ドジ',
#   '有り',
#   '2',
#   '匹',
#   '4',
#   '匹'],
#  ['過去',
#   'ジャパリカート',
#   '動画',
#   'TSUMURI',
#   'KART',
#   'VRChat',
#   'ワリスノ',
#   'MK',
#   '8',
#   'DX',
#   '一位',
#   'りし',
#   'た人',
#   '社会',
#   '出て',
#   '配信',
#   'https',
#   'co',
#   'FJoitl',
#   '8',
#   'JHE',
#   'ヘッダ',
#   '猫',
#   '飼い主',
#   'smmmmm'],
#  ['主', '雑多', '垢', '成人', '20', 'ic', '自作', 'hd', 'kmtmiu', '様', 'フリーヘッダー'],
#  ['18', '夢追翔', '伏見', 'ガク', 'ガオン', 'くん', '応援', 'アカウント', 'アークナイツ', 'dbd'],
#  ['スコティッシュ',
#   '猫',
#   'アンジェレッタ',
#   '2011',
#   '06',
#   '01',
#   '生れ',
#   '女の子',
#   '毎日',
#   '猫',
#   '生活',
#   '好き',
#   '猫',
#   '動物',
#   '爬虫類',
#   '塊根植物',
#   '藤原竜也',
#   'ﾏﾝｶﾞ・ｱﾆﾒ',
#   '大友克洋',
#   'ＡＫＩＲＡ',
#   '萩尾望都',
#   'せがわまさき',
#   '近藤',
#   '片岡',
#   'コンビ',
#   '羽海野チカ',
#   'ベルセルク',
#   'ヒグチユウコ',
#   'リラックマ',
#   '沖縄'],
#  ['98',
#   'line',
#   'こ',
#   'ｻﾝ',
#   '堀',
#   'ｻﾝ',
#   '健',
#   'ｻﾝ',
#   'all',
#   'LDHall',
#   'love',
#   '陸',
#   'ｸﾝ',
#   'all',
#   'チーム',
#   'NEXT',
#   'ジェネ',
#   'ランペ',
#   'ファンタ',
#   '固定',
#   'ツイ',
#   'rt',
#   'いいね',
#   'お願い',
#   '好きな物',
#   '多め',
#   '注意報',
#   '田中',
#   '氏',
#   'all',
#   'スト',
#   'teamSixTONES',
#   '介護福祉'],
#  ['21年',
#   '毎日',
#   '更新',
#   'ブロガー',
#   '写真',
#   '撮影',
#   'カメ',
#   'ライター',
#   'Amazon Kindle',
#   '100',
#   '冊',
#   '以上',
#   '出版',
#   '好き',
#   '仕事',
#   '大人',
#   '塾',
#   'かさこ',
#   '塾',
#   '塾長',
#   'ツイッター',
#   'マニュアル',
#   '特典',
#   '付',
#   'ネット',
#   '発信',
#   'セミナー',
#   'Kindle',
#   '活用',
#   'セミナー',
#   'ミスチル',
#   '旅行',
#   '川越高校',
#   'Youtube',
#   '毎日',
#   'https',
#   'co',
#   'FFR',
#   '43m',
#   'uMhU'],
#  ['フリーランス',
#   '大阪',
#   '中心',
#   '活動',
#   'デザイナー',
#   'イラストレーター',
#   'TAYAMA',
#   'KENICHI',
#   'バンドマン',
#   '大手',
#   '飲食',
#   'チェーン',
#   'デザイン',
#   '経験',
#   'お仕事',
#   'DM'],
#  ['芸',
#   '11期',
#   '美術科',
#   '日本画',
#   '専攻',
#   '高校２年生',
#   '模写',
#   'オリジナル',
#   'デッサン',
#   '将来',
#   '夢',
#   'フロム・ソフトウェア',
#   'デザイナー',
#   '日々',
#   'お絵描き',
#   '練習',
#   '中',
#   '太鼓の達人',
#   'フルコン',
#   '動画',
#   'たま',
#   'ブルー',
#   '名人',
#   'ヘッダー',
#   '画像',
#   'ボク',
#   '絵',
#   '一部',
#   '動画',
#   'こちら'],
#  ['人間', '信用', '性', 'さ'],
#  ['かに', 'ｶﾆﾁｬﾝ'],
#  ['スヌーピー',
#   '好き',
#   '犬',
#   '派',
#   '1番',
#   '分ち',
#   '犬',
#   'TBN',
#   'web',
#   '配信',
#   'リスナー',
#   'ラジオネーム',
#   '緑茶',
#   '大好き',
#   '茶柱',
#   'りょくちゃ',
#   '変更',
#   'HS',
#   'ブログ',
#   'の',
#   '楽しみ',
#   '林原めぐみ',
#   'さん',
#   'ファン',
#   '好き',
#   '小説',
#   'スレイヤーズ・コラボゲーム',
#   'ファンリビ',
#   '果物',
#   '系',
#   '緑茶',
#   '中'],
#  ['残念',
#   '人',
#   '成人',
#   '済',
#   '興奮',
#   '下ネタ',
#   '注意',
#   '銀魂',
#   '沖',
#   '土',
#   'T',
#   'B',
#   '兎',
#   '虎',
#   '兎',
#   '男',
#   '日',
#   'モト',
#   '唐',
#   'モト',
#   '黒バス',
#   '黄',
#   '笠',
#   '黒',
#   '火',
#   '進撃',
#   'エレリ',
#   'リヴァ',
#   'エル',
#   '刀',
#   'みかん',
#   '燭',
#   'いち',
#   'つる'],
#  ['庄原',
#   '2018',
#   '5',
#   '12',
#   'ライブ',
#   'セカオワ',
#   'カープファン',
#   'ONE PIECE',
#   '好き',
#   '戦隊',
#   '仮面ライダー',
#   'ASD',
#   'B'],
#  ['げる',
#   'ガルパ',
#   'APEX',
#   '別れ',
#   'ブロ',
#   '解',
#   'アニメ',
#   'ゲーム',
#   '好き',
#   '既読',
#   '感覚',
#   'いいね',
#   '通知',
#   'ON',
#   '推奨',
#   'gerugeru',
#   '1218',
#   'サブ垢',
#   '人'],
#  ['爬虫類系',
#   'YouTuber',
#   'アラサー',
#   'アリプロ',
#   'etc',
#   '現役',
#   '厨',
#   '二',
#   '16年前',
#   '独楽',
#   '漫画',
#   '赤毛',
#   'キャラ',
#   '人生',
#   '地雷',
#   '地雷',
#   '奴',
#   '地雷'],
#  ['AI',
#   'システム',
#   '科',
#   '1',
#   '組',
#   'ポケモン',
#   'ラブライブ',
#   'オルガル',
#   '等',
#   'ゲーム',
#   '好き',
#   '陰キャ',
#   'ヲタク',
#   '日常',
#   '垢',
#   '春',
#   '日本',
#   '校',
#   '学院',
#   'AI',
#   'システム',
#   '科',
#   '春',
#   '日本工学院',
#   '#ラブライブ',
#   'ポケモン',
#   'オルタナティブガールズ',
#   'https',
#   'co',
#   'gv',
#   '3q',
#   'isSFxq'],
#  ['カクヨム',
#   'マグネット',
#   '文体',
#   '軽',
#   'め',
#   '小説',
#   '暇',
#   'とき',
#   '感謝',
#   '小説家になろう',
#   'https',
#   'co',
#   'm',
#   '5g',
#   '1',
#   'Z',
#   '7',
#   'QKZH',
#   'カクヨム',
#   'https',
#   'co',
#   'zzkalYriZU',
#   '無言',
#   'フォロー',
#   '失礼'],
#  ['椛',
#   'クラスタ',
#   '多方面',
#   'クソリプ',
#   '型',
#   '特攻兵器',
#   'お祭り',
#   '野郎',
#   'TRPG',
#   'ベイブレード',
#   '野良',
#   '売り子',
#   'アイコン',
#   'はふ',
#   'ぇのめにょもけさん',
#   'monyomoke',
#   'さん',
#   'https',
#   'co',
#   'dG',
#   '1',
#   'aDtgx',
#   '56'],
#  ['錆兎',
#   'さん',
#   'チャンネル',
#   'チョコ',
#   'ゅ',
#   '気軽',
#   'アイコン',
#   'mimicha',
#   'zzz',
#   'みみ',
#   'たん',
#   'ヘッダー',
#   'SiN',
#   '190609',
#   'シン',
#   'さん'],
#  ['8', 'enz', '0', 'ぞうと', '2020', '12', '28', 'Youtube'],
#  ['お絵描き', 'おじさん', '2児', '父'],
#  ['Just',
#   'see',
#   'tweets',
#   'everything',
#   'My',
#   'world',
#   'is',
#   'my',
#   'world',
#   'but',
#   'you',
#   'can',
#   'come',
#   'in',
#   'if',
#   'you',
#   'honor',
#   'each',
#   'other'],
#  ['ゲーム',
#   'ミラジーノ',
#   '好き',
#   'クサガメ',
#   '世話',
#   '係',
#   'RT',
#   'いいね',
#   '最近',
#   '鬼',
#   '滅',
#   '呪術',
#   'ウマ娘',
#   'FF14',
#   '水柱',
#   '夏',
#   '油',
#   '中の人'],
#  ['キャラコス',
#   'ピアノ',
#   '即興',
#   '演奏',
#   'フォロー',
#   '友好的',
#   'コメ',
#   'いいね',
#   'RT',
#   'お迎え',
#   '鬼',
#   '滅',
#   'FGO',
#   'エヴァ',
#   'セラムン',
#   '炎炎',
#   'ネバ',
#   'SAO',
#   '凪',
#   'あす',
#   '空の境界',
#   '銀魂',
#   '文豪',
#   'グラブル',
#   '夏目',
#   'ジブリ',
#   'るろ剣',
#   '愛猫',
#   'ノルウェー',
#   'ジャン',
#   'ピアノ',
#   '奏者',
#   '経営者',
#   '教育者',
#   '即興',
#   '作曲',
#   '酒',
#   '肉',
#   '蛤',
#   '鰻',
#   '猫',
#   '大好き'],
#  ['映画', '感想', 'プラモデル', 'アカウント', '映画', '感想', 'プラモデル', '時', 'アカウント'],
#  ['音楽', 'お酒', '塩顔', '男', '好き'],
#  ['成人',
#   '済',
#   'なん',
#   '方',
#   '向け',
#   '通知',
#   'off',
#   'たま',
#   '絵',
#   'フォロー',
#   '前',
#   '必読',
#   'https',
#   'co',
#   'WDqPcbj',
#   '5',
#   'kq',
#   'Repost',
#   'is',
#   'prohibit',
#   'ed',
#   '転載禁止'],
#  ['北海道',
#   '北陸',
#   '愛知県民',
#   '痛車',
#   '大好きな人',
#   'GD',
#   '２',
#   '天体のメソッド',
#   '仕様',
#   'ラブライブ',
#   '痛',
#   '車',
#   '乗り',
#   'ほの',
#   '仕様',
#   'フィット',
#   'GE',
#   '8',
#   'ミラカスタム',
#   '島田愛里寿',
#   '仕様',
#   'ドール',
#   'オーナー',
#   'ラス',
#   'フォロー',
#   'フォロー',
#   '気軽'],
#  ['趣味',
#   '用',
#   '好き',
#   'モノ',
#   '好き',
#   'よう',
#   '鬼滅の刃',
#   'Dr.STONE',
#   '約束のネバーランド',
#   '大変',
#   'こと'],
#  ['仮面女子',
#   'アリス十番',
#   'アーマーガールズ',
#   'チェリーブロッサム',
#   '肉汁',
#   'ガールズ',
#   'ぱー研!',
#   'スライムガールズ',
#   '八重歯',
#   '楠木',
#   'まゆ',
#   '卒業',
#   '芸能活動',
#   '引退',
#   '済',
#   'mau',
#   '1013',
#   'サッカードイツ代表',
#   '闘将',
#   'ローター・マテウス',
#   '氏',
#   '尊敬'],
#  ['ゆず',
#   'ゆず',
#   'くん',
#   '好き',
#   '専門学生',
#   '介護福祉学科',
#   '寮',
#   '人',
#   'いいね',
#   '荒野行動',
#   'global',
#   '民',
#   'アニメ',
#   '漫画',
#   '好き',
#   '将棋ウォーズ',
#   '２',
#   '級',
#   'プロセカ',
#   '稀',
#   'とき',
#   '()',
#   'マ',
#   'アイコン',
#   'ALkXEu',
#   '229',
#   'pq',
#   '1',
#   'EKQ'],
#  ['成人',
#   '済み',
#   '一般人',
#   '兼',
#   'オタク',
#   '兼',
#   '腐女子',
#   '12',
#   'y',
#   'TW',
#   'JP',
#   'EN',
#   'Vegetarian'],
#  ['特',
#   'オタ',
#   'ロボオタ',
#   '80年代',
#   'ジャンプオタ',
#   'おっさん',
#   'その昔',
#   'ロックスター',
#   '歌',
#   '係',
#   'クウガ',
#   '響鬼',
#   'ガンダム',
#   'サンライズ',
#   '作品',
#   '聖闘士星矢',
#   '好物',
#   '職業',
#   '会社',
#   '経営',
#   '目標',
#   '経営者',
#   '竹尾ワッ太'],
#  ['98', 'line'],
#  ['平針',
#   '名',
#   '栄',
#   '鳴海',
#   '大曽根',
#   '千種',
#   'YouTube',
#   '活動',
#   '3人',
#   '流行',
#   'イラスト',
#   'お送り',
#   '是非',
#   '遊び'],
#  ['愛知', 'apex', 'ガンダム', 'グラブル', 'vs', 'その他', 'イラスト', 'RT', '結目', 'ユイ', 'おたく'],
#  ['ジョジョ', '好き', 'GNCT', '卒業生', '好き', 'ソシャゲ', 'FGO', '呪術廻戦', '新巻', '奴', 'すき'],
#  ['寝ても覚めても',
#   '徳島ヴォルティス',
#   '大好き',
#   'サポーター',
#   '歴',
#   '１',
#   '7年目',
#   '１',
#   '定着',
#   '中年',
#   'おっさん',
#   '情熱',
#   '気軽',
#   '声',
#   '浜下瑛'],
#  ['一人娘',
#   'め',
#   '母',
#   'こと',
#   '親子',
#   '鬼滅の刃',
#   '母',
#   '実弥',
#   '娘',
#   '善',
#   '逸',
#   'くん',
#   '伊黒',
#   'さん',
#   '家族',
#   '柴犬',
#   '海',
#   'カイ',
#   '袋井市',
#   '芝',
#   '田荘',
#   '出身'],
#  ['声優さん', 'イベント', '感想', 'ごちうさ', 'シャロ', 'アイマス', '蘭子', '楓', '琴葉', 'ウマ娘', 'ゴルシ'],
#  ['鬼滅の刃',
#   '時透無一郎',
#   'くん',
#   '頭',
#   '全て',
#   '無言',
#   'フォロー',
#   'タメ',
#   '歓迎',
#   '気軽',
#   '鬼',
#   '滅',
#   '垢',
#   '基本',
#   'フォロバ',
#   '同盟',
#   'le',
#   'ciel',
#   'hyde'],
#  ['さぬき',
#   '5人',
#   '格',
#   'ツイステ',
#   'とうらぶ',
#   '鬼',
#   '滅',
#   '呪術',
#   'Sky',
#   'お絵描き',
#   'Nekosaki',
#   'Alice',
#   '夢',
#   '垢',
#   '無言',
#   'フォロー',
#   '失礼',
#   'OIMYK',
#   '1124'],
#  ['GOOD', 'MORNING', 'GOODNIGHT', 'HAPPY BIRTHDAY'],
#  ['趣味',
#   'やおい',
#   '日常',
#   'メイン',
#   'たま',
#   '二次創作',
#   'ツイフィ',
#   '目通し',
#   '推奨',
#   '昭和',
#   '末期',
#   '生まれ',
#   '番組',
#   '実況',
#   '有'],
#  ['スピリチュアル',
#   '系',
#   '歴史',
#   '系',
#   '物書き',
#   '風吹',
#   'づる',
#   'エロ',
#   '系',
#   '槌屋',
#   'ほむら',
#   'ヒーラー',
#   '建築',
#   '設計',
#   '屋',
#   'さん',
#   'おまけ'],
#  ['カラー',
#   '声',
#   '真似',
#   '動画',
#   '趣味',
#   'Like',
#   'FGO',
#   '特撮',
#   'プリキュア',
#   'メガテン',
#   '呪術',
#   'ウマ娘',
#   '時',
#   '声',
#   '真似',
#   '中',
#   '村',
#   '悠',
#   '一',
#   's',
#   '声',
#   '真似',
#   '兼',
#   'FGO',
#   '作品',
#   '他',
#   'キャラ',
#   '声',
#   '真似',
#   'トレーナー',
#   'ウマ娘',
#   'そ',
#   '中村',
#   'さん',
#   'キャラ',
#   '日々'],
#  ['オス',
#   'ネコ',
#   '全身',
#   '白色',
#   '頭',
#   'てっぺん',
#   '毛',
#   '色',
#   'ネコ',
#   'こと',
#   'の',
#   'の',
#   'しっぽ',
#   'リボン',
#   '包帯'],
#  ['3D',
#   'さくひん',
#   'ちーむ',
#   'Heart',
#   'F',
#   'clan',
#   'せん',
#   'GxxxxxxxU',
#   'Zeno',
#   'af',
#   'りすぺくと',
#   'BoBoBoBoin',
#   'n',
#   'toroch',
#   '2525',
#   'papico',
#   'デバイス',
#   'https',
#   'co',
#   'sULkcWgFRr',
#   'ふぁん'],
#  ['女子高生', '意思'],
#  ['歴史',
#   '好物',
#   'ゲーム',
#   '垢',
#   'たま',
#   '日常',
#   '無双',
#   'モンハン',
#   'APEX',
#   'fgo',
#   '原',
#   '神',
#   'etc.',
#   '無言',
#   'フォロー',
#   '失礼',
#   '大学生',
#   '18',
#   'caffeinenoboku',
#   '五',
#   'ツイステ',
#   'あん',
#   'スタ',
#   'ツイフィ',
#   'https',
#   'co',
#   'QHijO',
#   '4u',
#   '70',
#   'o'],
#  ['ましゅ',
#   'りえ',
#   '人',
#   '備忘録',
#   '地元',
#   '二宮町',
#   '山',
#   '海',
#   '大好き',
#   '人間',
#   '季節',
#   '海',
#   'シータヒーリング',
#   '印刷会社',
#   '勤め',
#   'デザイン',
#   '印刷',
#   '裁断',
#   'いま',
#   '台湾人',
#   '彼',
#   '遠距離恋愛',
#   '中'],
#  ['好き', '成人', '済み'],
#  ['映画',
#   '漫画',
#   '音楽',
#   'ｱﾆﾒ',
#   'ﾐｭｰｼﾞｶﾙ',
#   'お笑い',
#   'ｷﾒﾂ',
#   'YOI',
#   'T',
#   'B',
#   '商',
#   'DBH',
#   'BF',
#   'OL',
#   'ﾌﾟﾛﾒｱ',
#   'MHA',
#   'etc',
#   'CP',
#   '設定',
#   '基本',
#   '的',
#   '地雷',
#   '何',
#   '好き',
#   '無言',
#   'フォロー',
#   '30',
#   '現在',
#   'ヴィク',
#   '勇',
#   '炭',
#   '煉',
#   '狂',
#   '聡',
#   '勝'],
#  ['ここ',
#   '数年',
#   'ドール',
#   'オタク',
#   '貧乏人',
#   '成人',
#   '済',
#   'アニメ',
#   'ユーリ!!!on ICE',
#   'ド',
#   '中',
#   'イラスト',
#   '漫画',
#   'RT',
#   'ミュート',
#   '推奨'],
#  ['アニメ', '漫画', '垢', 'ғ'],
#  ['King&Prince', '廉', 'くん', '好き', '鬼滅の刃', 'お酒', '白米', '唐揚げ', 'ポテト', '好き'],
#  ['気', '絵', '投稿', '頻度', '少なめ', '煉獄', '18'],
#  ['介護士',
#   'アニメ',
#   'ゲーム',
#   'コスプレ',
#   '進撃の巨人',
#   '人生',
#   '教科書',
#   'エレン',
#   'りとる',
#   'さん',
#   '永遠',
#   '様'],
#  ['スマ',
#   '大好き',
#   '鬼滅の刃',
#   'ファンマ',
#   '解毒剤',
#   'めろん',
#   'ぱーかー',
#   '絵',
#   '世界',
#   '僕たち',
#   '約束',
#   'ん',
#   '所属',
#   'ひす'],
#  ['性',
#   '白津',
#   '名',
#   'ショーゴ',
#   '負け犬',
#   'ころし',
#   '11月',
#   '12月',
#   '松',
#   'ステ',
#   '1月',
#   '刀',
#   'ミュ',
#   'リボステ',
#   '2月',
#   '3月',
#   'F6',
#   'ライブ',
#   '4月',
#   '5月',
#   'デュラステ'],
#  ['兼業',
#   '作詞',
#   '家',
#   '御城',
#   '葡萄',
#   'GRAPE',
#   '塩ノ谷早耶香',
#   '雪空',
#   'NACK5',
#   'パワープレイ',
#   '昭和',
#   '男',
#   '名古屋',
#   '人',
#   'radiko',
#   'プレミアム',
#   '会員',
#   'Hello',
#   'guys',
#   'I',
#   'live',
#   'in',
#   'Nagoya',
#   'Japan',
#   "I'll",
#   'try',
#   'to',
#   'tweet',
#   'Japanese',
#   'life'],
#  ['KUN', 'キッズ', '陰キャ', 'コミュ障'],
#  ['multifandom', 'BTS', 'NCT', 'hypmic', 'KNY', 'Twst', 'Genshin', 'impact'],
#  ['クラ', '饅頭'],
#  ['声優',
#   '女優',
#   'MC',
#   '女性',
#   '2人',
#   '組',
#   'おもしろ',
#   'アラサーチャンネル',
#   'あららら',
#   'らら',
#   '劇場',
#   '休み',
#   '中'],
#  ['ぴぇこっていいます',
#   '銀魂',
#   '五等分の花嫁',
#   'ヒロアカ',
#   'かぐや様は告らせたい',
#   '好き',
#   'めちゃくちゃ',
#   '相方',
#   'くん',
#   'Drano',
#   'suke',
#   'ヘッダー',
#   'レパートリー'],
#  ['99%',
#   '事',
#   '投稿',
#   '内容',
#   '私',
#   '個人',
#   '意見',
#   '質問箱',
#   'endo',
#   'soudan',
#   'YouTubeCH',
#   'https',
#   'co',
#   'aAUz',
#   '8',
#   'LdHxN'],
#  ['俺',
#   'カワイ',
#   '韓',
#   '1月',
#   '12月',
#   '誕生日',
#   'ハッピー',
#   '生き物',
#   '肉',
#   '系',
#   'ヴィーガン',
#   'https',
#   'co',
#   '591',
#   'xSf',
#   '9',
#   'Cn',
#   '7'],
#  ['欅坂46',
#   '山崎',
#   '天',
#   '土生瑞穂',
#   '平手友梨奈',
#   '日向坂46',
#   '丹生明里',
#   '佐々木美玲',
#   '乃木坂46',
#   '佐藤楓',
#   '梅澤美波',
#   'すと',
#   'ぷり',
#   'くん',
#   'ｱﾆｦﾀ',
#   '07',
#   'LINE',
#   '交換',
#   'DM',
#   '返信'],
#  ['草花',
#   '散歩',
#   '音楽',
#   '綺麗',
#   '写真',
#   'ご飯',
#   'twitter',
#   '初心者',
#   'お願い',
#   '無言',
#   'フォロー',
#   '失礼'],
#  ['映画', 'アニメ', 'の', '好き', '最近', '洋画', '沼'],
#  ['Visual', 'Kei', 'Jrock', 'kpop', 'Bands', 'Anime', 'ω'],
#  ['私',
#   '白',
#   '鈴',
#   'くりん',
#   'ゲーム',
#   'ボイロ',
#   '大好き',
#   'スケベ',
#   '絵',
#   'RT',
#   'マン',
#   'たま',
#   '動画',
#   '投稿'],
#  ['Main', 'Xkun', '1026', 'Who', 'are', 'you'],
#  ['ヤンバルクイナ', '誕生日', 'ヤンバルクイナ', '発見', '命名', '日'],
#  ['ESP', 'ENG', 'Spoilers', 'Ahead'],
#  ['ストラト', '星人'],
#  ['キノコ',
#   '嫌い',
#   'トウカ',
#   '所属',
#   '大学生',
#   'アニメ',
#   'デュエルマスターズ',
#   'ポケモン',
#   'ゆずソフト',
#   'カラオケ',
#   '在原七海',
#   '一神教'],
#  ['宮野真守',
#   '激推し',
#   'マモクラ',
#   '仲間',
#   '募集',
#   '中',
#   '取り引き',
#   'ゆうちょ',
#   '対応',
#   '譲渡',
#   '交換',
#   '買い取り',
#   '経験',
#   '成人',
#   '済み'],
#  ['リトルトゥース', 'おひさま', '丹生', 'ちゃん'],
#  ['小学生',
#   '時',
#   'THE ALFEE',
#   '大好き',
#   '映画',
#   '好き',
#   'カメ止め',
#   'スペアク',
#   '最高',
#   'ただ今',
#   '鬼滅の刃',
#   '燕',
#   '党',
#   'リラックマ',
#   'もの',
#   '星',
#   'ビーズ手芸',
#   'もの',
#   '好き'],
#  ['最近', 'ウイイレ'],
#  ['トット',
#   'こ',
#   'ジエリッヒダンテ',
#   '大阪',
#   '27期',
#   '西',
#   '東',
#   '吉本',
#   '坂',
#   'ﾀﾀﾞﾁｬﾝﾋﾅﾀﾁｬﾝ',
#   'ﾅｵﾁｬﾝ',
#   'ﾃｯﾁｬﾝ'],
#  [],
#  ['ラブライブ',
#   '凛',
#   'ちゃん',
#   '丸ちゃん',
#   'バンドリ',
#   'banndori',
#   'saya',
#   'プロセカ',
#   'こはねちゃん',
#   '腐女子',
#   '流れ星',
#   'SPF',
#   'FPS',
#   'ガチ',
#   '初心者',
#   'AP',
#   'EX',
#   'ライズ',
#   'ヘッダー',
#   'リアトコ',
#   'ReaToko'],
#  ['二次',
#   'アカ',
#   '志崎樺音',
#   'さん',
#   '応援',
#   'のん',
#   'フィル',
#   'Roselia',
#   '人生',
#   'ハピアラ',
#   'ぉ',
#   '白金燐子',
#   'さん',
#   '渡',
#   '月',
#   '麗',
#   'さん',
#   'バンドリ',
#   'D4DJ',
#   '多め',
#   'アニメ',
#   'たま',
#   'パズドラ',
#   '今年',
#   '日本一'],
#  ['役者',
#   'たま',
#   '構成作家',
#   'まれ',
#   'イベント',
#   '広告',
#   'プランナー',
#   '商店街',
#   '広報',
#   '昔',
#   '余分',
#   '三',
#   '兄弟',
#   '糖分',
#   '5年前',
#   'ショッカー',
#   '部長',
#   '18年前',
#   '東京',
#   'モーターショー',
#   'CM',
#   'コンテスト',
#   'グラ',
#   '受賞',
#   '難し',
#   'い事',
#   '抜き',
#   'sas',
#   '応援団',
#   '会員',
#   '桑田佳祐',
#   'office',
#   'yamajam',
#   '代表取締役社長',
#   'そり',
#   '運営'],
#  ['釣り',
#   '今',
#   'ジギング',
#   '音楽',
#   'HM',
#   'HR',
#   '大好き',
#   '二',
#   '児',
#   '父',
#   '気持ち',
#   'バスケ',
#   '沼',
#   '片足',
#   '家族',
#   'スサノオマジック',
#   '応援',
#   '松江シティFC',
#   '応援',
#   '中',
#   '子供達',
#   'ミニバス',
#   '奮闘',
#   '中',
#   '無言',
#   'フォロー',
#   '無言',
#   'フォロー',
#   '歓迎'],
#  ['20代',
#   '雑多',
#   '垢',
#   '賢章',
#   '学',
#   '園生',
#   'i',
#   '7',
#   '賢章',
#   'さん',
#   '声優',
#   'コスプレイヤー',
#   'https',
#   'co',
#   '41',
#   'Faey',
#   '8',
#   'Crj',
#   '質問箱',
#   'https',
#   'co',
#   'szUpLWU',
#   '2',
#   'lV',
#   '受付中',
#   '前世',
#   '双子',
#   '彼氏',
#   'Lulz',
#   '0',
#   'M',
#   '気軽',
#   'カメラババア',
#   '間'],
#  ['ゲーム',
#   'アニメ',
#   '用',
#   '垢',
#   'モンスト',
#   'ウイイレ',
#   'ドカバト',
#   'パズドラ',
#   'フェアリーテイル',
#   '呪術廻戦',
#   '鬼滅の刃',
#   '炎炎',
#   '進撃',
#   'ペダ',
#   '始め',
#   'たて',
#   'よろしくお願いします',
#   'フォロバ',
#   '絵',
#   'よう'],
#  ['複数',
#   'ブログ',
#   'サイト',
#   '運営',
#   '株',
#   '投資',
#   'ブログゲーム',
#   'https',
#   'co',
#   'sLD',
#   '9',
#   'jJ',
#   '8',
#   'AG',
#   '3',
#   '趣味',
#   'ブログ',
#   '数',
#   '十',
#   '個',
#   'ブログ',
#   '運営',
#   '嵐',
#   "B'z",
#   '好き',
#   'ゲーム',
#   'DQFF',
#   '妖怪ウォッチ',
#   '系',
#   'フォトナ',
#   '妖怪ウォッチ',
#   'Ｅpic',
#   'クリエイター',
#   '済'],
#  ['雑多',
#   '垢',
#   '永遠',
#   '初心者',
#   'レイヤー',
#   '無言',
#   'フォロー',
#   '失礼',
#   '関東',
#   '今月',
#   '誕生',
#   '日',
#   'https',
#   'co',
#   'ebG',
#   '1',
#   'fqJJ',
#   '4R'],
#  ['UX',
#   'UI',
#   'designer',
#   'Travel',
#   'Adviser',
#   'Movie',
#   'Creater',
#   'TableGame',
#   'Promoter'],
#  ['懸賞', '猫', 'アロマ', '映画', '紅茶', 'コーヒー', '好き', '懸賞', '好き', 'さん'],
#  ['プロ野球',
#   'オタ',
#   'アイドルオタ',
#   'ai',
#   'yue',
#   '殿',
#   '戦国',
#   'アニマル',
#   '極楽浄土',
#   '窮鼠',
#   '百合',
#   '殿',
#   'スリジエ',
#   '中丸',
#   '葵',
#   '殿',
#   '仮面女子',
#   '候補生',
#   '乙木',
#   '伽奈',
#   '殿',
#   '神激',
#   '三笠',
#   'エヴァ',
#   '殿',
#   'HaSH',
#   'NAOKI',
#   '殿',
#   'BLACKSHEEPSYNDROME',
#   '赤司',
#   '殿',
#   '卒業',
#   'ILoVU',
#   '沖',
#   '海',
#   'みや',
#   '殿',
#   '神激',
#   '不死鳥',
#   'a.k.a',
#   'フェニックス',
#   '殿'],
#  ['高校球児',
#   '西武ライオンズ',
#   '好き',
#   '推しメン',
#   '山田遥楓',
#   '52',
#   '愛斗',
#   '53',
#   '伊藤翔',
#   '36',
#   '無限',
#   '可能性'],
#  [],
#  ['三代目',
#   'J SOUL BROTHERS',
#   'BUMP OF CHICKEN',
#   'SUPER JUNIOR',
#   '中村',
#   '倫也',
#   '鬼滅の刃',
#   'クラシック',
#   'ピアノ',
#   'ドラえもん',
#   'うさ',
#   '黒色',
#   '青色',
#   '今年',
#   '保育士',
#   '１７年',
#   '目',
#   '好き',
#   'もの'],
#  ['優柔不断', '雑食', '健康', '体'],
#  ['好き',
#   '俳優さん',
#   'アーティスト',
#   'さん',
#   '垢',
#   '何',
#   '十',
#   '年',
#   '振り',
#   'お絵描き',
#   '再開',
#   '怖い話',
#   '不思議',
#   '話',
#   '好き',
#   'https',
#   'co',
#   'b',
#   '5',
#   'AbdWZYfc'],
#  ['筋肉',
#   '知識',
#   '身',
#   '継続',
#   'パパ',
#   '妻',
#   '息子',
#   '1人',
#   '1',
#   '匹',
#   '1',
#   '匹',
#   'やりとり',
#   'ポジティブ',
#   '筋トレ',
#   'サブ垢',
#   'Niyoshi',
#   '14',
#   '相互フォロー',
#   '100',
#   '朝活',
#   '継続',
#   '筋トレ',
#   '英語'],
#  ['Based',
#   'in',
#   'Japan',
#   'Dancer',
#   'Choreographer',
#   'Instructor',
#   'IDO',
#   '世界大会',
#   'Jazzdance',
#   '日本代表',
#   'SJDA',
#   'ダンスコンテスト',
#   '優勝',
#   '雪月花',
#   '歌劇団',
#   '娘役',
#   '愛咲',
#   'ラン',
#   'Please',
#   'follow me',
#   'contact',
#   'rnkiwgm',
#   '97412',
#   'gmail.com'],
#  ['独身', '未婚男性', '彼女', 'ため', 'マッチングアプリ', '利用', '報告', '皆さん', '役', 'よう'],
#  ['kmt',
#   '柱',
#   '成人',
#   '済',
#   'いいね',
#   '雑食',
#   '地雷',
#   'Reproduction',
#   'is',
#   'prohibit',
#   'ed'],
#  ['千葉', '銚子', 'Lv', '21', '織部', '里紗', '命'],
#  ['マリオ',
#   'ファン',
#   '波',
#   '翠',
#   'みどり',
#   '名前',
#   '活動',
#   '任天堂',
#   'ゼルダ',
#   'ゲーム',
#   'チャージマン研!',
#   'ナック',
#   'アニメ',
#   'ヤマト',
#   'ネウロ',
#   '東方',
#   'irodori',
#   '彼岸島',
#   'MAD',
#   '動植物園',
#   '水族館',
#   'ハードオフ',
#   'ニコニコ大百科',
#   '過激',
#   'ネタ',
#   '等',
#   '苦手',
#   'ツイート',
#   'チャー研',
#   '多め'],
#  ['Vtuber', '音楽', 'よう', '誰かさん'],
#  ['会計',
#   '専門学生',
#   '毎日',
#   '頭',
#   'そう',
#   '勉強',
#   '趣味',
#   'ハンドメイド',
#   'メイク',
#   '.s',
#   'hopping',
#   '旅行',
#   'etc'],
#  ['橋川',
#   '姉妹',
#   '永遠に',
#   '1',
#   '2016',
#   '06',
#   '15',
#   '16',
#   '2017',
#   '02',
#   '20',
#   '特別',
#   '日',
#   '深川麻衣',
#   '橋本',
#   '奈々未',
#   '井上小百合',
#   '乃木坂',
#   '久保',
#   'ちゃん',
#   'いくちゃん',
#   'レイ',
#   'ちゃん',
#   'まいちゅん',
#   '日向坂',
#   'みほ',
#   '丹生',
#   'ちゃん',
#   'みーぱん',
#   'まいまい',
#   '毎日',
#   'マイペース',
#   '人',
#   '必要',
#   '時',
#   '必要',
#   '人',
#   '座右の銘',
#   'お願い'],
#  ['山形市',
#   'ゲームセンター',
#   'パルケ・デ・アミーゴ',
#   'メインアカウント',
#   '主',
#   '景品',
#   'ゲーム',
#   '事',
#   'アカウント',
#   'にも',
#   'イベント情報',
#   'いろいろ',
#   '事',
#   '気まま'],
#  ['ゆずりは',
#   '成人',
#   '済み',
#   '加州',
#   '服部耀',
#   'レオナ',
#   '五条',
#   '悟',
#   '狗巻棘',
#   '好き',
#   '30代',
#   '二児',
#   '母',
#   '取引',
#   '初回',
#   'ツイフィ',
#   '必読',
#   'フォロワー',
#   '様',
#   '最優先',
#   '48時間',
#   '以上',
#   '返信',
#   '場合',
#   'エラー',
#   'DM',
#   'リプ',
#   'お知らせ',
#   '幸い',
#   'アイコン',
#   '次女',
#   '作',
#   'ヘッダー',
#   '優起',
#   'さん',
#   'yu',
#   'u',
#   'ki'],
#  ['金', 'マカロン'],
#  ['FF外',
#   '気軽',
#   '成人',
#   'note',
#   'アニメ',
#   '感想',
#   '記事',
#   'FF外',
#   '場合',
#   '悪気',
#   '一人称',
#   '気分'],
#  ['成人',
#   'ﾏﾃﾝﾛ',
#   'twst',
#   'ｸﾞﾗﾌﾞﾙ',
#   'ｺﾝﾊﾟｽ',
#   '5',
#   'FGO',
#   'VRoid',
#   '血反吐',
#   'ﾍｯﾀﾞｰ',
#   '荘園',
#   'UTAU',
#   '倫理',
#   '人道',
#   '言動',
#   'ﾍｷ',
#   '傾向'],
#  ['1986年',
#   '創業',
#   '栃木県足利市',
#   '大麦',
#   'お菓子',
#   '食品',
#   '製造',
#   '販売会社',
#   '商品情報',
#   '等',
#   '更新',
#   'インスタ',
#   '商品',
#   '問い合わせ',
#   '下記',
#   'URL',
#   'お願い',
#   'RT',
#   'キャンペーン',
#   '実施中',
#   '栃木',
#   'Twitter',
#   '会'],
#  ['eKAZU',
#   'maino',
#   'ZAT',
#   'ラジオ',
#   'Poaro',
#   'YMO',
#   '新感線',
#   'LoL',
#   'ドイツゲーム',
#   '鷺沢',
#   '萠',
#   'bermei',
#   'inazawa',
#   '清竜人25',
#   'SideM',
#   'チャミグリ',
#   'Culdcept',
#   '炎の蜃気楼'],
#  ['Tokyo',
#   '30代',
#   'DM',
#   'なん',
#   '気分屋',
#   '人',
#   '歓迎',
#   '大学生',
#   '以上',
#   'お願い',
#   'kakao',
#   'yo',
#   'sh',
#   'a13'],
#  ['広島',
#   '生息',
#   'カメコ',
#   '写真',
#   'の',
#   '好き',
#   'カメラ',
#   'レンズ',
#   '沼',
#   '腕',
#   '機材',
#   '立派',
#   '成長',
#   '最近',
#   'キャンプ',
#   'キャンプアカウント',
#   'https',
#   'co',
#   'xd',
#   '8',
#   'YyEITGt'],
#  ['男性',
#   'これ',
#   '重要',
#   'シノ',
#   'アリス',
#   '主',
#   '雑多',
#   '垢',
#   'いばら',
#   '業火',
#   '物理',
#   '大好き',
#   '本屋',
#   'すてぃーる',
#   'めいと',
#   '所属',
#   'フレンド',
#   '募集中',
#   'シノ',
#   'アリス',
#   '以外',
#   'プリコネ',
#   'ツイステ',
#   '日常',
#   'こと',
#   'よろしくお願いします',
#   '一人暮らし',
#   'ため',
#   'たま',
#   '料理',
#   '写真',
#   '本日',
#   'ナナ',
#   '飯'],
#  ['キャパ',
#   'オーバー',
#   '発信',
#   '休み',
#   '中',
#   'たま',
#   'ROM',
#   'フォロー',
#   '方',
#   'ROOM',
#   'マイペース',
#   'https',
#   'co',
#   'hhuihfVyKU'],
#  ['日向坂で会いましょう', '沈黙の金曜日'],
#  ['ドラゴンボール',
#   '大好き',
#   '悟空',
#   '一番',
#   '好き',
#   'ドッカンバトル',
#   '中心',
#   '37回',
#   '天下一武道会',
#   '98位',
#   '極限',
#   'バトロ',
#   '制覇',
#   'プリコネ',
#   '中',
#   'タメ口',
#   'OK',
#   'ドラゴンボール',
#   '以外',
#   'ツイート',
#   'そこ',
#   '了承',
#   'フォロバ',
#   '師匠',
#   'teriyakitikin',
#   '7'],
#  ['ONCT',
#   '科',
#   '制御',
#   '科',
#   '頃',
#   'OB',
#   'ロボ',
#   '研',
#   '無線',
#   '部',
#   'くまモン',
#   'めじろん',
#   'カモネギ',
#   'ファン',
#   'アカウント',
#   '発言',
#   '私',
#   '個人',
#   '物',
#   '私',
#   '所属',
#   '組織',
#   '一切',
#   '関係'],
#  ['石切丸',
#   '好き',
#   '煉獄',
#   'さん',
#   'ゲーム',
#   '刀剣乱舞',
#   '刀',
#   'ミュ',
#   '刀ステ',
#   '刀剣',
#   '展示',
#   'ヅカオタ',
#   '年寄り',
#   '外',
#   '事',
#   '為',
#   'アカウント'],
#  ['高校1年生',
#   '15歳',
#   '模写',
#   '神',
#   '絵師',
#   'よう',
#   'インスタ',
#   'フォロー',
#   'よろしくお願いします',
#   'https',
#   'co',
#   'CfabYVUPBH'],
#  ['群馬県', 'ご当地アイドル', 'あかぎ', '団', '応援'],
#  ['東方神起', '大好き', 'ホミンペン', 'チャミペン', 'ユノ', '大好き', '何', 'チャミ', '好き'],
#  ['厨二病',
#   '患者',
#   '様々',
#   'ゲーム',
#   '者',
#   '実況',
#   '動画',
#   '厨',
#   '気',
#   '配信',
#   'ゲーム',
#   '自体',
#   '下手くそ',
#   'ひたすらに',
#   '雑食',
#   '最近',
#   '神',
#   'ウマ娘',
#   'TRPG',
#   '幕末志士',
#   'MSSP',
#   '熱',
#   '規制垢',
#   'homusa',
#   'No',
#   '2',
#   'アイコン',
#   'pinonononono'],
#  ['最近',
#   'コスプレ',
#   'ﾟ',
#   'ﾟ',
#   'アサシン',
#   '佐々木小次郎',
#   'アルジュナ',
#   '冨岡義勇',
#   'さん',
#   'マーリン',
#   '3',
#   '写真',
#   'の',
#   '牛歩',
#   '不死川実弥',
#   '黒死牟'],
#  ['ただ',
#   'おじさん',
#   '特撮',
#   '好き',
#   'アニメ',
#   '好き',
#   '美人',
#   '好き',
#   '料理',
#   '適当',
#   '応援',
#   '商品',
#   'こと',
#   '最近',
#   '甘酢',
#   '人'],
#  ['写真',
#   '人',
#   '趣味',
#   '音楽',
#   'イラスト',
#   'クラフト',
#   '書道',
#   'アニメ',
#   'マンガ',
#   'ゲーム',
#   '好き',
#   'camera',
#   'FUJIFILM',
#   'X',
#   'A1',
#   'Canon',
#   'FTb'],
#  ['CoDモバイル',
#   'KAME',
#   'さん',
#   'ほらー',
#   'ん',
#   'さん',
#   'モデレーター',
#   'トレーニング',
#   'ダイエット',
#   '指導',
#   'パーソナルトレーナー',
#   '20歳',
#   'トレーニング',
#   'ダイエット',
#   '指導者',
#   'トレーニング',
#   '指導者',
#   'ボディメイクデザイン'],
#  ['ホロライブ',
#   '箱推し',
#   'ロゼ',
#   '隊',
#   '農民',
#   'エル',
#   'スペシャル',
#   'リスト',
#   '月城',
#   '家',
#   '家臣',
#   'とき',
#   '時',
#   '１',
#   '番',
#   '最近',
#   'ショールーム',
#   '歌',
#   '枠',
#   '好き',
#   '音楽',
#   '映画',
#   '小説',
#   '漫画',
#   'おっさん'],
#  ['Taiwan',
#   'ese',
#   'She',
#   'They',
#   '阿美',
#   '語',
#   '閩南',
#   '語',
#   '龜',
#   '速',
#   '學',
#   '習',
#   '中',
#   '最近',
#   '沉迷',
#   '於進',
#   '巨',
#   'R',
#   '6',
#   '法',
#   '爾',
#   '科',
#   '寶',
#   '包',
#   '萊納',
#   '的',
#   '奶子',
#   '銳傑',
#   '號',
#   '惡魔',
#   '城',
#   '動',
#   '畫影',
#   '集',
#   'I',
#   'do',
#   'what',
#   'I',
#   'want',
#   'I',
#   'speak',
#   'what',
#   'I',
#   'want',
#   '廢推',
#   '與',
#   '心情',
#   '文',
#   'rt'],
#  ['鬼滅の刃',
#   'ファン',
#   'ページ',
#   '出張所',
#   '毎日',
#   '鬼滅の刃',
#   '関連',
#   '予定',
#   '表',
#   '共有',
#   '毎週',
#   '鬼滅の刃',
#   '予定',
#   '表',
#   '共有',
#   'フォロワー',
#   '2万人',
#   'ファン',
#   'ページ',
#   '運営',
#   'https',
#   'co',
#   '4',
#   'iQZF',
#   '0ma',
#   'SQ'],
#  ['共通',
#   '3年目',
#   'マジで',
#   '雑多',
#   '垢',
#   '生粋',
#   'ショタコン',
#   'ディズニー',
#   'ピクサー',
#   '1番',
#   '熱い',
#   'ハイキュー',
#   'イナズマ',
#   'GO',
#   'アレス',
#   'Dr',
#   'ストーン',
#   'ハリポタ',
#   'NARUTO',
#   'コナン',
#   '鬼',
#   '滅',
#   '彼方のアストラ',
#   'ロックマン',
#   'ざく',
#   'ら',
#   '熱',
#   'レイヤー',
#   'ハロ',
#   '仮装',
#   '者',
#   '発言',
#   '20'],
#  ['マルハン',
#   'マネージャー',
#   '趣味',
#   'バスケ',
#   'アキレス腱断裂',
#   '2周年',
#   'マルハン',
#   'マルハン',
#   '臨海',
#   '店',
#   'コバマネ',
#   '秋田高専',
#   '秋田大学',
#   'クレッシェンド',
#   '理想',
#   '実力',
#   '者',
#   '口',
#   '現実',
#   'コーチカーター',
#   'キングダム',
#   'モンスト',
#   '信念'],
#  ['無言',
#   'フォロー',
#   '失礼',
#   'バンタン',
#   '大好き',
#   'テテペン',
#   'ウイイレ',
#   'サッカー',
#   'ネタ',
#   '大好き',
#   'バンタン',
#   '好き',
#   '方',
#   'サッカー',
#   '好き',
#   '方',
#   'がめ',
#   'め',
#   'army',
#   'ウイニングイレブン',
#   '2021',
#   'バンタン',
#   '好き'],
#  ['懸賞',
#   '好き',
#   '爪',
#   'ぼろぼろ',
#   '今',
#   'セルフネイル',
#   '好き',
#   '綺麗',
#   'もの',
#   '好き',
#   '花江夏樹',
#   'さん',
#   '好き',
#   '笑顔',
#   'いちばん',
#   'ちゃん'],
#  ['ママ',
#   'One Direction',
#   '参戦',
#   '済',
#   'ONE OK ROCK',
#   '35',
#   'xxxv',
#   '5',
#   '30',
#   '参戦',
#   '済',
#   'Ambitions',
#   '5',
#   '16',
#   '広島',
#   '参戦',
#   '済',
#   'Ambitions',
#   'Final',
#   '京セラ',
#   '3',
#   '31',
#   '取引',
#   '垢',
#   '何回',
#   '取引',
#   '経験',
#   '無言',
#   'フォロー'],
#  ['アニメ',
#   '漫画',
#   '大好き',
#   'ONEOKROCK',
#   'MyFirstStory',
#   'UVERworld',
#   '大好き',
#   '気軽',
#   'フォロー',
#   '4',
#   '1',
#   'ONE OK ROCK',
#   '京セラドーム',
#   'LIVE',
#   'きた',
#   '腹',
#   '底',
#   '声',
#   '出して',
#   '思い出'],
#  ['趣味',
#   'アカウント',
#   'Hinde',
#   'Ikeyan',
#   'LINE',
#   '絵文字',
#   'https',
#   'co',
#   'nYUwhP',
#   '0',
#   'NOP',
#   'PC',
#   'MacBook Pro',
#   'Mid',
#   '2012',
#   'スマホ',
#   'iPhone 11',
#   'Pro',
#   'Max',
#   '使用',
#   'ソフト',
#   'Firealpaca',
#   'Blender'],
#  ['しよう', '最近', 'ラジオ', '好き', '20代'],
#  ['アニメーター', 'たま', '絵', '趣味', '人間'],
#  ['ドラマ', 'バラエティ', 'アニメ', 'etc'],
#  ['DAIGO',
#   '大好き',
#   '東北',
#   'TEAM',
#   'BREAKERZ',
#   '2009年',
#   '超絶',
#   'ファン',
#   '主',
#   '東京',
#   '仙台',
#   'イベント',
#   'ライブ',
#   '参戦',
#   'コロナ禍',
#   'ため',
#   '留守番',
#   '組',
#   '主',
#   'オンライン',
#   '活',
#   '継続',
#   '中',
#   '猫'],
#  ['フリー',
#   'タレント',
#   'All',
#   'or',
#   'Nothing',
#   '元メンバー',
#   'カラー',
#   '赤',
#   '北海道出身',
#   '子',
#   'ブタ',
#   'ぽっちゃり',
#   'アイドル',
#   '特撮',
#   '女子',
#   'YouTuber',
#   '好き',
#   'もの',
#   '仮面ライダー',
#   'スーパー戦隊シリーズ',
#   '特撮',
#   'お仕事',
#   '依頼',
#   'DM',
#   'hirona',
#   'izumi',
#   'gmail.com'],
#  ['20', 'アニメ', '漫画', '大好き', '雑多', '垢', 'RT', 'いいね', '多目'],
#  ['広島',
#   '幾田',
#   'りら',
#   'ちゃん',
#   '歌声',
#   '歌い手',
#   'さん',
#   '達',
#   '元気',
#   'ツイ',
#   '歌ってみた',
#   '動画',
#   '再生',
#   'リスト',
#   '歌い手',
#   'さん',
#   '是非',
#   'チャネル',
#   '登録'],
#  ['NARUTO',
#   'ボカロ',
#   'がく',
#   '好き',
#   '桃組+戦記',
#   'Dグレ',
#   'モブサイコ100',
#   'ネウロ',
#   'ネウヤコ',
#   'FGO',
#   '円卓',
#   '組',
#   'ベディ',
#   '2部',
#   '4',
#   '章',
#   'クリア',
#   '済み',
#   '刀剣乱舞',
#   '伊達',
#   '組',
#   '粟田口',
#   '脇差',
#   '組',
#   '土方',
#   '組',
#   '伽羅',
#   'ちゃん',
#   '兼',
#   'さん',
#   'ツイステ',
#   '絵',
#   'たま',
#   '絵',
#   '垢',
#   'a',
#   'ya',
#   'ki',
#   'dango'],
#  ['FGO',
#   'パズドラ',
#   'あたり',
#   'メイン',
#   '他',
#   'アズレン',
#   'モンスト',
#   'ガル',
#   'パ',
#   'ら',
#   'ファン',
#   'プリコネ',
#   '他',
#   'destiny',
#   '2',
#   '香澄',
#   '気軽',
#   'フォロー',
#   '気',
#   '人',
#   '無言',
#   'フォロー',
#   '了承'],
#  ['鬼', '滅', '用', 'アカ', '柱'],
#  ['https',
#   'co',
#   'DUBOZxGpjL',
#   '亀梨',
#   '担',
#   '亀と山P',
#   '滅',
#   '成人',
#   '済',
#   '雑食',
#   '東京喰種',
#   '無印',
#   'Re:',
#   'POI',
#   'TWD',
#   'PLL',
#   'デクスター',
#   'ゾンビ',
#   'アメドラ',
#   '大好き',
#   'ミナ',
#   'ぺ',
#   'ルホネン',
#   'サリースコット',
#   '洋服'],
#  ['I',
#   'swear',
#   'on',
#   'her',
#   'kindness',
#   'and',
#   'her',
#   'love',
#   'and',
#   'her',
#   'grave',
#   'that',
#   'I will',
#   'avenge',
#   'her'],
#  ['以前',
#   '知多娘。',
#   'クラスタ',
#   '最近',
#   'きまま',
#   '近場',
#   '鉄道撮影',
#   'メイン',
#   '名鉄',
#   'ネタ',
#   '多め',
#   '地味',
#   '他',
#   '業',
#   'せい',
#   '快活CLUB',
#   'セブンイレブン',
#   '全県',
#   '訪問',
#   '日本',
#   'JR',
#   '未乗',
#   '路線',
#   '只見線',
#   '小出',
#   '会津川口',
#   '現在',
#   '存続',
#   '他',
#   '路線',
#   '全線',
#   '完乗'],
#  ['広島出身',
#   '埼玉',
#   '野球',
#   'マンガ',
#   'アニメ',
#   'ラノベ',
#   '事',
#   '好き',
#   '強面',
#   'チキンハート',
#   '見た目',
#   '外食',
#   'ロンリー',
#   '食事',
#   'ツイ',
#   '多め',
#   '好き',
#   '事',
#   '適当',
#   'よろしくお願いします'],
#  ['深谷',
#   '寄居',
#   '地域',
#   '活動',
#   '非営利団体',
#   '記帳',
#   '労働保険',
#   '申告',
#   '社会保険',
#   '税金',
#   '相談',
#   '民商',
#   '税金',
#   '記帳',
#   '資金繰り',
#   '開業',
#   '労働保険',
#   'Instagram',
#   'Facebook'],
#  ['趣味',
#   'こと',
#   'こと',
#   'タク',
#   'こと',
#   'ラーメン',
#   'ハロヲタ',
#   '歴',
#   '23年目',
#   '島村',
#   '嬉唄',
#   'ちゃん',
#   '永遠',
#   '一',
#   '無言',
#   'フォロー',
#   '歓迎',
#   'ハロヲタ',
#   'さん',
#   'ゅる',
#   'ヲタ',
#   'さん',
#   'フォロバ',
#   '100％',
#   '鬼滅の刃',
#   'ガチ',
#   '沼',
#   'おじさん',
#   '826aska'],
#  ['イカ', 'まんねん', 'タコ', 'ちゅ', 'ちゅ', 'タコ', 'かいな'],
#  ['都内某所',
#   'カフェ',
#   '日々',
#   '妄想',
#   'いつ',
#   'ウルトラ',
#   'ハッピー',
#   '展開',
#   '光',
#   '腐女子',
#   '普段',
#   '仕事',
#   '料理',
#   'こと',
#   'ネタ',
#   'ケーキ',
#   '排球',
#   '牛',
#   '天',
#   '東西',
#   'ワンピ',
#   'サン',
#   'ウソ',
#   '一撃',
#   '男',
#   '師弟',
#   '好き',
#   '小説',
#   'SS',
#   '名刺',
#   '支部',
#   '投稿'],
#  ['6月9日', '22歳', '新日本プロレス', 'BiSH', '麻雀格闘倶楽部', '疾風', '白虎', '二', '段', '麻雀'],
#  ['30代',
#   '既婚',
#   '者',
#   '女性',
#   '新米',
#   '母',
#   '銀',
#   '閃',
#   '一家',
#   '長女',
#   '兼',
#   '伯母',
#   'RT',
#   'いいね',
#   '多め',
#   '時',
#   '事',
#   '事',
#   'い事',
#   '愚痴',
#   '等',
#   'アニメ',
#   'カラオケ',
#   'ゲーム',
#   '声優',
#   '特撮',
#   '読書',
#   '漫画',
#   '好き',
#   '基本的',
#   '地雷',
#   '無し',
#   '同担',
#   '歓迎',
#   '加害',
#   '的',
#   '人',
#   'ブロック'],
#  ['コレリス',
#   'ポケリス',
#   '倭',
#   '国民',
#   'korekore',
#   '19',
#   'G',
#   'C5',
#   'R5',
#   'OGIKgV',
#   '0',
#   'yvz',
#   'kzhodowameku',
#   '無言',
#   'フォロー',
#   '失礼',
#   'ポッキー',
#   'さん',
#   'コレコレ',
#   'さん',
#   '好き',
#   'ゲン',
#   'リス',
#   'パワプロ',
#   '漫画',
#   '好き'],
#  ['中国人', 'どうぶつの森', '中国人', '动物', '森', '平川大輔'],
#  ['姫',
#   'ぷぅ',
#   'ミラティブ',
#   '配信',
#   'ポケモン',
#   'モンハン',
#   'シノ',
#   'アリス',
#   'モンスト',
#   '下手',
#   '姫プレイ',
#   'ω',
#   'ﾃﾚﾃﾚ'],
#  ['ドラえもん',
#   'クレヨンしんちゃん',
#   '感動',
#   'シーン',
#   '涙',
#   '子供',
#   '６',
#   '人',
#   '父親',
#   'トレーラー',
#   'ヘッド',
#   'ボルボ',
#   '箱',
#   '日本',
#   '１',
#   '台',
#   'トラック',
#   '大阪',
#   '冷蔵庫',
#   '安室奈美恵',
#   '神',
#   'AimyonGtter',
#   'Fate',
#   'セイバー',
#   '煉獄杏寿郎'],
#  ['好き',
#   '料理',
#   '旅行',
#   'グルメ',
#   'コスメ',
#   'お酒',
#   'サッカー',
#   'アメコミ',
#   'あつ森',
#   'ドラクエ',
#   'パソコン',
#   '音楽',
#   '柴犬',
#   '当選',
#   'きんとん',
#   '当選',
#   '色々',
#   '企業',
#   '様',
#   '縁',
#   'よう',
#   '無言',
#   'フォロー',
#   '歓迎',
#   '最近',
#   'ハム',
#   'ちゃん'],
#  ['我妻善逸'],
#  ['サムネ',
#   'ヘッダー',
#   '妻',
#   'Akaki',
#   'Kon',
#   '129',
#   'あつ森',
#   '夢番地',
#   'DA',
#   '6065',
#   '5291',
#   '8078',
#   'モンハン',
#   'スプラ',
#   '2',
#   'リング',
#   'フィット',
#   'フィットボクシング',
#   'マリオオデッセイ',
#   '写真',
#   'コンテスト',
#   '銀賞',
#   '3回',
#   '受賞',
#   'スマブラSP',
#   '1回',
#   '写真',
#   'コンテスト',
#   '採用'],
#  ['FANKS',
#   '笑い',
#   '神様',
#   '負け',
#   '神様',
#   '中',
#   'ずく',
#   '無言',
#   'フォロー',
#   'ブロック',
#   '例外',
#   '有り'],
#  ['once',
#   'withU',
#   '専属',
#   '加工',
#   '師',
#   'HONO',
#   '71523432',
#   'たくさん',
#   'HN',
#   '45007630',
#   'Nanashichan',
#   '324',
#   'ヘッダー',
#   '専属',
#   '加工',
#   '師',
#   'さん',
#   '制作'],
#  ['20', 'ROM専'],
#  ['ウマ娘',
#   'やるマン',
#   'あと',
#   '漫画',
#   '特撮ヒーロー',
#   'アメコミヒーロー',
#   '食玩',
#   'オモチャ',
#   '子供',
#   '事',
#   'ハイロー',
#   '好き',
#   'FGO',
#   'スタァライト',
#   'アサルトリリィ',
#   '昔',
#   'WTRPG'],
#  ['マタ',
#   '育児',
#   'アカ',
#   '情報収集',
#   '思考',
#   '整理',
#   'ため',
#   '専用',
#   'アカウント',
#   '作りました',
#   '2',
#   '21',
#   '無事',
#   '女の子',
#   '出産'],
#  ['アニメ',
#   '系',
#   'ゲーム',
#   '大好き',
#   '専門',
#   '校生',
#   '東方',
#   '好き',
#   '音ゲー',
#   'まーす',
#   '趣味',
#   '音ゲー',
#   'クレーンゲーム',
#   'ヮ'],
#  ['奈良', 'こと', '奈良', '奈良', '好きな人', '夏目友人帳', 'ノラガミ', '鬼滅の刃', '無言', 'フォロー'],
#  ['幼児',
#   '２',
#   '人',
#   '母',
#   '睡眠時間',
#   '確保',
#   '時短',
#   '勤務',
#   '中',
#   '活字',
#   '漫画',
#   '本',
#   'の',
#   '好き',
#   'イラスト集',
#   '好き',
#   'プラレール',
#   '踏切',
#   '何',
#   '没頭',
#   '時間'],
#  ['雑多',
#   'ゲーム',
#   '垢',
#   'FGO',
#   'メギド72',
#   'グラブル',
#   'アイギス',
#   '崩壊3rd',
#   'MtGA',
#   '済',
#   '極め',
#   '2',
#   '賢者',
#   '2',
#   '神石',
#   '水',
#   '闇',
#   '最近',
#   'デレステ',
#   '履修'],
#  ['逃げ',
#   'シス',
#   '好き',
#   'ぎるへんたいふしんしゃ',
#   'トレーナー',
#   'ナナシス',
#   'アイマス',
#   'ドラクエ10',
#   '好き',
#   'サッカー',
#   '前世',
#   '絵描き'],
#  ['20',
#   'じゅじゅ',
#   '足',
#   'ツイステ',
#   'まんが',
#   'アニメ',
#   '雑多',
#   'ゲーム',
#   'クソ',
#   '下手',
#   '初心者',
#   '好き',
#   'こと',
#   '勝手',
#   '無言',
#   'フォロー'],
#  ['SKE48',
#   '末永桜花',
#   'ちゃん',
#   '佐藤佳穂',
#   '竹内',
#   'ななみ',
#   '伊藤',
#   '実希',
#   '秦佐和子',
#   'ふっかちゃん',
#   'Y',
#   'o',
#   '0',
#   'ω',
#   '0',
#   'o',
#   'Y',
#   '趣味',
#   '仏像',
#   '鑑賞',
#   '御朱印',
#   'FGO',
#   'ウマ娘',
#   'プレイ',
#   '中',
#   'ライスシャワー'],
#  ['映画', '好き'],
#  ['チェリ',
#   '高',
#   '帰宅部',
#   'イリヤ',
#   'くん',
#   'VTuber',
#   'メイン',
#   '応援',
#   '垢',
#   'アオバズ',
#   '専',
#   '垢',
#   'i',
#   'y',
#   'k',
#   'k4',
#   'love',
#   'ゅがすて',
#   'みなみ',
#   'くん',
#   'セブ',
#   'リス',
#   '⁷',
#   'れふ',
#   'くん',
#   '専',
#   '垢',
#   'ぇりすたありがとう',
#   '解散',
#   '大好き',
#   '素敵',
#   'グループ',
#   'ぷり',
#   'ぎ'],
#  ['ゲーム', '漫画', '垢', '20', '審神者', '監督生', 'マスター'],
#  ['動画編集',
#   'アカウント',
#   '方',
#   'ゲーム',
#   'アニメ',
#   '最高',
#   'YOUTUBE',
#   '毎日',
#   '投稿',
#   'b',
#   '夢',
#   '最中',
#   'フォロバ',
#   '１',
#   '０',
#   '０',
#   '％',
#   'ヒメヒナ',
#   '大好き',
#   '今',
#   '動画編集',
#   'フリーランス',
#   '方',
#   '基本的',
#   '人',
#   '嘘',
#   '嫌い',
#   '22歳',
#   '韓国',
#   '人'],
#  ['English',
#   'learner',
#   'Love',
#   'Bali',
#   'NYC',
#   'AKIKO',
#   'YANO',
#   'HIROMI',
#   'UEHARA',
#   'Musical',
#   'play',
#   'Saxophone'],
#  ['イラスト',
#   '依頼',
#   'DM',
#   'たましい',
#   'くん',
#   'ぬいぐるみ',
#   'イラスト',
#   '発信',
#   'メイン',
#   '個性',
#   '道',
#   'イラスト',
#   '関係',
#   '拡散',
#   '発信',
#   'お手伝い',
#   'アメブロ',
#   '毎日',
#   '2',
#   '記事',
#   '更新',
#   '中',
#   'GLAY',
#   '家族',
#   '事',
#   '妻',
#   '専業主婦',
#   'の',
#   '最終',
#   '目標',
#   '店',
#   'こちら'],
#  ['モンスト',
#   '初心者',
#   'rank',
#   '680',
#   '運',
#   '極',
#   '597',
#   '推',
#   'ｷｬﾗ',
#   '鬼丸国綱',
#   'アルセーヌ',
#   'きょんこ'],
#  ['中学',
#   '17年',
#   '生',
#   '彼女',
#   'MAZDA',
#   '3',
#   'EOS RP',
#   'GoPro',
#   '一座',
#   'ラーメン',
#   '安全運転'],
#  ['ケモ',
#   '生き物',
#   '物',
#   '何',
#   '守備範囲',
#   '大阪',
#   '生誕',
#   '世紀',
#   'メタボ',
#   'おば',
#   'ちゃん',
#   'おっぱい',
#   '正義',
#   'RT',
#   '魔',
#   '毒',
#   'フリート',
#   'スルー',
#   '社交辞令',
#   '的',
#   'フォロバ',
#   '無し',
#   '某',
#   '団',
#   '248',
#   '画像',
#   'きゃわわ',
#   'ガチグロ',
#   '注意',
#   'うち',
#   '子',
#   'LandPlanariaBot'],
#  ['⁽⁽', '⁾⁾', 'Naturally', 'cute'],
#  ['声', '真似', 'ゲーム実況', 'の', '大好き'],
#  ['漫画',
#   'アニメ',
#   '声優',
#   '2次元',
#   '2.5次元',
#   '心身',
#   'とも',
#   'イラスト',
#   '投下',
#   '無言',
#   'フォロー',
#   '本垢',
#   'つぶ',
#   'こと',
#   'こと'],
#  ['只',
#   'オタク',
#   '独り言',
#   '二次元',
#   'アイドル',
#   '好き',
#   'こと',
#   'スクフェス',
#   'デレステ',
#   'ガル',
#   'パ',
#   'FGO',
#   'アニメ'],
#  ['声優さん',
#   'まんが',
#   'アニメ',
#   'スイーツ',
#   '大好き',
#   'ヲタ',
#   '活',
#   '充実',
#   '為',
#   '副業',
#   '興味',
#   '方',
#   '案内'],
#  ['14',
#   '2',
#   '13',
#   '13',
#   '73',
#   '73',
#   'MASAJC',
#   '64',
#   '13',
#   'AJC',
#   '10',
#   'ex',
#   '15',
#   '17'],
#  ['利用',
#   'おへや',
#   '家主',
#   'おすすめ',
#   '商品',
#   '紹介',
#   'たま',
#   'の',
#   '紹介',
#   '勘弁',
#   '経由',
#   'よろしくお願いします',
#   '楽天',
#   'ROOM',
#   'Amazonアソシエイト',
#   'ねこ',
#   '猫',
#   'ネコ'],
#  ['ポイント'],
#  ['暇', '時', '最近', 'キャンプ', '絡み'],
#  ['20',
#   '雑多',
#   '垢',
#   'あん',
#   'スタ',
#   'A3',
#   '2月',
#   '後半',
#   '絵描き',
#   'スタート',
#   'フォロバ',
#   '無言',
#   'フォロー',
#   '失礼',
#   '鬼滅の刃',
#   '単行',
#   '本',
#   '派',
#   'オリジナル',
#   'コスプレ'],
#  ['天気の子',
#   '大好き',
#   '38回',
#   '観',
#   '映画館',
#   '機会',
#   'たくさん',
#   'こと',
#   '君の名は。',
#   '泣き',
#   '猫',
#   'たまこ',
#   'しんちゃん',
#   '好き',
#   'フォロー返し',
#   '気まぐれ',
#   '期待'],
#  ['STAY',
#   '23',
#   'MDCU',
#   '69',
#   'Believe',
#   'in',
#   'the',
#   'person',
#   'I',
#   'want',
#   'to',
#   'become',
#   '1995',
#   'Thailand',
#   'instragram',
#   'omaoom'],
#  ['よろしくお願いします', 'ω', '性別', 'スイッチ', '無機物', 'の', 'ω', 'ω', 'ω', '大量', '生産'],
#  ['ファンマ',
#   '竈門',
#   '禰豆',
#   '子',
#   '公式',
#   '嫁',
#   'みう',
#   '48',
#   '音',
#   'ちゃん',
#   '大好き',
#   'の',
#   '48',
#   'fam',
#   'れいちゃ',
#   '愛してます',
#   '一生',
#   '大事',
#   'ゆな',
#   'ちゃん',
#   '同担',
#   '嫁',
#   '拒否',
#   '愛人',
#   'yuna',
#   '20050929',
#   '嫁',
#   'hanotann',
#   'カプ',
#   'みう',
#   'みう',
#   'みう',
#   'ゆり',
#   'みう',
#   'のぶ',
#   'みう',
#   'ゆな'],
#  ['ひとで', 'みな', 'みやま', '海外', 'EDM', 'オタク', '鬼', '滅', '結果', 'リモ', '女', '新入生'],
#  ['taiwan'],
#  ['海上自衛隊',
#   '陸上自衛隊',
#   '高校野球',
#   'ラーメン',
#   'カレー',
#   '物',
#   'アイドル',
#   '大好き',
#   '基本',
#   'DD',
#   'AKB',
#   'さ',
#   '萌',
#   'ちゃん',
#   '永遠',
#   '渚沙',
#   'ゆうかりん',
#   '超絶',
#   '神推し',
#   'NMB',
#   '望',
#   '叶',
#   '怜',
#   'ちゃん',
#   'STU',
#   '宙花',
#   'みゆな',
#   'マリーナ',
#   '乃木坂',
#   '真夏',
#   '生田',
#   '飛鳥',
#   '北野',
#   '3',
#   '4期生',
#   '全員',
#   '欅坂',
#   'ねる',
#   '永遠',
#   '神推し',
#   '2期生',
#   '全員',
#   '日向坂',
#   'こさかな',
#   '影',
#   'ちゃん'],
#  ['懸賞',
#   '大好き',
#   'ディズニー',
#   'チケット',
#   'の',
#   '夢',
#   '企業',
#   '様',
#   '団体',
#   '様',
#   '縁',
#   'よう',
#   'フォロー',
#   '人',
#   'す',
#   '基本',
#   'フォロバ',
#   '心',
#   '穏やか',
#   'みんな',
#   'みんな',
#   'コロナ',
#   '終息'],
#  ['仕事', '合間', '応募', '人', 'サブ垢', 'ありません'],
#  ['アカウント',
#   'CHEMISTRY',
#   'side',
#   'K',
#   'ドナルドダック',
#   'Disney',
#   'MARVEL',
#   '猫',
#   '声優',
#   'etc.',
#   '自分',
#   'ペース',
#   'ケミ',
#   '活',
#   'AVM',
#   '定期',
#   '検診',
#   '様子見'],
#  ['鬼滅の刃',
#   '大好き',
#   '女子',
#   'カナヲ',
#   'ちゃん',
#   'しのぶ',
#   'さん',
#   '男子',
#   '義勇',
#   'さん',
#   '天元',
#   'さん',
#   '呪術廻戦',
#   '五条',
#   '先生',
#   '狗巻',
#   '先輩',
#   '娘',
#   'イラスト'],
#  ['佐藤', '家', '長男', 'AP', 'EX', 'LEGENDS'],
#  ['キャライフ',
#   'キャラクター',
#   'Character',
#   '生活',
#   'Life',
#   '造語',
#   'キャラクター',
#   '生活',
#   '提案',
#   'ショップ',
#   'アニメ',
#   '漫画',
#   '名車',
#   'コラボ',
#   'アイテム',
#   '企画',
#   '販売',
#   'ショップ',
#   'life',
#   'with',
#   'character',
#   'concept',
#   'shop',
#   'in',
#   'japan'],
#  ['YouTube',
#   'カラオケ',
#   '100点',
#   'おじさん',
#   'チャンネル',
#   '佐々木',
#   '淳平',
#   'さん',
#   '歌声',
#   '世界',
#   '一番',
#   '大好き',
#   '佐々木',
#   '淳平',
#   'さん',
#   'グッズ',
#   'ショップ',
#   'check',
#   'it',
#   'out',
#   'https',
#   'co',
#   '4G',
#   'klEGMxw',
#   '8',
#   '佐々木',
#   '淳平',
#   '石崎ひゅーい',
#   'SiM',
#   'YOHIO'],
#  ['99',
#   'line',
#   'fukuoka',
#   '杉野遥亮',
#   '平野紫耀',
#   'オタク',
#   'suginoofficial',
#   'kingandprince',
#   'j',
#   'ちゃん',
#   's',
#   '広報',
#   '隊長',
#   'めん',
#   'couple'],
#  ['二次創作',
#   'オタク',
#   '趣味',
#   '専用',
#   'アカウント',
#   '成人',
#   '済み',
#   '主',
#   '刀剣乱舞',
#   'Fate',
#   'DC',
#   'あと',
#   'ミニチュア',
#   'R-18',
#   '基本的',
#   '十八歳',
#   '以下',
#   'ブロリム',
#   'マシュマロ',
#   'https',
#   'co',
#   'OnS',
#   '7',
#   'Qmo',
#   '7',
#   'pT'],
#  ['成人',
#   '済',
#   '会社員',
#   'Love',
#   '声優',
#   '山中',
#   '真尋',
#   'ジャニーズWEST',
#   '橙',
#   '緑',
#   '桃',
#   'VAZZROCK',
#   '赤',
#   '青',
#   '刀剣乱舞',
#   '亀甲貞宗',
#   '夢',
#   '女子',
#   '発言',
#   '多め',
#   '無言',
#   'フォロー',
#   'icon',
#   '友人',
#   'ct',
#   '0421',
#   '貰い物'],
#  ['宇野昌磨',
#   '選手',
#   '真央',
#   'さん',
#   '高橋さん',
#   '町田先生',
#   '尊敬',
#   '友野',
#   '君',
#   '島田',
#   '君',
#   '鍵山',
#   '君',
#   '応援',
#   '女子',
#   'ザギ',
#   'ちゃん',
#   '三原',
#   'さん',
#   '坂本さん',
#   '海外',
#   '選手',
#   '基本',
#   'フィギュアスケート',
#   '垢',
#   '綺麗',
#   '写真',
#   '絵画',
#   '雑貨',
#   '小物',
#   '動物',
#   '健康',
#   '食養生',
#   'アルメニア',
#   'リンク',
#   '大嫌い',
#   '選手',
#   'ファン'],
#  ['こうや',
#   'こうや',
#   'そ',
#   '自動車',
#   'アニメ',
#   '声優',
#   '漫画',
#   '勉強',
#   '雑学',
#   'ミニマリスト',
#   'ＧＬＡＹ',
#   'ラルク',
#   '福原',
#   '遥',
#   '中川大志',
#   '浜辺美波',
#   '暴言',
#   '厨',
#   '湾岸',
#   'キッズ',
#   'フォロバ',
#   '目的',
#   '出会い',
#   '目的',
#   'オフパコ',
#   '目的',
#   'ビジネス',
#   '副業',
#   'ＦＸ',
#   '投資',
#   'アフィリエイト',
#   '勧誘',
#   '目的',
#   '追加'],
#  ['京都市',
#   '在住',
#   '２',
#   '児',
#   '母',
#   '年子',
#   '小1',
#   '女子',
#   '年長',
#   '男子',
#   '下',
#   '子',
#   'ダウン症',
#   '友達',
#   'ダウン症',
#   '児',
#   '子育て',
#   'サークル',
#   'にじいろ',
#   'すまいる',
#   '下',
#   'URL',
#   'FB',
#   'ページ',
#   '毎日',
#   '睡魔',
#   '心',
#   '格闘',
#   '中'],
#  ['私', '人', '悪夢', 'こと'],
#  ['楽天市場',
#   'オススメ',
#   '商品',
#   '紹介',
#   'アフェリエイト',
#   '初心者',
#   '人',
#   'フォロー',
#   'ねが',
#   'フォロバ',
#   '100％'],
#  ['アメコミ',
#   'SF',
#   'ホラー',
#   '映画',
#   '大好き',
#   'MARVEL',
#   '1番',
#   'Blu',
#   'ray',
#   '全部',
#   'お酒',
#   '好き',
#   '韓国',
#   '音楽',
#   '好き',
#   '昔',
#   'BIGBANG',
#   '最近',
#   'BTS',
#   'BLACKPINK',
#   '応援',
#   '映画',
#   '好きな人',
#   '友達',
#   '募集',
#   'お酒',
#   '好きな人',
#   'BIGBANG',
#   'BTS',
#   'BLACKPINK'],
#  ['21',
#   'twst',
#   'hpmi',
#   '鬼',
#   '滅',
#   'ect',
#   '無言',
#   'フォロー',
#   '失礼',
#   '気軽',
#   'フォロー',
#   '別れ',
#   'ブロ',
#   '解',
#   'エロ',
#   '垢',
#   'フォロー',
#   'なっつ',
#   'ん',
#   'ω'],
#  ['m'],
#  ['wonderland',
#   'ｯｯ',
#   '女',
#   '同担',
#   'さん',
#   'その他',
#   '諸々',
#   '大丈夫',
#   '多分',
#   '皆さん',
#   'タメ',
#   '歓迎',
#   'リプ',
#   'アニメ',
#   '好き',
#   '絵描き',
#   'さん',
#   'ツイステ・ミューパレ',
#   '好き',
#   '人',
#   'ヘッダー',
#   'ゆず',
#   '煮込み',
#   '様'],
#  ['AAA',
#   'SHINJIRO ATAE',
#   '関ジャニ∞',
#   '鬼滅の刃',
#   'セーラームーン',
#   'etc.',
#   'ツイート',
#   'RT',
#   'たま',
#   '疲労困憊',
#   'ツイート',
#   '了承'],
#  ['絵',
#   'またの名',
#   'ディルムッド',
#   '翁',
#   '絵',
#   'モーメント',
#   'アイコン',
#   '自前',
#   '絵',
#   '小説',
#   '歌',
#   '勉強',
#   '中',
#   'アイアンサーガ',
#   '机',
#   '动战',
#   '队',
#   'ウマ娘',
#   '無差別',
#   'RT',
#   '多め',
#   '私',
#   'イラスト',
#   '無断転載',
#   '禁止',
#   'Unauthorized',
#   'reproduction',
#   'prohibit',
#   'ed'],
#  ['懸賞',
#   '垢',
#   '新社会人',
#   'ブルベ',
#   '夏',
#   '好き',
#   'もの',
#   'コスメ',
#   'サンリオ',
#   '特撮',
#   '声優',
#   '邦',
#   'ロック',
#   'V系',
#   'お笑い',
#   'アイドル',
#   '当選',
#   'とき',
#   'ろ',
#   'ろ',
#   '当選',
#   '報告',
#   '報告',
#   '夢',
#   'デパコス',
#   '当選',
#   '気軽',
#   'フォロー',
#   '懸賞',
#   '垢',
#   'さん',
#   'フォロバ',
#   '敬語',
#   '懸賞',
#   '垢',
#   'さん'],
#  ['北海道江別市',
#   '在住',
#   '江別',
#   '野幌',
#   '大麻',
#   '地区',
#   '情報発信',
#   'サイト',
#   'ナビ',
#   '運営',
#   '月間',
#   '最高',
#   '57',
#   '4',
#   '万',
#   'アクセス',
#   '累計',
#   '1',
#   '300万',
#   'PV',
#   '超',
#   '管理人',
#   '育児',
#   '中',
#   '40代',
#   '旅',
#   '鉄道',
#   '廃線跡',
#   '廃墟',
#   '建物',
#   '読書',
#   '等',
#   '趣味',
#   'ブログ',
#   '講師',
#   'Web',
#   'コンサル',
#   '業',
#   'フォロー',
#   '気軽',
#   'フォロー返し',
#   '気まぐれ',
#   '鍵',
#   '垢',
#   '基本',
#   'フォロー返し'],
#  ['セレブ',
#   '最上級',
#   '最高',
#   '究極',
#   'セレブ',
#   'こと',
#   '人',
#   'セレベスト',
#   '勢い',
#   'ＭＡ',
#   '作者',
#   '一筆',
#   '一',
#   '筆',
#   '魂',
#   '究極',
#   'セレブ',
#   'たち',
#   '天下',
#   '取り',
#   'セレベスト',
#   'たち',
#   '合戦',
#   'おもてなし',
#   '相手',
#   '屈服',
#   '究極',
#   'セレブ',
#   '界',
#   '頂点'],
#  ['役者', '脚本', '勉強', '中', '熊本県', '出身', '農家', '娘', 'お洒落', '田舎者'],
#  ['八雲紫',
#   '西行寺幽々子',
#   'フェローチェ',
#   'アニメ',
#   'の',
#   'お姫様',
#   'ドレス',
#   '雑コラ',
#   '作り',
#   '好き',
#   '妄想',
#   '絵',
#   'こと',
#   '…。',
#   '固定',
#   'ツイート',
#   '毎回',
#   '変化',
#   '他',
#   '好き',
#   'キャラ',
#   'ミュウツー',
#   'シルヴァディ',
#   'マッシブーン',
#   'サザンドラ',
#   'ピーチ姫',
#   'デイジー姫',
#   'ロゼッタ',
#   'Pixiv'],
#  ['好き', 'もの'],
#  ['FF7',
#   'ｸﾗｽﾀ',
#   'DMC',
#   'ｸﾗｽﾀ',
#   'ｸﾗｳﾄﾞ',
#   'ﾊﾞｰｼﾞﾙ',
#   '好き',
#   'FF7',
#   'ｼﾘｰｽﾞ',
#   '小説',
#   '5',
#   '8',
#   '10',
#   '-2',
#   '12',
#   '13',
#   '-3',
#   '15',
#   '零式',
#   'ﾊﾞｲｵ',
#   'DM',
#   'C1',
#   '5',
#   'SE',
#   '含',
#   'ﾆｰｱ',
#   '等',
#   '成人',
#   '済',
#   '腐女',
#   '大学',
#   '勤務',
#   'ｺｽﾌﾟﾚ',
#   'たま',
#   'DMC',
#   '兄弟',
#   '愛',
#   'ﾈﾛ',
#   'V',
#   '地雷',
#   '何',
#   'FF',
#   'DMC'],
#  ['歌い手'],
#  ['目当て',
#   '動物',
#   '科学',
#   '情報',
#   '絵',
#   '雑事',
#   '連投',
#   '発散',
#   '頃',
#   '天文',
#   '興味',
#   'はやぶさ2',
#   '愛',
#   '炸裂',
#   '中',
#   'NG',
#   '身元判明',
#   '固有名詞',
#   '人格',
#   '否定',
#   '攻撃',
#   '加担'],
#  ['旅',
#   'ゴルフ',
#   '登山',
#   '料理',
#   '皿',
#   'お酒',
#   '好き',
#   '趣味',
#   '為',
#   '間',
#   'どこ',
#   '日々',
#   '食',
#   '休日',
#   '重き',
#   '仕事',
#   'おなご'],
#  ['自発',
#   'ポスト',
#   'ご覧',
#   '他',
#   'キスマイ',
#   'KinKi',
#   'MFS',
#   '好き',
#   '男性',
#   'crew',
#   'NAKAMA',
#   '一笑懸命',
#   'テキ',
#   'トー',
#   'スト',
#   'テラ',
#   'マイファス',
#   '11',
#   '1夜',
#   '公演',
#   '参戦',
#   '済み',
#   'ミラティブ',
#   '配信',
#   '者',
#   '笑',
#   'NARUTO',
#   '大好き',
#   '人間',
#   'イコラブ',
#   '沼',
#   '笑'],
#  ['音楽',
#   'ライブ',
#   '元気',
#   '源',
#   '大好き',
#   'ポルノグラフィティ',
#   'スカパラ',
#   'Base Ball Bear',
#   'UNISON',
#   'SQUARE',
#   'GARDEN',
#   'サカナクション',
#   'クリープハイプ',
#   'BUMP',
#   'Perfume',
#   '中田裕二',
#   'スヌーピー',
#   'ディズニー'],
#  ['鬼滅の刃', 'ネバ', '呪術廻戦', '胡蝶しのぶ', 'さん', '藪', '佑介', 'くん'],
#  ['AAA',
#   'WANIMA',
#   '大好き',
#   '大瀬良',
#   'くん',
#   'ジャンプチ',
#   'クロン',
#   '選手',
#   '写真',
#   'の',
#   '好き',
#   '無許可',
#   'の',
#   '2021年',
#   'オープン戦',
#   '2勝',
#   '公式戦',
#   '2勝',
#   '4敗',
#   '2分'],
#  ['成人',
#   '済',
#   'FGO',
#   'ロマ',
#   'ぐだ',
#   'ソ',
#   '科目',
#   'ぐだ',
#   'マーぐだ',
#   'ツイステ',
#   'オクタ',
#   '監',
#   'スカラビア',
#   '基本',
#   '雑食',
#   'マシュマロ',
#   'https',
#   'co',
#   'zWrP',
#   '0m',
#   'ufNZ',
#   'Skeb',
#   'https',
#   'co',
#   'ljus',
#   '4',
#   'MwlUO'],
#  ['ドット絵', 'クロスステッチ', 'グッズ', '猫と金魚', 'ペンギン', '大好き', 'ネイル'],
#  ['アマチュア',
#   '物書き',
#   '書き出し',
#   '祭り',
#   '３回',
#   '総合',
#   '６',
#   '120位',
#   '９回',
#   '総合',
#   '15',
#   '100位',
#   'その他',
#   '短編',
#   'コンテスト',
#   '入賞',
#   '経験',
#   'アイコ',
#   'ン',
#   'ヘッダー',
#   '画像',
#   '黒杉くろん',
#   'さん',
#   '代表作',
#   'ぷ',
#   '夢',
#   '町',
#   '捕物',
#   '控',
#   'https',
#   'co',
#   'LAo',
#   '4',
#   'ocBNlF'],
#  ['旦那',
#   '子供',
#   '3人',
#   '暮らし',
#   '国内外',
#   '旅行',
#   'コスメ',
#   'インテリア',
#   '料理',
#   'キャンプ',
#   '当選',
#   '報告',
#   '気軽',
#   '話',
#   'っ子',
#   'じいちゃん',
#   'https',
#   'co',
#   'NyWHbV',
#   '2',
#   'p',
#   '08'],
#  ['成人',
#   '済み',
#   '25',
#   '取引',
#   '垢',
#   '兼',
#   '用',
#   '鬼',
#   '滅',
#   '中心',
#   '煉獄杏寿郎',
#   '甘露寺蜜璃',
#   '友人',
#   '分',
#   '義勇',
#   '炭',
#   '治郎',
#   'しのぶ',
#   '実弥',
#   '前世',
#   '煉獄',
#   'さん',
#   '芋',
#   '一人称',
#   '芋',
#   '芋',
#   '同担拒否',
#   'ありません',
#   '平和',
#   '1番',
#   '皆',
#   '事',
#   'ょっ',
#   '本垢',
#   '気軽',
#   'たま',
#   'コスプレ',
#   '投下'],
#  ['秋元',
#   '系列',
#   '乃木坂',
#   '関連',
#   '等',
#   'ＮＧ',
#   '辻加護',
#   '世代',
#   '男',
#   '両親',
#   '影響',
#   '幼少',
#   '期',
#   '党',
#   '浦和サポ',
#   '以外',
#   '基本的',
#   'ＮＧ',
#   'アンチ巨人',
#   'アンチ浦和',
#   'お断り',
#   '都道府県',
#   '男女',
#   'ハロヲタ',
#   '党',
#   '浦和サポ',
#   '好き',
#   'フォロー',
#   '歓迎',
#   'ハロプロ',
#   '以外',
#   'なんキニ！',
#   '仁科',
#   '茉彩',
#   'ちゃん',
#   '好き',
#   'ツイート',
#   '喜怒哀楽',
#   '固定',
#   'ツイート'],
#  ['主',
#   'ゲーム',
#   'こと',
#   'アカウント',
#   'あと',
#   '漫画',
#   '感想',
#   '絵',
#   '主',
#   'レトロゲー',
#   '古',
#   'ゲーマー',
#   'DQ',
#   '10',
#   '以外',
#   'プレイ',
#   'FF',
#   '7',
#   'クリア',
#   'ロマサガ',
#   'ミンサガ',
#   '聖剣伝説3',
#   '好き',
#   '最近',
#   'ダイの大冒険',
#   '実況',
#   '垢',
#   'みたい'],
#  ['キングダム',
#   '嬴政',
#   '漂',
#   '吉沢亮',
#   'くん',
#   'さ',
#   '演技力',
#   '亮',
#   'くん',
#   'みずがめ座',
#   'B型',
#   '水星人',
#   'new',
#   '人見知り',
#   '最近',
#   '浮上',
#   'ぎみ',
#   'フォロー'],
#  ['恋',
#   '愛',
#   'みんな',
#   '想像',
#   '以上',
#   '心のままに',
#   'Mr.Children',
#   '空',
#   '海',
#   '景色',
#   '花',
#   '日々',
#   '気軽',
#   'リプ',
#   'フォロー',
#   '歓迎',
#   '車',
#   '好き',
#   '空',
#   '好き',
#   'MrChildren',
#   'サブ垢',
#   'しるし',
#   '空',
#   'SZRf',
#   '4',
#   'I',
#   '0',
#   'dJI',
#   '8',
#   'Ed',
#   '3',
#   'T'],
#  ['アニメ',
#   '漫画',
#   'ツイート',
#   '多め',
#   'ガンプラ',
#   'メイン',
#   'スケール',
#   '物',
#   '地元',
#   'ゾンビ・フランシュシュ',
#   '地元',
#   '球団',
#   'ホークス',
#   '応援'],
#  ['成人',
#   '済',
#   '好き',
#   'もの',
#   '好き',
#   'おはぎ',
#   'アカウント',
#   '滅',
#   'まり',
#   'たて',
#   '原作',
#   'ファンブ',
#   '読了',
#   'バレ',
#   '発言',
#   '柱',
#   'さ',
#   'ねぎ',
#   'ゆ',
#   '幸せ',
#   'ねぎ',
#   'ゆ',
#   '普段',
#   '洋画',
#   '沼',
#   '二次',
#   '字',
#   '書き',
#   '端くれ'],
#  ['お仕事',
#   '多忙',
#   '犬',
#   '最近',
#   '極度',
#   '運動不足',
#   '基本',
#   '人',
#   '気分屋',
#   '布団',
#   '友達',
#   '稀',
#   'どこか',
#   'イベント',
#   'うちの犬',
#   '出て',
#   '中国語',
#   '翻訳',
#   'ちゃん',
#   '使用',
#   '英語',
#   'a',
#   'little',
#   '韓国語',
#   '翻訳機',
#   '使用',
#   'リク',
#   '犬',
#   '居候',
#   'I',
#   'have',
#   'a',
#   'dog',
#   'called',
#   'Riku'],
#  ['FF11',
#   'プリコネ',
#   'R',
#   '復帰',
#   'グラブル',
#   '休止',
#   '中',
#   '大好き',
#   '鈴木',
#   '愛奈',
#   'ちゃん',
#   '2021年',
#   '4月24日',
#   'ウマ娘'],
#  ['自分', 'アニメ', 'こと', '特撮', '作品', 'こと', 'アカウント'],
#  ['好き',
#   '勝手',
#   '手間',
#   '垢',
#   '分け',
#   '鳥海',
#   '有子',
#   'ちゃん',
#   'の',
#   '最近',
#   'もの',
#   'ウマ娘',
#   'ボンバーガール',
#   'ポンコツ',
#   'マス',
#   'ガル',
#   'カフェ',
#   'FGO',
#   'ミリ',
#   'デレ',
#   'マス',
#   'etc'],
#  ['者',
#   '社会',
#   '共産',
#   'ファシズム',
#   '趣味',
#   '者',
#   'ニート',
#   '佐藤優',
#   'ファン',
#   '椎名林檎',
#   'ファン',
#   '石原莞爾',
#   '満州国',
#   '大好',
#   '大正ロマン',
#   'スタディサプリ',
#   'スタディプラス',
#   'マジメ',
#   '勉強',
#   '中',
#   '2018年',
#   '小学校',
#   '勉強',
#   '制覇',
#   '2019年',
#   '中学',
#   '校',
#   '教科',
#   '2020年',
#   '12月14日',
#   '中学校',
#   '勉強',
#   '範囲',
#   '復習',
#   '沢山'],
#  ['JOIN', 'スピッツ', '衝撃', '的', '出会い', '大好き', '猫', '2', 'ひき', 'パーソナルトレーニング'],
#  ['失敗', 'NG'],
#  ['切り絵',
#   '無断転載',
#   '等',
#   '遠慮',
#   'LOVE',
#   'w-inds.',
#   'Da-iCE',
#   '米津玄師',
#   '向井太一',
#   'ハイキュー!!',
#   '鬼滅の刃',
#   '大人',
#   '6',
#   '面',
#   '素敵',
#   'アイコン',
#   'さ',
#   'nta',
#   '56'],
#  ['スイーツ',
#   '目',
#   'カフェラテ',
#   'の',
#   '生きがい',
#   'いす',
#   'スイーツ',
#   'いす',
#   'コスメ',
#   '当選',
#   '報告',
#   'いいね'],
#  ['旭',
#   '楽曲',
#   'アートワーク',
#   'CDジャケット',
#   '四月の魚',
#   'プロジェクト',
#   '大島',
#   'はるな',
#   '様',
#   '2021年',
#   '生誕',
#   '記念',
#   'イラスト',
#   '春乃',
#   'こね',
#   '子',
#   'タカハシ',
#   'ルイ',
#   '様',
#   'ミニアルバム',
#   '制作',
#   '決定',
#   '依頼',
#   'DM',
#   '自作',
#   '発言',
#   '無断転載',
#   '禁止'],
#  ['エンタメ',
#   '最高',
#   '鬼',
#   '滅',
#   'エヴァ',
#   '感涙',
#   '荒木飛呂彦',
#   '先生',
#   '鳥山明',
#   '先生',
#   '伊藤潤二',
#   '先生',
#   '山下しゅんや',
#   '先生',
#   'etc.',
#   '敬愛'],
#  ['カメラ',
#   '初心者',
#   '風景',
#   '中心',
#   'きれい',
#   '写真',
#   '私',
#   '好き',
#   '世界',
#   '写真',
#   '誰か',
#   '平日',
#   '医療',
#   '業界',
#   'お仕事',
#   'ため',
#   '写真',
#   '更新',
#   '子供',
#   '股関節',
#   '唇',
#   '損傷',
#   '修復',
#   '術',
#   '経過',
#   '良好',
#   'TDL',
#   '大好き',
#   '春畑道哉',
#   'さん',
#   '大好き',
#   'LIVE',
#   'スケーター',
#   'さん',
#   '応援',
#   '中'],
#  ['2012年',
#   '8月3日',
#   'ドラゴンクエストX',
#   'プレイ',
#   'プ',
#   '男',
#   'にしん',
#   'しん',
#   'ID',
#   'BZ',
#   '730',
#   '-2',
#   '50',
#   'フレ',
#   '随時',
#   '募集',
#   '家',
#   'トゥーン',
#   '3917',
#   '-1',
#   'サポ',
#   '登録',
#   '魔',
#   '使',
#   'Lv',
#   '113',
#   'まほう',
#   '杖',
#   '200',
#   '感染予防',
#   '対策',
#   'マスク',
#   '着用',
#   '中',
#   '2019年',
#   '10月',
#   '06',
#   '日',
#   'DQウォーク',
#   '継続',
#   '中',
#   'radiko',
#   'FM COCOLO'],
#  ['公認心理師',
#   '精神保健福祉士',
#   '社会福祉士',
#   '介護福祉士',
#   '高齢者',
#   '福祉',
#   '障害者',
#   '児',
#   '福祉',
#   '20年',
#   '相談',
#   '支援',
#   '専門',
#   '員',
#   '介護支援専門員',
#   '二刀流',
#   '発達障害',
#   '理解',
#   'サポート',
#   'こども',
#   '高齢者',
#   '福祉',
#   '情報',
#   '知識',
#   '発信',
#   '事',
#   '目的'],
#  ['東京', 'ゲゲゲィ', 'マカロニえんぴつ', 'キュウソネコカミ', '大好き', '札幌市', '在住', 'よろしくお願いします'],
#  ['コスプレ',
#   '造形',
#   '制作中',
#   '女装',
#   'しません',
#   '20',
#   'HAL名古屋',
#   'CT',
#   '13',
#   'A',
#   'CG',
#   'HAL',
#   '奴隷',
#   '現在',
#   '滅亡',
#   '迅雷',
#   '.net',
#   '接続',
#   '今後',
#   'コスプレ',
#   '造形',
#   '依頼',
#   'ダメ人間',
#   'https',
#   'co',
#   '4Q',
#   'Hq',
#   '9',
#   'EFC',
#   '7',
#   'k'],
#  ['アイマス',
#   'P',
#   '兼',
#   'マスター',
#   '兼',
#   '諸々',
#   'ソシャゲ',
#   '民',
#   '兼',
#   'ヘッポコ',
#   '小説',
#   '書き',
#   '1期',
#   'ハイパーヨーヨー',
#   '経験',
#   '復帰',
#   '勢',
#   'クソザコ',
#   '1',
#   'A',
#   '2',
#   'A',
#   '4',
#   'A',
#   '練習中',
#   'MTG',
#   'モダン',
#   'パイオニア',
#   '民'],
#  ['自公',
#   '維',
#   '反独裁',
#   '日々',
#   '皆様',
#   'ツイート',
#   '拝見',
#   '勉強',
#   '世の中',
#   '子供達',
#   '未来',
#   '為',
#   '無言',
#   'フォロー',
#   'お許し',
#   'RT',
#   '多め',
#   '広域',
#   '一元化',
#   '条例',
#   '反対',
#   '消費税',
#   '廃止',
#   'コロナ',
#   '収束',
#   '毎月',
#   '国民',
#   '皆',
#   '一律',
#   '給付',
#   '金',
#   'バナー',
#   '自由',
#   'DM',
#   '野党共闘',
#   '政権交代'],
#  ['UVERworld',
#   'FC',
#   '会員',
#   '夫婦',
#   '奈良',
#   'crew',
#   '長野',
#   'crew',
#   '愛方',
#   'crew',
#   'uwloveyou',
#   '1101',
#   'T.M.Revolution',
#   'abingdon boys school',
#   'REBORN',
#   '君に届け',
#   'ばらかもん',
#   'flat',
#   'ホリミヤ',
#   '書道',
#   'アート',
#   '不定期',
#   '作品',
#   'Up',
#   '最愛',
#   '息子',
#   'R2',
#   '6',
#   '10',
#   '生'],
#  ['BLACK',
#   'LIVES',
#   'MATTER',
#   'RT',
#   'heavy',
#   'world',
#   's',
#   'slowest',
#   'artist'],
#  ['トイガー',
#   '松井',
#   '今',
#   'プロレス',
#   '漫画',
#   '料理',
#   'I',
#   'm',
#   'Matsu',
#   'tora',
#   'Who',
#   'watch',
#   'Pro',
#   'wrestling',
#   'read',
#   'comic',
#   'and',
#   'cooking',
#   'トイガー',
#   'マスク',
#   'W',
#   'ネコゾクファイト',
#   'ネコソギ',
#   'ファイト',
#   '虎猫',
#   '飯'],
#  ['21歳', 'l', 'she', 'her', 'giyushinojpg'],
#  ['劇団',
#   '監督',
#   '兼',
#   'セカイ',
#   '住人',
#   '兼',
#   '人',
#   '理',
#   '修復',
#   'マスター',
#   '兼',
#   '審神者',
#   '森',
#   '民',
#   '好きな物',
#   'いっぱい'],
#  ['モデル',
#   'さん',
#   '意外',
#   '何処',
#   '気',
#   'モデル',
#   'さん',
#   'フォロー',
#   '通常',
#   '垢',
#   'Try',
#   'all',
#   'photo'],
#  ['作りました',
#   '紫電',
#   '隊',
#   '隊長',
#   '荒野行動',
#   'クラン',
#   'StWipe',
#   '最近',
#   '東雲',
#   'はる',
#   'shino',
#   'nome',
#   '22',
#   'サブ垢',
#   'MP',
#   'max',
#   '27',
#   'ミラティブ',
#   '配信',
#   'https',
#   'co',
#   'u2',
#   'hgLQA',
#   '9',
#   'f6'],
#  ['アーティスト',
#   '藍井エイル',
#   '内田',
#   '真礼',
#   'チコハニ',
#   'Roselia',
#   'RAISE',
#   'A',
#   'SUIREN',
#   '燐',
#   '舞曲',
#   '青木志貴',
#   '志崎樺音',
#   '夏芽',
#   'つんこ',
#   '直田姫奈',
#   '青木志貴',
#   'twitch',
#   'リスナー',
#   'デレマス',
#   '担当',
#   '最近',
#   'バンドリ',
#   '浮気',
#   '中',
#   '二宮',
#   '飛鳥'],
#  ['ゲーム',
#   'アニメ',
#   'スキ',
#   '中村悠一',
#   'さん',
#   '松岡禎丞',
#   'さん',
#   'V6',
#   'さん',
#   'etc.',
#   '好き',
#   '07',
#   'thLove',
#   '詩音',
#   '人',
#   '2b',
#   'ro',
#   '2010年'],
#  ['32', 'ほう', 'ロック', 'ω'],
#  ['typhon',
#   '鯖',
#   '生息',
#   'ふち',
#   'ごろ',
#   'へっぽこ',
#   '墨',
#   '魔道士',
#   '赤',
#   '魔',
#   '転向',
#   '人',
#   'フォローﾖﾛｼｸ',
#   '从',
#   '人',
#   'そこ',
#   'フォロー',
#   'ぽち',
#   '最近',
#   'DbDPC',
#   '版',
#   'プレイ'],
#  ['18',
#   '絵',
#   'ボカロ',
#   '垢',
#   'madoi',
#   'io',
#   'お題',
#   '箱',
#   'https',
#   'co',
#   'j3',
#   '71V',
#   'BDjX',
#   '2'],
#  ['丿貫',
#   '店長',
#   'ニラ',
#   '大将',
#   '青森',
#   '津軽',
#   '煮干',
#   '煮干',
#   '結社',
#   '東京',
#   '生まれ',
#   '津軽',
#   '煮干',
#   '育ち'],
#  ['杖',
#   '精神',
#   '病気',
#   'SHINee',
#   'アニメ',
#   '映画',
#   'だんな',
#   '友達',
#   '仲間',
#   '一緒',
#   '事',
#   '無言',
#   'フォロー',
#   '失礼',
#   'SHINee',
#   '杖',
#   '精神',
#   '病気',
#   'アニメ',
#   '映画'],
#  ['成人',
#   '済',
#   'ALTER',
#   'EGO',
#   '旅',
#   'エス',
#   'ガラスの仮面',
#   '麗',
#   'マヤ',
#   'うち',
#   '上司',
#   '情緒',
#   'ヤバい',
#   '不笠',
#   '安定',
#   '鍵',
#   'nxoa',
#   '784',
#   'e4',
#   'QVBwTE',
#   'アイコン',
#   'alteregoillust',
#   '様',
#   '・ヘッダー',
#   'mao',
#   'project',
#   '83',
#   '様'],
#  ['おたく', '手', '出して', 'ぼんやり', '成人', '済み'],
#  ['2020',
#   '9.',
#   '14',
#   'practice',
#   'English',
#   'Ziofiny',
#   'tig',
#   '溶接',
#   'yag',
#   '溶接',
#   '神',
#   '最近',
#   '嫁',
#   'Vtube',
#   'モーフィング',
#   '制作',
#   '手伝い',
#   'イラスト',
#   '復帰'],
#  ['ニコマス', 'P', '喫茶', '8765'],
#  ['懸賞',
#   '好き',
#   '懸賞',
#   'アカ',
#   'sport',
#   'food',
#   'travel',
#   '何',
#   '好きな人',
#   'RT',
#   'たくさん',
#   '無言',
#   'フォロー',
#   '失礼',
#   '懸賞',
#   '好き',
#   'さん'],
#  ['落ち着き', '三十路', 'OL'],
#  ['KAZE',
#   'JAPAN',
#   'RECORD',
#   'OFFICIAL',
#   'Music',
#   'that',
#   'express',
#   'es',
#   'good',
#   'old',
#   'Japan',
#   'pictorially',
#   'and',
#   'visually',
#   'To',
# ...
#   '滅',
#   'とっく',
#   '昔',
#   '成人',
#   '済'],
#  ['ガンプラ',
#   '猫',
#   '好き',
#   'よろしくお願いします',
#   'ワルキューレ',
#   '好き',
#   '安野',
#   '家',
#   'ファンクラブ',
#   'じゅん',
#   '６',
#   'くみ',
#   'ファンクラブ',
#   '入会',
#   '小松未可子',
#   'さん',
#   'ファン',
#   '西田望見',
#   'さん',
#   'マキナ・中島',
#   'ちゃん',
#   'ファン',
#   '魂',
#   '会員',
#   '5年目'],
#  ['小学2年生',
#   '娘',
#   '12歳',
#   '愛犬',
#   '子育て',
#   '中',
#   'ナース',
#   'ママ',
#   '音楽',
#   'ドライブ',
#   'アイス',
#   'お酒',
#   '海',
#   '空',
#   'ディズニー',
#   'スヌーピー',
#   '話',
#   '大好き',
#   'iPhone',
#   '写真',
#   '練習中',
#   'うち',
#   'ご飯',
#   '気まぐれ',
#   'アップ'],
#  ['青森県',
#   '在住',
#   'Chappy',
#   '男の子',
#   '2人',
#   'ママ',
#   '愛猫',
#   '２',
#   '頭',
#   '現在',
#   '子育て',
#   '余裕',
#   '飼い猫',
#   'かわいそう',
#   '猫',
#   '達',
#   '１',
#   '匹',
#   'ため',
#   '無言',
#   'フォロー',
#   'ツイート',
#   '動物虐待',
#   '反対',
#   '殺処分',
#   'ゼロ',
#   '動物',
#   '環境に優しい',
#   '国',
#   'ねぶた祭り',
#   '青森大',
#   '好き'],
#  ['弓',
#   '使い',
#   '動物',
#   '全般',
#   'うさぎ',
#   '家',
#   '丹羽',
#   '智則',
#   'さん',
#   '横川',
#   '結城',
#   'さん',
#   '応援',
#   'ナゴヤ',
#   '座',
#   '参',
#   '駄',
#   '右衛門',
#   'さん',
#   '参',
#   '十',
#   '音楽',
#   'オルタナ',
#   '好き',
#   'ラバッパー',
#   '時',
#   'ヒプノシスマイク',
#   '名古屋おもてなし武将隊',
#   '写真',
#   '無断転載',
#   'お断り',
#   'ヘッダー',
#   'モル',
#   'カー',
#   '公式',
#   '使用',
#   '許可',
#   '画像'],
#  ['福岡県久留米市',
#   '在住',
#   'みずき',
#   '主',
#   '鉄道',
#   '街',
#   '話題',
#   '豆知識',
#   '木曜',
#   '金曜',
#   'ラジオ',
#   '実況',
#   '旅行',
#   'ゲーム',
#   '系',
#   '漫画',
#   'アニメ',
#   'コスプレ',
#   '好き',
#   'コス',
#   '衣装',
#   '服も',
#   '守備範囲',
#   '47都道府県',
#   '最低',
#   '1回',
#   'づつ',
#   '訪問',
#   '済',
#   '2016',
#   '5',
#   '4',
#   'みずき',
#   '本名',
#   'ありません'],
#  ['大好き',
#   'アニメ',
#   'ファッション',
#   'テーマ',
#   '活動',
#   'アニメ',
#   'アニソン',
#   '声優',
#   'ゲーム',
#   'コスプレ',
#   'オタク',
#   '皆',
#   '友達',
#   'コーデ',
#   'WEAR',
#   'URL',
#   '気軽'],
#  ['28',
#   'she',
#   'her',
#   'half',
#   'multi',
#   'fandom',
#   "μ's",
#   'nijigaku',
#   'maki',
#   'and',
#   'karin',
#   'oshi',
#   'FFXIV',
#   'serayomi',
#   'twice',
#   'ENG',
#   '日本語',
#   'OK',
#   'icon',
#   'by',
#   'yomi',
#   '043'],
#  ['method',
#   'to',
#   'the',
#   'madness',
#   'Writer',
#   'Correspondent',
#   'NewsByCatalyst',
#   'co',
#   'host',
#   'W3',
#   'D',
#   'Show',
#   'wabi',
#   'sabi',
#   'i',
#   'm',
#   'not',
#   'just',
#   'a',
#   'pretty',
#   'face',
#   'people',
#   'sit',
#   'on',
#   'phil',
#   'dunphy'],
#  ['ヌンチャン', 'たま', '絵', '最近', 'メギド', 'バトスピ', '勢'],
#  ['dustbox',
#   'HEY-SMITH',
#   'MAN WITH A MISSION',
#   '10-FEET',
#   'SHANK',
#   'UNISON SQUARE GARDEN',
#   'WANIMA',
#   'ライブ',
#   '生き甲斐',
#   '邦',
#   'ロック',
#   '大好き',
#   '最近',
#   'dustbox',
#   'TAKUMA',
#   'さん',
#   'SUGA',
#   'さん',
#   'どちら',
#   '大好き'],
#  ['アンケート',
#   '屋',
#   '本業',
#   'マーケティングコンサル',
#   '自称',
#   'テント',
#   '生活',
#   '男',
#   '政治',
#   '系',
#   'YouTuber',
#   '自己紹介',
#   '動画',
#   'https',
#   'co',
#   'Exar',
#   '6',
#   'UvAR',
#   '7'],
#  ['全て', 'こと', 'にわか', 'rabbitium'],
#  ['お絵描き', 'ゲーム', '雑多', '垢', '成人', '済'],
#  ['獣', '虫', '好き', '変態', '日常', 'アカウント', 'BL', '死骸', 'もの', '好き', '死骸', '写真'],
#  ['クルマ', '6', '14', '鈴鹿', 'フル'],
#  ['26歳',
#   'OL',
#   '映画',
#   '舞台',
#   'アカウント',
#   'ミュージカル',
#   'MCU',
#   'アニメ',
#   'みなさま',
#   'おすすめ',
#   '映画'],
#  ['煉獄',
#   'さん',
#   '成人',
#   '済み',
#   '原作',
#   '好き',
#   '劇場版',
#   '煉獄',
#   'さん',
#   'すべて',
#   '6回',
#   '乗車',
#   'いっとう',
#   '好き',
#   'かまぼこ',
#   '隊',
#   '煉獄',
#   '家',
#   'げん',
#   '兄弟',
#   'カナ',
#   '原作',
#   'CP',
#   '好き',
#   'RT',
#   '無言',
#   'フォロー',
#   '素敵',
#   '作品'],
#  ['初心者',
#   'ブログ',
#   '収益',
#   '化',
#   '身',
#   '情報',
#   '配信中',
#   '子',
#   '夢',
#   'ため',
#   'ブログ',
#   '総収',
#   '益',
#   '100万円',
#   '以上',
#   '達成',
#   'キーワード',
#   '基礎',
#   '大事',
#   'ブログ',
#   '楽天',
#   'アマゾン',
#   'キャッシュ',
#   'ポイント',
#   'の',
#   '得意',
#   'メルマガ',
#   '登録',
#   'ブログ',
#   '収益',
#   '化',
#   '身',
#   '豪華',
#   '４',
#   '特典',
#   'https',
#   'co',
#   'v',
#   '5',
#   'kwrQMR',
#   '0',
#   'G'],
#  ['成人',
#   '済',
#   '猫',
#   '歌',
#   'DAMとも',
#   'カフェ',
#   '巡り',
#   'https',
#   'co',
#   'PonhiZnsMX',
#   'マンガ',
#   '素敵',
#   '絵',
#   'プチプラコスメ',
#   'シャン',
#   'トリ',
#   'スイーツ',
#   'カフェラテ',
#   'チョコミント',
#   '野球',
#   '虎',
#   'フィギュア',
#   'バレー',
#   'とうらぶ',
#   'ミュステ',
#   'twst',
#   'レオナ',
#   'さん',
#   'フロイドジャミル',
#   'くん',
#   'レンチン',
#   '料理',
#   '呪術',
#   'コミックス',
#   '派'],
#  ['時', '応援', 'アカウント', 'ハラミちゃん', 'まみむめも', 'ちお', 'のんちゃん', 'キズナアイ', 'loveちゃん'],
#  ['tarkov'],
#  ['高校', '時', 'マサイ', 'いた事', 'w/', '最近', 'ライブ', '三昧'],
#  ['常習犯',
#   'パズドラー',
#   '目標',
#   'ランク',
#   '1100',
#   'アニメ',
#   'パズドラ',
#   '好き',
#   'パズドラー',
#   'フォロバ',
#   '100%',
#   '理',
#   '課金'],
#  ['兼業',
#   'フォトグラフ',
#   '美術史',
#   '現代アート',
#   '魅了',
#   '半人前',
#   'コレクター',
#   '美術館',
#   'アートフェア',
#   '定期',
#   '本業',
#   '携帯',
#   '会社',
#   '5G',
#   'VR',
#   '領域',
#   'サービス',
#   'プランナー',
#   'フォト',
#   'アート',
#   '価値',
#   '転換',
#   '基本',
#   '写真',
#   'アート'],
#  ['メイン', '坂道', 'J', '兼', 'サブ', 'sabumaru', '0025'],
#  ['歳',
#   '２',
#   '０',
#   '刀剣乱舞',
#   'うた',
#   'ぷり',
#   '聖川真斗',
#   '担',
#   'その他',
#   '何',
#   '漫画',
#   '大好き',
#   'q',
#   '系',
#   'ゎ',
#   '無縁',
#   'Twitter',
#   '初心者',
#   '勝手',
#   'ふぁ',
#   'RT',
#   'フォロー',
#   '失礼'],
#  ['山下誠一郎',
#   '荒牧慶彦',
#   '鬼',
#   '滅',
#   '一郎',
#   '累',
#   'スタマイ',
#   '亜貴',
#   '慶ちゃん',
#   'A3',
#   '至',
#   '万里',
#   '千景',
#   'ウマ娘',
#   'ツインダーボ',
#   'あん',
#   'スタ',
#   '朔',
#   '間',
#   '兄弟',
#   '刀',
#   'ラブ',
#   '薬研',
#   '山姥',
#   '切',
#   'etc',
#   'ww',
#   '20'],
#  ['ゲーム',
#   'バイオ',
#   '大好き',
#   '人',
#   '腐女',
#   '婆',
#   '40',
#   'BL',
#   '好き',
#   '編み物',
#   '大好き',
#   '主',
#   'かぎ針',
#   'シュシュ',
#   '作り',
#   '趣味',
#   '編み物',
#   'YouTube',
#   '動画',
#   '勉強',
#   '中',
#   '棒',
#   '針',
#   '挑戦'],
#  ['フットサル',
#   '酒',
#   'ガールズ・エンタテイメントユニット',
#   'トキヲイキル',
#   '所属',
#   '大庭彩歌',
#   'さん',
#   'ただ',
#   '老人',
#   '最近',
#   'ドゲンジャーズ',
#   '基本',
#   'おーば',
#   'or',
#   'あや',
#   '人',
#   '応援',
#   '大好物',
#   '高菜',
#   '職業',
#   '大庭彩歌',
#   'さん',
#   '幽波紋',
#   'おーば',
#   'ちゃーん',
#   '能力',
#   '座右の銘',
#   '薬'],
#  ['ナチュラル',
#   '大好き',
#   'コンセプト',
#   '楽天',
#   'ブログ',
#   '楽天',
#   'ROOM',
#   '活',
#   'フォロー',
#   '気軽',
#   'よろしくお願いします',
#   '無言',
#   'フォロー',
#   'お許し',
#   '楽天',
#   'Twitter',
#   'Amazon',
#   'サブ垢',
#   'aoringo',
#   'heart'],
#  ['もの', '皆', '共有', 'あなた', 'いいもの', '宣伝', '万', '垢', 'フォロバ', 'フォロー', 'お願い'],
#  ['プライド', '絶対'],
#  ['アイコン',
#   'ykr',
#   '608',
#   '銀髪',
#   '褐色',
#   '赤髪',
#   '八重歯',
#   '狼',
#   '系',
#   '男',
#   '大好き',
#   '成人',
#   '済'],
#  ['福井県',
#   '伝統工芸',
#   '応援',
#   '福井',
#   '様々',
#   '魅力',
#   'エンターテインメント',
#   'アイドルグループ',
#   'ステージ',
#   'パフォーマンス',
#   'イベント',
#   'MC',
#   'リポーター',
#   'モデル',
#   '出演',
#   '新規',
#   '企画',
#   '運営',
#   '商品開発',
#   '宣伝',
#   '気軽',
#   'DM',
#   '相談',
#   '追加',
#   'メンバー募集'],
#  ['YOU',
#   'TUBE',
#   'スパルタ',
#   '検索',
#   'ｵﾈｼｬｽ',
#   '相棒',
#   'minesandazo',
#   'kiru',
#   '6',
#   '所属事務所',
#   'https',
#   'co',
#   'lbFPZWc',
#   '9',
#   'YD',
#   'サブ',
#   'kyoutei',
#   '4545',
#   '下心',
#   'https',
#   'co',
#   'WdP',
#   '4k',
#   'BFFvz'],
#  ['一日',
#   '三食',
#   '五',
#   '十',
#   '品目',
#   'わたし',
#   '最強',
#   'バナナ',
#   '乳製品',
#   '脳',
#   '活性',
#   '化',
#   'ん',
#   '手',
#   '大切',
#   'たま',
#   '名乗り',
#   'ドジっ子',
#   '落ち着き',
#   '戦車道',
#   '乙女',
#   'たしなみ',
#   'アイコン',
#   '艦隊',
#   'ヒュウガ',
#   'さん'],
#  ['マチカネタンホイザ',
#   'プログノーシス',
#   'グレナディアガーズ',
#   'マルターズディオサ',
#   'ホウオウイクセル',
#   'ダイワクンナナ',
#   'プロスピ',
#   '広島',
#   '純正',
#   '24回',
#   '最強',
#   '決定',
#   '戦',
#   'オリックス',
#   '3位'],
#  ['おさむ',
#   '兄',
#   'ゆう子',
#   '姉',
#   'ただ',
#   'おたく',
#   '男子',
#   '二',
#   '人',
#   '働きマン',
#   '好き',
#   '松澤由美',
#   '奥村愛子',
#   '高',
#   '瀬綾',
#   '早稲田ちえ',
#   'ウレロ',
#   '戦国鍋',
#   '深夜ラジオ',
#   'etc'],
#  ['i', 'just', 'wanna', 'be', 'a', 'little', 'part', 'of', 'your', 'memory'],
#  ['下野紘', 'さん', '大好き', '応援', '声優', '夜あそび', '大好き', '他', '声優さん', '応援'],
#  ['犬', '柱', 'ワン', '呼吸'],
#  ['本垢',
#   '凍結',
#   '異議',
#   '申立',
#   '中',
#   '為',
#   '転生',
#   'ｴﾛｽ',
#   '漫画家',
#   '胡桃屋ましみん',
#   '阪神',
#   '虎',
#   '温泉',
#   'おっぱい',
#   'ご飯',
#   '並み',
#   '好き',
#   '現在',
#   'ペンギンクラブ',
#   '等',
#   '執筆',
#   '中',
#   '是非',
#   '一読',
#   '…。',
#   '18歳',
#   '未満',
#   'フォロー',
#   '閲覧',
#   '禁止',
#   '電',
#   '書',
#   '単行',
#   '本',
#   'FANZA',
#   'https',
#   'co',
#   'OF',
#   '5',
#   'OOuZfVe',
#   'PIXIV',
#   'https',
#   'co',
#   'hfYh',
#   '1',
#   'inJr',
#   '0'],
#  ['pkmn',
#   'pksp',
#   'fate',
#   'マンキン',
#   'エヴァ',
#   '銀英伝',
#   'ベルセルク',
#   'AKIRA',
#   '好き',
#   '男女',
#   'CP',
#   'リバ',
#   '雑食',
#   '腐女子',
#   '成人',
#   '済',
#   'インド',
#   '話',
#   '飯',
#   '話',
#   'Web',
#   'デザイナー',
#   '勉強',
#   '中',
#   '近況',
#   'リィンカネ',
#   '銀英伝',
#   '垢',
#   'Cabo',
#   'Gin',
#   'FGO',
#   '垢',
#   'Retwo',
#   '22'],
#  ['シャヲル',
#   'E',
#   'L',
#   'F',
#   'ﾋﾞｷﾞ',
#   'ジョンキーペン',
#   'ウネペン',
#   'ユノペン',
#   'shinee',
#   'sline',
#   '会',
#   '3322'],
#  ['成人',
#   '済',
#   '腐女子',
#   '型',
#   '月',
#   'あん',
#   'スタ',
#   '刀剣乱舞',
#   '文',
#   'アル',
#   'ヒプマイ',
#   '千銃士',
#   '５',
#   '人格',
#   'あみだ',
#   '仏',
#   '鬼',
#   '滅',
#   'まほ',
#   'ツイステ',
#   '娘',
#   'その他',
#   '基本',
#   '雑食',
#   'たま',
#   '字',
#   '書き'],
#  ['LOVE',
#   '特撮',
#   'プロレス',
#   'マンガ',
#   'ラウドロック',
#   'アクション映画',
#   'マーベル',
#   '系',
#   '麺類',
#   '主',
#   'ラーメン',
#   '酒',
#   '家飲み',
#   '長崎',
#   '水曜どうでしょう',
#   'ロボットアニメ',
#   'HATE',
#   '身勝手',
#   '奴',
#   '道義',
#   '奴',
#   '理不尽',
#   '奴',
#   'コロナ',
#   'YouTube',
#   '広告'],
#  ['30代',
#   '家族',
#   '経営',
#   '会社',
#   '承継',
#   '日々',
#   '奮闘',
#   '中',
#   '基本的',
#   '実践',
#   '事',
#   '実践',
#   '中',
#   '株',
#   '債券',
#   '不動産',
#   'FX',
#   '家計',
#   '管理',
#   'ダイエット',
#   '古本',
#   'せどり',
#   '今後',
#   'こと',
#   '楽天ポイント',
#   'せどり',
#   '簿記',
#   '3級',
#   '2級',
#   '取得'],
#  ['SMAP',
#   '新しい地図',
#   '香取慎吾',
#   'Junsu',
#   '鹿',
#   '呪',
#   '刃',
#   'shipper',
#   '20',
#   '95',
#   'line',
#   '雑食'],
#  [],
#  ['社会人',
#   '不器用',
#   '田舎',
#   '出身',
#   '貴重',
#   '２',
#   '連休',
#   '以上',
#   '休日',
#   '漫画',
#   '映画',
#   '旅行',
#   '神社',
#   '城',
#   '三',
#   '幸福',
#   '食い意地',
#   '一人前'],
#  ['NICO Touches the Walls',
#   '9mm Parabellum Bullet',
#   'DA PUMP',
#   'COACH',
#   '好き',
#   '柴犬',
#   'ジェフサポ・',
#   '工藤浩平',
#   '信者',
#   '山岸智',
#   'ぐう聖',
#   '今',
#   '鬼滅の刃'],
#  ['気分',
#   '無言',
#   'フォ',
#   '口',
#   'フォロバ',
#   'リムバ',
#   '100%',
#   '親友',
#   '蟹',
#   '友',
#   'TheBIoodRain',
#   'MMD',
#   '動画',
#   '垢',
#   'Acceler',
#   '97',
#   'なりきり',
#   '垢',
#   'YoucantkillXXX',
#   '兄ちゃん',
#   'redqueenAZ',
#   'ペア画',
#   'ヘッダー',
#   '信仰',
#   '対象',
#   'hinatanata',
#   '1021',
#   'あと',
#   '教',
#   '葵',
#   '葉',
#   'カラオケ',
#   '部屋'],
#  ['IT',
#   '屋',
#   '大阪',
#   '秋葉',
#   'フリー',
#   '食事',
#   '当番',
#   '英',
#   '日',
#   '字幕',
#   '駆け出し',
#   '全国通訳案内士',
#   'Hawks',
#   '多め',
#   '将棋',
#   '多め',
#   'w',
#   'NHK',
#   '番組',
#   '定期',
#   '相撲',
#   '花',
#   '公園',
#   '動物',
#   '映画',
#   'vfk',
#   'movies',
#   'Volunteer',
#   'Guide',
#   'in',
#   'Tokyo',
#   '3',
#   'months',
#   'Philly',
#   '舒',
#   '畅',
#   '魔',
#   '幻',
#   '手',
#   '机',
#   '学',
#   '习汉',
#   '语加',
#   '油',
#   '吧'],
#  ['グレン', '草原', '1219', '5', 'うち'],
#  ['高2',
#   '夢女子',
#   '腐女子',
#   '自衛',
#   '基本',
#   'フォロバ',
#   '無言',
#   'フォロー',
#   '素敵',
#   'アイコン',
#   'yamabuki',
#   '7',
#   '11',
#   'コス',
#   'niboshi',
#   '1206',
#   '二次創作',
#   '中心',
#   'twst',
#   '熱',
#   '無償',
#   '依頼',
#   '停止'],
#  ['BREMEN',
#   'ジャニーズ',
#   'Hey!Say!JUMP',
#   '伊野尾',
#   '慧',
#   '川崎フロンターレ',
#   '山根',
#   '視',
#   '来',
#   '阿部浩之'],
#  ['フォロバ',
#   'フォロー',
#   'お願い',
#   'かって',
#   'フォロー',
#   'イラスト',
#   'Honeyworks',
#   '大好き',
#   '鬼滅の刃',
#   '大好き',
#   'アナログ',
#   'デジタル',
#   'フォロバ'],
#  ['チェック',
#   '仕事',
#   '上',
#   '返信',
#   '連絡',
#   '可能性',
#   '交換',
#   '譲渡',
#   '等',
#   '点',
#   'ﾏﾅｰ',
#   '違反',
#   'ましら',
#   '教授',
#   'FF',
#   '不安',
#   '方',
#   'フリマ',
#   '対応',
#   '可能',
#   'ツイフィ',
#   '一読',
#   'お願い',
#   'トラブル',
#   '防止',
#   '為',
#   'お手数'],
#  ['何',
#   '能條愛未',
#   '井上小百合',
#   '鈴木絢音',
#   '応援',
#   '絢音',
#   'ちゃん',
#   '舞台',
#   '才能',
#   '基本的',
#   '乃木坂46',
#   '箱推し',
#   '趣味',
#   'スポーツ観戦',
#   '何',
#   'サッカー',
#   '浦和',
#   '応援',
#   'バドミントン',
#   '好き',
#   'Twitter',
#   'よっと'],
#  ['大人',
#   '艶',
#   '美魔女',
#   '採用',
#   'メンズエステ',
#   '美魔女',
#   'refle',
#   '店舗',
#   'スタッフ',
#   'H',
#   'Twitter',
#   '限定',
#   '極秘',
#   '情報',
#   '等',
#   '皆様',
#   '発信',
#   'TEL',
#   '090',
#   '-1',
#   '020',
#   '0024',
#   '堺筋本町',
#   '梅田',
#   'メンズエステ',
#   'ミセス',
#   '谷町四丁目',
#   'マンション',
#   'エステ'],
#  ['ネットラジオ',
#   'ポッドキャスト',
#   '対応',
#   '16年目',
#   '14周年',
#   'そこ',
#   '15周年',
#   'HOTCAST',
#   '最終回',
#   '配信',
#   '音声',
#   'コンテンツ',
#   '作成',
#   'チーム',
#   'HOTCAST',
#   'WAVE',
#   '代表',
#   'パーソナリティ',
#   'プロデュース',
#   'たま',
#   '飯テロ',
#   'うち',
#   '居酒屋'],
#  ['Artist',
#   'Multifandom',
#   'Random',
#   'posts',
#   'NSFW',
#   'Acc',
#   'michhorny',
#   'All',
#   'support',
#   'are',
#   'very',
#   'much',
#   'appreciated'],
#  ['気まま', '謳歌', '日々', 'ッ'],
#  ['主',
#   '野球',
#   '坂道',
#   '高山一実',
#   '梅澤美波',
#   '土生瑞穂',
#   '森田',
#   'ひかる',
#   '齊藤京子',
#   '浮上',
#   '愛嬌',
#   'KIMAMALabo',
#   'ume',
#   '1',
#   'st',
#   'minami',
#   'きょんこ',
#   'Kyoko',
#   '1',
#   'st',
#   'GRX',
#   '130'],
#  ['マリーンズ',
#   'ジェフ',
#   '好き',
#   'info',
#   'shinboshi',
#   'info',
#   'bbdb',
#   '陽色',
#   '2021',
#   '6月',
#   '目標',
#   'リズム感'],
#  ['jjba',
#   '雑食',
#   '20',
#   'R-18',
#   'アイコン',
#   'ヘッダー',
#   'https',
#   'co',
#   'BXqmPxoISY',
#   '18',
#   'G',
#   'ss',
#   'ss',
#   'on_',
#   'mon'],
#  ['ninguém'],
#  ['情緒', '安定', 'しない', 'ゴミ', '絵師'],
#  ['ハッピー', '陰キャ', 'life'],
#  ['猫',
#   '東方Project',
#   '音ゲー',
#   '高2',
#   '絵描き',
#   'さん',
#   '大好き',
#   '結晶',
#   '絵',
#   '私的',
#   'no.1',
#   '絵師',
#   'yumetuki',
#   '24',
#   'フォロワー',
#   '1号',
#   'yairooooooo',
#   '神奈川',
#   '民'],
#  ['映画', '海外ドラマ', '好き', 'ハリウッド映画', '阪神ファン'],
#  ['エウ',
#   '゙',
#   'ァンケ',
#   '゙',
#   'リオン',
#   'RQ',
#   '2017',
#   '真希波・マリ・イラストリアス',
#   '役',
#   '今後',
#   'アーティスト',
#   '活動',
#   'YouTube',
#   'えり',
#   'ゲーム',
#   '部屋',
#   '音楽',
#   'アニメ',
#   'ゲーム',
#   '漫画',
#   '洋画',
#   '韓',
#   'ドラ',
#   '好き',
#   '150',
#   '0043',
#   '東京都渋谷区道玄坂',
#   '1丁目',
#   '16',
#   '6',
#   '5',
#   'F',
#   '株式会社',
#   'BIG',
#   'ISLAND',
#   'RECORDS',
#   '津島衣里',
#   '宛'],
#  ['前',
#   'アカウント',
#   'kongou',
#   'd',
#   '凍結',
#   '不便',
#   'ところ',
#   '本垢',
#   '復活',
#   'こっち',
#   'サブ',
#   'デレ',
#   '北条',
#   'ｶﾛ',
#   '蓮',
#   'その他',
#   'シャニ',
#   '樋口円香',
#   'その他',
#   '・',
#   'ミリ',
#   '高坂',
#   '海美'],
#  ['Simple',
#   'twitto',
#   'passionné',
#   'd',
#   'an',
#   'imation',
#   'japonaise',
#   'aime',
#   'bien',
#   'les',
#   'grorobots',
#   'seiyuphile',
#   'voxophile',
#   'sympathique',
#   'shitposter',
#   'à',
#   'ses',
#   'heures',
#   'perdues',
#   'PV',
#   'Kilolo',
#   '925'],
#  ['2021年', '開始'],
#  ['カルデアマスター',
#   '兼',
#   'ヒカセン',
#   '20',
#   'ラムウ',
#   '鯖',
#   'FF14',
#   'タンク',
#   '性懲り',
#   'エロ',
#   'RT',
#   '18歳',
#   '未満',
#   'ブロック',
#   'アイコン',
#   'しん',
#   'ズゥ',
#   'sinzu',
#   'u',
#   '19',
#   'さん',
#   'もの'],
#  ['ドラゴンボール', 'ヒロアカ', '仮面ライダー', '等', 'フィギュア', 'プラモ', 'ガチャ', 'ハマッ'],
#  ['巌',
#   '縁本',
#   '蝕',
#   '罪',
#   'https',
#   'co',
#   'TAhho',
#   '4',
#   'iIsq',
#   '鬼滅の刃',
#   '継国',
#   '兄弟',
#   '主',
#   '巌',
#   '縁',
#   '実玄',
#   '義',
#   '炭',
#   'MHA',
#   '轟',
#   '出',
#   '心',
#   '出',
#   '炎',
#   'ホ',
#   'セーラームーン',
#   '星',
#   'うさ',
#   'YOI',
#   'ピチ',
#   '勇',
#   'ヒプマイ',
#   '幻',
#   '寂乱',
#   'SK'],
#  ['シナリオライター',
#   '映画',
#   '大好き',
#   'XJAPAN',
#   'ファン',
#   '表現の自由',
#   'アナ雪2',
#   '劇場',
#   '鑑賞',
#   '回数',
#   '123回',
#   '映画',
#   'ブログ',
#   'https',
#   'co',
#   '6',
#   'f9',
#   'u',
#   '6',
#   'LvX',
#   '62',
#   'ようつべ',
#   'https',
#   'co',
#   'HVqg',
#   '4',
#   'ELOfY'],
#  ['ゲーム',
#   'アニメ',
#   '予定',
#   'ゲーム',
#   'スクスタ',
#   'スクフェス',
#   'ショバフェス',
#   'プロセカ',
#   'アニメ',
#   'ゾンサガ',
#   'シャドーハウス',
#   '異世界',
#   'その他',
#   'こと'],
#  ['大阪',
#   '道頓堀',
#   'TSUTAYA',
#   'OPEN',
#   '10',
#   '00',
#   'CLOSE',
#   '20',
#   '00',
#   'TEL',
#   '06',
#   '6214',
#   '6262',
#   'B1',
#   'F',
#   'BOOK',
#   'COMIC',
#   'CD',
#   'DVD',
#   '3',
#   'F',
#   'ｃｏｓｍｅ',
#   'STORE',
#   'DM',
#   '返信',
#   '問い合わせ',
#   '電話'],
#  ['ワタユタケ', '安全地帯', 'DAITA', '氷室京介', 'いちむじん'],
#  ['成人',
#   '済',
#   'wj',
#   '本誌',
#   '派',
#   '無断転載',
#   '使用',
#   '禁止',
#   'All',
#   'rights',
#   'reserved',
#   'ﾂｲﾌｨ',
#   'https',
#   'co',
#   '62',
#   'IpjKaqLP',
#   'ブロマンス',
#   '地雷',
#   '自衛',
#   '済',
#   'kmt',
#   'jjt',
#   'twst',
#   'hrak',
#   '不滅',
#   '無言',
#   'フォロー',
#   'OK',
#   'わたし'],
#  ['カーディスト', 'マギレコ'],
#  ['ねこ', 'まんが', 'アニメ', 'ゲーム', '好き', '愛車', 'smart', '引用', 'RT', 'ノーサンキュー'],
#  ['高坂',
#   '高海',
#   '伊波',
#   'さん',
#   'サイレンススズカ',
#   'アイコン',
#   '上林',
#   '先生',
#   'mushiyaki',
#   'たま',
#   '遊戯王',
#   'PSO2',
#   'ngs'],
#  ['ポケモンマスター',
#   'ガンダム',
#   'パイロット',
#   'の',
#   '夢',
#   '暇',
#   'お気に入り',
#   'YouTuber',
#   '発掘',
#   'ダイヤ',
#   '原石',
#   'よう',
#   '最近',
#   'マイブーム',
#   'フィギュア',
#   '集め',
#   '荒野行動',
#   'apex'],
#  ['三国志大戦',
#   '現在',
#   '十',
#   '陣',
#   '好き',
#   '武将',
#   '王平',
#   '陳到',
#   '馬岱',
#   '姜維',
#   '現在',
#   'ダイエット',
#   '中',
#   '目標',
#   '65kg',
#   'FPS'],
#  ['趣味',
#   '用',
#   '垢',
#   '返信',
#   'RT',
#   '中心',
#   'ALM',
#   '緊縮',
#   'DM',
#   '遠慮',
#   'ユーラシア主義',
#   '者',
#   'BCE',
#   '500',
#   'CE',
#   '2020',
#   '古今東西',
#   'ユーラシア',
#   'JR',
#   'RT',
#   '系',
#   '古典派',
#   'ファンタジー',
#   '作品',
#   'Military',
#   'Police',
#   'ネタ',
#   '映画',
#   '好き',
#   'Gamer',
#   '大東流',
#   '棒',
#   '杖',
#   '仕事',
#   '動物',
#   '関係',
#   '制作',
#   'アンチ',
#   '機械的',
#   'フォロバ'],
#  ['SHiNë', 'さん', 'シィナン', 'みんな', 'ヤギ', 'ハンター', 'たい系'],
#  ['嫁', 'PC', '前', '夢'],
#  ['ゲーム',
#   '好き',
#   'アカウント',
#   '使用',
#   'アイコン',
#   'イラスト',
#   'イラストレーター',
#   '方',
#   '依頼',
#   '転載',
#   '転用'],
#  ['好き',
#   'もの',
#   '家',
#   '肉',
#   '布',
#   '服',
#   '作り',
#   '刺繍',
#   'SHINee',
#   'オンキーペン',
#   '土岐麻子',
#   'さん',
#   '大河ドラマ',
#   '関西',
#   'シャヲル',
#   'さん',
#   '知り合い',
#   '刺しゅう'],
#  ['無言',
#   'フォロー',
#   '失礼',
#   'テレビ番組',
#   '感想',
#   'ゲーム',
#   '近況',
#   'イマソラ',
#   '等',
#   'ツィート',
#   'クラロワ',
#   'ブロスタ',
#   'イマソラ',
#   '相互',
#   '固定',
#   'RT',
#   'フォロバ',
#   '100',
#   'NiziU',
#   'エロ',
#   '系',
#   'NG',
#   'DM',
#   'お断り'],
#  ['HoneyWorks',
#   '中',
#   '高校生',
#   '声優',
#   'ayasa',
#   'ito',
#   'さん',
#   'SAO',
#   '同好会',
#   'NO.6',
#   '9',
#   '姉',
#   'kr',
#   '1202',
#   '弟',
#   'maccha',
#   'yuratami',
#   '兄',
#   'Rito',
#   '63888936',
#   '妹',
#   'xxr',
#   '1',
#   'u',
#   'プロスピ',
#   '垢',
#   'CROW',
#   'purosupi',
#   'サブ垢',
#   '勉強',
#   '垢',
#   'Midori',
#   'study',
#   '2'],
#  ['F&M', '会員', 'Free!', '猫', '型', 'ロボ'],
#  ['沈黙は金', '雄弁は銀', '私', '土'],
#  ['趣味垢'],
#  ['OC',
#   'talk',
#   'etc.',
#   '25',
#   'Bi',
#   'nsfw',
#   'ecc',
#   'h1b',
#   'ao',
#   'Steven',
#   'Stone',
#   'fan',
#   'girl'],
#  ...]

# %% [markdown]
# ## 11-02 データ行列の作成
# * NMFの場合、TF-IDFで単語の重みを求めて各文書をベクトル化する。
# * LDAの場合、単に単語の出現頻度を重みとして各文書をベクトル化する。

# %% [markdown]
# ### sklearnのCountVectorizerで疎行列化する

# %% [markdown]
# * 全文書の半分より多い文書に現れる単語は、高頻度語とみなして削除する。
# * 10件未満の文書にしか現れない単語は、低頻度語とみなして削除する。

# %%
import os
import urllib.request
def download_stopwords(path):
    url = 'http://svn.sourceforge.jp/svnroot/slothlib/CSharp/Version1/SlothLib/NLP/Filter/StopWord/word/Japanese.txt'
    if os.path.exists(path):
        print('File already exists.')
    else:
        print('Downloading...')
        # Download the file from `url` and save it locally under `file_name`:
        urllib.request.urlretrieve(url, path)

def create_stopwords(file_path):
    stop_words = []
    for w in open(path, "r"):
        w = w.replace('\n','')
        if len(w) > 0:
          stop_words.append(w)
    return stop_words    

path = "stop_words.txt"
download_stopwords(path)
stop_words = create_stopwords(path)
# Out:
# File already exists.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectoriz
', '31', '310', '315', '31年', '31歳', '32', '320', '326', '32歳', '33', '333', '33歳', '34', '346', '34歳', '35', '350', '35年', '35歳', '36', '360', '365', '365日', '36歳', '37', '373', '37歳', '38', '39', '39歳', '3b', '3d', '3dcg', '3ds', '3g', '3jsb', '3k', '3m', '3p', '3q', '3r', '3rd', '3s', '3t', '3v', '3w', '3つ', '3万円', '3人', '3人家族', '3代目', '3位', '3児', '3分', '3割', '3回', '3年', '3年生', '3年目', '3度', '3日', '3月', '3月のライオン', '3期', '3期生', '3本', '3次元', '3歳', '3級', '3部', '40', '400', '4000', '40代', '40年', '40歳', '41', '41歳', '42', '43', '43歳', '44', '440', '444', '44歳', '45', '46', '4649', '47', '47都道府県', '48', '48グループ', '48歳', '49', '4b', '4d', '4dx', '4g', '4k', '4m', '4p', '4q', '4r', '4s', '4t', '4th', '4u', '4v', '4w', '4つ', '4コマ', '4コマ漫画', '4人', '4児', '4回', '4年', '4年生', '4年目', '4才', '4月', '4期', '4期生', '4本', '4歳', '4級', '4部', '50', '500', '5000', '500円', '50代', '50歳', '51', '510', '52', '53', '54', '55', '550', '550円', '555', '56', '57', '58', '59', '5d', '5g', '5m', '5s', '5t', '5v', '5w', '5万円', '5人', '5分', '5割', '5周年', '5回', '5年', '5年目', '5才', '5時', '5月', '5期', '5次元', '5歳', '5級', '5部', '60', '600', '6000', '61', '610', '612', '62', '63', '64', '65', '650', '66', '666', '67', '68', '69', '6g', '6m', '6t', '6v', '6w', '6人', '6位', '6回', '6年', '6年生', '6年目', '6月', '6期', '6歳', '70', '700', '7000', '70年代', '71', '72', '723', '728', '73', ' ...

# %%
print(len(vectorizer.get_feature_names()))
# Out:
# 13363

# %% [markdown]
# * 文書数と語彙サイズを変数にセット

# %%
n_samples, n_features = X.shape

# %% [markdown]
# ### TF-IDFで各文書における単語の重みを計算する

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf = TfidfTransformer()
Xtfidf = tfidf.fit_transform(X)

# %%
print(Xtfidf[0])
# Out:
#   (0, 11047)	0.431803321010621
#   (0, 10837)	0.33656875348588305
#   (0, 9484)	0.5130933332785758
#   (0, 9223)	0.13211295128074138
#   (0, 9017)	0.23896590223193948
#   (0, 8983)	0.25614707531784403
#   (0, 8682)	0.4747756969099675
#   (0, 4664)	0.1719552270462194
#   (0, 2706)	0.20457804496538182

# %%
Xtfidf.shape
# Out:
# (88481, 13363)

# %%
n_components = 6

# %% [markdown]
# ## 11-03 NMFでトピック抽出
# * まず、TF-IDFのデータ行列を使って　NMFによってトピック抽出を試みる。
#  * NMFのパラメータ群は下記サンプルコードのまま。
#  * https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html#sphx-glr-auto-examples-applications-plot-topics-extraction-with-nmf-lda-py

# %% [markdown]
# ### NMFとLDAのインポート

# %%
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %% [markdown]
# ### NMFによるトピック抽出の実行

# %%
from time import time

print((f"Fitting the NMF model (generalized Kullback-Leibler "
  f"divergence) with tf-idf features, n_samples={n_samples} "
  f"and n_features={n_features}"))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha=.1, l1_ratio=.5,
          verbose=1)
nmf.fit(Xtfidf)
print(f"done in {time() - t0:0.3f}s.")
# Out:
# Fitting the NMF model (generalized Kullback-Leibler divergence) with tf-idf features, n_samples=88481 and n_features=13363
# Epoch 10 reached after 2.509 seconds, error: 1680.460155
# Epoch 20 reached after 4.847 seconds, error: 1678.500589
# Epoch 30 reached after 7.185 seconds, error: 1677.944987
# Epoch 40 reached after 9.524 seconds, error: 1677.667771
# Epoch 50 reached after 11.861 seconds, error: 1677.508079
# done in 12.793s.

# %% [markdown]
# * NMFにおける各コンポーネントは、それぞれのトピックにおける単語の重要度を表すベクトルとして表現されている。

# %%
nmf.components_
# Out:
# array([[1.65148109e-02, 1.34028697e-02, 1.50681959e-03, ...,
#         1.36298496e-03, 6.17774559e-04, 3.22931643e-04],
#        [1.53018381e-01, 1.09810397e-02, 3.48289873e-03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [8.65940353e-06, 4.39714718e-03, 2.77157228e-03, ...,
#         5.79604807e-03, 0.00000000e+00, 0.00000000e+00],
#        [4.04683138e-03, 8.80197630e-13, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [5.10509570e-03, 1.01485043e-06, 0.00000000e+00, ...,
#         1.51627896e-03, 1.04033918e-02, 4.30708642e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.18941484e-03, 0.00000000e+00, 0.00000000e+00]])

# %% [markdown]
# ### トピックの重要語を取り出す関数の定義

# %%
def get_top_words(model, feature_names, n_top_words=30):
  top_features = list()
  weights = list()
  for topic_idx, topic in enumerate(model.components_):
    top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
    top_features.append([feature_names[i] for i in top_features_ind])
    weights.append(topic[top_features_ind])
  return top_features, weights

# %% [markdown]
# ### NMFの各コンポーネントから重要語を取り出す

# %%
top_words, weights = get_top_words(nmf, vectorizer.get_feature_names())

# %%
topic_words = [dict(zip(top_words[i], weights[i])) for i in range(n_components)]

# %%
topic_words[0]
# Out:
# {'好き': 2.3530810259394888,
#  '映画': 0.437770478523959,
#  'アニメ': 0.39129547934183295,
#  '趣味': 0.3635496891437839,
#  '音楽': 0.3436840750778855,
#  '写真': 0.3209291391161282,
#  '最近': 0.29745299067498737,
#  '人生': 0.28070045477434014,
#  '仕事': 0.26173127962254944,
#  '漫画': 0.2319059565352211,
#  'ゲーム': 0.21621678484730217,
#  '日々': 0.20258337610092558,
#  'ツイート': 0.19043432114481745,
#  '動物': 0.17355649262289258,
#  '現在': 0.17230060007716932,
#  '気軽': 0.15472435680366148,
#  'ブログ': 0.15166155942426576,
#  'アカウント': 0.15155873793212782,
#  'フォロー': 0.15128240617085764,
#  '料理': 0.1486482889512818,
#  '読書': 0.14838591523166234,
#  'たま': 0.14791047296330145,
#  '特撮': 0.14660863856656892,
#  '在住': 0.14483202015118105,
#  '勉強': 0.1392014097495919,
#  '基本': 0.13906268142671002,
#  '興味': 0.13899286829486557,
#  'バイク': 0.13210520880842722,
#  'おじさん': 0.13127152413387025,
#  '世界': 0.12616620587432711}

# %% [markdown]
# ### 重要語をワードクラウドで可視化

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# * ワードクラウドから除去するストップワードを確認する。

# %% [markdown]
# * ワードクラウドを描画

# %%
FONT_PATH = "/usr/share/fonts/opentype/ipaexfont-mincho/ipaexm.ttf"
cloud = WordCloud(stopwords=STOPWORDS,
                  font_path=FONT_PATH,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=100,
                  colormap='tab10'
                  )

# %%
# fig, axes = plt.subplots(10, 2, figsize=(32, 50), sharex=True, sharey=True)
tate = math.ceil(n_components / 3)
fig, axes = plt.subplots(tate, 3, figsize=(32, 50), sharex=True, sharey=True)
for i, ax in enumerate(axes.flatten()):
    
  if i > len(topic_words)-1:
    break
  fig.add_subplot(ax)
  cloud.generate_from_frequencies(topic_words[i], max_font_size=500)
  plt.gca().imshow(cloud)
  plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
  plt.gca().axis('off')

plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()

# %% [markdown]
# ## 11-04 LDAでトピック抽出

# %% [markdown]
# ### LDAによるトピック抽出の実行

# %%
lda = LatentDirichletAllocation(n_components=n_components, 
                                max_iter=20,
                                topic_word_prior=0.01,
                                learning_method='online',
                                learning_offset=50,
                                batch_size=200,
                                mean_change_tol=1e-4,
                                random_state=1,
                                evaluate_every=1,
                                verbose=1)

# %%
print((f"Fitting LDA models with tf features, "
  f"n_samples={n_samples} and n_features={n_features}"))
t0 = time()
lda.fit(X)
print(f"done in {time() - t0:0.3f}s.")
# Out:
# Fitting LDA models with tf features, n_samples=88481 and n_features=13363
# iteration: 1 of max_iter: 20, perplexity: 6692.4215
# iteration: 2 of max_iter: 20, perplexity: 6512.5604
# iteration: 3 of max_iter: 20, perplexity: 6460.0357
# iteration: 4 of max_iter: 20, perplexity: 6436.6653
# iteration: 5 of max_iter: 20, perplexity: 6422.9770
# iteration: 6 of max_iter: 20, perplexity: 6414.6399
# iteration: 7 of max_iter: 20, perplexity: 6408.9167
# iteration: 8 of max_iter: 20, perplexity: 6404.9163
# iteration: 9 of max_iter: 20, perplexity: 6401.9039
# iteration: 10 of max_iter: 20, perplexity: 6399.5434
# iteration: 11 of max_iter: 20, perplexity: 6397.6518
# iteration: 12 of max_iter: 20, perplexity: 6396.0082
# iteration: 13 of max_iter: 20, perplexity: 6394.6726
# iteration: 14 of max_iter: 20, perplexity: 6393.5925
# iteration: 15 of max_iter: 20, perplexity: 6392.6700
# iteration: 16 of max_iter: 20, perplexity: 6391.9034
# iteration: 17 of max_iter: 20, perplexity: 6391.2610
# iteration: 18 of max_iter: 20, perplexity: 6390.6738
# iteration: 19 of max_iter: 20, perplexity: 6390.1884
# iteration: 20 of max_iter: 20, perplexity: 6389.7551
# done in 499.562s.

# %% [markdown]
# ### LDAの各トピックから高確率語を取り出す

# %%
top_words, weights = get_top_words(lda, vectorizer.get_feature_names())

# %%
print(top_words[0])
# Out:
# ['好き', 'アニメ', '大好き', 'ゲーム', '漫画', '趣味', '映画', '最近', '音楽', '声優', '懸賞', 'よろしくお願いします', 'fgo', '仕事', '特撮', '当選', '鬼滅の刃', 'etc', 'オタク', 'ポケモン', 'ウマ娘', '報告', 'マンガ', 'モンスト', '旅行', '料理', 'lisa', '社会人', '声優さん', '動物']

# %%
topic_words = [dict(zip(top_words[i], weights[i])) for i in range(n_components)]

# %% [markdown]
# ### 高確率語をワードクラウドで可視化

# %%
cloud = WordCloud(stopwords=STOPWORDS,
                                font_path=FONT_PATH,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=100,
                  colormap='tab10'
                  )

# %%
# fig, axes = plt.subplots(5, 4, figsize=(16, 25), sharex=True, sharey=True)
tate = math.ceil(n_components / 2)
fig, axes = plt.subplots(tate, 2, figsize=(32, 50), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    
  if i > len(topic_words)-1:
    break

  fig.add_subplot(ax)
  cloud.generate_from_frequencies(topic_words[i], max_font_size=500)
  plt.gca().imshow(cloud)
  plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
  plt.gca().axis('off')

plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()


from matplotlib.backends.backend_pdf import PdfPages

import datetime
pdf = PdfPages( 
(datetime.datetime.now() + datetime.timedelta(hours=9) ) .strftime('%m%d_%H%M') + 'topic.pdf')


fignums = plt.get_fignums()
for fignum in fignums:
    plt.figure(fignum)
    pdf.savefig()

pdf.close()

# %%
top_words, weights = get_top_words(lda, vectorizer.get_feature_names(), 100)

# %%
def get_top_prof (topic_idx, top_n = 100):
    
    topics = lda.transform(X)
    prof_idx_list = topics[:, topic_idx].argsort()[:-top_n - 1:-1]
    print(prof_idx_list)
    print(docs[prof_idx_list[0]])
    return [docs[d] for d in prof_idx_list]
    # topics[45864]

# %%
get_top_prof(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-bb352cf156f0> in <module>
# ----> 1 get_top_prof(0)
#
# <ipython-input-44-1c136c94d94f> in get_top_prof(topic_idx, top_n)
#       1 def get_top_prof (topic_idx, top_n = 100):
# ----> 2     prof_idx_list = topics[:, topic_idx].argsort()[:-top_n - 1:-1]
#       3     print(prof_idx_list)
#       4     print(docs[prof_idx_list[0]])
#       5     return [docs[d] for d in prof_idx_list]
#
# NameError: name 'topics' is not defined

# %%
# new_docs[1]
docs[1]

# %%
# Out:
# array([[0.7370671 , 0.01515154, 0.20232674, 0.01515152, 0.01515159,
#         0.01515152],
#        [0.01201757, 0.01191033, 0.86892913, 0.08333333, 0.01190476,
#         0.01190487],
#        [0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#         0.16666667],
#        ...,
#        [0.23299411, 0.05934567, 0.41826477, 0.07169308, 0.05105636,
#         0.16664601],
#        [0.05584373, 0.05555556, 0.05555556, 0.72193405, 0.05555556,
#         0.05555556],
#        [0.01396672, 0.01388897, 0.42283275, 0.26388889, 0.10457594,
#         0.18084674]])
