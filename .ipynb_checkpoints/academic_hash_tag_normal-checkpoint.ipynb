# %%
#JSONとOAuth認証用のライブラリを使用
import json
from requests_oauthlib import OAuth1Session
import tweepy
import os

# %%
#import setting
import ac_setting as setting


twitter = OAuth1Session(setting.CONSUMER_KEY, setting.CONSUMER_SECRET, setting.ACCESS_TOKEN, setting.ACCESS_SECRET)

# %%
# !pip install tweepy

# %%
keyword = "#金曜ロードSHOW"

q = keyword
#認証
auth = tweepy.OAuthHandler( setting.CONSUMER_KEY, setting.CONSUMER_SECRET )
auth.set_access_token( setting.ACCESS_TOKEN, setting.ACCESS_SECRET)

api = tweepy.API(auth, wait_on_rate_limit = True)

#検索キーワード設定 
q = keyword

#つぶやきを格納するリスト
tweets_data =[]

#カーソルを使用してデータ取得
for tweet in tweepy.Cursor(api.search, q=q, count=100,tweet_mode='extended').items():

    #つぶやきテキスト(FULL)を取得
    tweets_data.append(tweet.full_text + '\n')

#出力ファイル名
dfile = "../data/hash_tag"
fname = "init.txt"
if not os.path.exists( dfile):
    os.mkdir(dfile)

#ファイル出力
with open(dfile+"/"+fname, "w",encoding="utf-8") as f:
    f.writelines(tweets_data)

# print
for i in range(len(tweets_data)):
    if i % 100 == 0: 
        print(tweets_data[i])
# Out:
# RT @Nonmikotake: 若い人は罹らないという考えは捨てようね…
# 某県では学童保育で１０歳未満のクラスターが発生…
# 学童保育だけでなく小学校も臨時休校、そこから保護者や家族にまで波及する恐れがある…
# 高齢者と同居している者もいる為今後拡大して重症者の恐れもある…
#  #…
#
# RT @PONURU_SDBH: 芸人の有吉さんと結婚💍されました【真相報道バンキシャ！】の司会を勤める【夏目三久さん】が9月をもって引退されることについて語り、枡アナから最近の新婚生活について、聞かれました❗️😊
#
# #バンキシャ
# #夏目三久 https://t.co/qLo…
#
# RT @yukkuri_sion: バンキシャで秋葉原を報道してますが、これで
# 「オタクが感染者を増やしてる」
# 「秋葉原を重点に規制しよう」
# 「ゲームやプラモ(フィギュア)を規制対象にしよう」
# と生贄論をやりたがるメディアの考えが見えますよ。
# #バンキシャ
# #日テレ
# #表現規制…
#
# RT @1123macha4: 緊急事態宣言初日。
# 18時の渋谷。
# 全然人が減ってない。
# これでは2週間で減少するんでしょうか？
# 出かけている人はなぜ我慢できない？
# 大人しく家でステイホームしている自分がバカバカしくなっている。
# #バンキシャ　#緊急事態宣言　＃多過ぎ　#105…
#
# RT @lemmy_miyauchi: バンキシャ!を観てたら、昨日秋葉原で駆け込みで買い物に来ていた人をインタビュー
#
# ごちうさのシャロちゃんドールを買っていたごちうさ民がwww
#
# #バンキシャ
# #gochiusa https://t.co/QSrW9SJFpq
#
# 4月25日ナツメグラム
# #夏目三久 キャスターファッションチェック
#
# スタイリストさんから今日の衣装のワンポイント
# 春色の爽やかなワンピースです。
#
# https://t.co/gClGrRNuS0 #バンキシャ
#
# RT @oricon: 夏目三久、9月で『バンキシャ』も卒業　桝太一アナ本音「コンビ組んだばかりで寂しい…」
# https://t.co/C4xv0eMgQt
#
#  #夏目三久 #日テレ #バンキシャ
#
# RT @take_ji: 結局、”出かけないようにしよう”とは最後まで一言も言わずに終わらせるバンキシャ
#
# それで、よく”政府のメッセージが国民に伝わらない”などと軽々しく言うよな
#
# 自分達が”政府のメッセージを伝えない”ように努力しているだけだろうが
#
# #ntv #バンキシャ
#
# RT @marchrabbit0615: さっきからヒャダインが政府が我慢ばかり強いてるから不満がとか気候が良いからとか飲みに行ったり外出する人達に寄り添ってる風で…。
# 若者の代表面してるけどもう40歳でしょ。
# 若者に向けて何故自粛が必要なのか、何故飲み会が駄目なのか分かりやす…
#
# RT @ku96roku96ro: コロナは月に何回も変異を起こしてる。だから、人類が滅びても、コロナ感染は他の生物で起こるから、感染ゼロは無理。それを国民に伝え、ゴールを設定しないと、この状況はいつまでも続く。#バンキシャ!
#
# 芸能人のコメンテーターって本当に雑なコメントばっかでイライラする。なんでも政府や行政のせいにするから、みんながそう言う思考になる。みんなでワクチンが打てるまで頑張ろう！の一言がなぜ言えないかなぁ。
# #バンキシャ
#
# #バンキシャ
#
# 一人暮らしの若者ってそんな公園とか集まる？笑
#
# 公園と駅の混雑を比較されてもね……
#
# #バンキシャ
#
# 5/11に解除すると7月のオリンピックの時期にもう一回緊急事態宣言を入れなければならなくなるんですってよ
#
# #バンキシャ
#
# RT @muttsumuttsu: 今の渋谷の様子。東京でも緊急事態宣言出てるっちゅうのに人多いやん！
# #バンキシャ
# #真相報道バンキシャ https://t.co/BuVRG079zi
#
# 「劇場とか配信に」って政府は気軽に言うけど、オンラインは必要以上にお金かかるんだよ(怒)
# #バンキシャ
# #ヒャダイン
#
# えーっ！
# 結婚式場も酒類の提供が出来ないの？！🤙🏽😂 #バンキシャ #緊急事態宣言
#
# 政府のせいにする前に自分の行動を見直すべき。 #バンキシャ
#
# 今日から緊急事態宣言で商業施設とかが閉まるのを知らずに遊びに来る人って、、、せめてネットででもニュース見ようよ、、、
#
#  #バンキシャ
#
# RT @megane2_taka: 『渋谷の様子です！』
#
# 世間は、、
#
# 緊急事態宣言、、
#
# まるっきり、無視‼️でした…
#
# #バンキシャ
#
# 県独自の緊急事態だのなんだのやり過ぎて緊急事態とか言われても知らんがなだわな #バンキシャ
#
# RT @yukkuri_sion: バンキシャで秋葉原を報道してますが、これで
# 「オタクが感染者を増やしてる」
# 「秋葉原を重点に規制しよう」
# 「ゲームやプラモ(フィギュア)を規制対象にしよう」
# と生贄論をやりたがるメディアの考えが見えますよ。
# #バンキシャ
# #日テレ
# #表現規制…
#
# なぜモザイク？
#
# モザイクするなら
# インタビュー受けなきゃいいのに……
#
# #バンキシャ
#
# 駆け込みでわざわざ買う必要あるの？それ？って聞きたい #バンキシャ
#
# こうやってバカが出歩いて外食したりして無駄な税金が使われる。罰則で100万ずつくらい回収してくれ。
# #バンキシャ
#
# まあこれが日本の実態で、そういう国民を作ったのは政府ではなく、間違いなくメディア。重罪だよ。国民はもっと放送に対して厳しくなるべきだ。スポンサーにも厳しい目を向けるべきだ。 #バンキシャ
#
# 悔しいのぉｗｗｗ #バンキシャ
#
# RT @jiro80578981: 東京は検査数も操作してるから実態は解らない‼️
# 東京基準とかも‼️#バンキシャ!
#
# こちらは、3度目の緊急事態宣言直前、土曜日の都内の様子です。
# あす、宣言初日に人出はどう変化するのでしょうか。
# #バンキシャ取材中
# #緊急事態宣言
# #バンキシャ #桝太一 https://t.co/3Z3eGAHqRp
