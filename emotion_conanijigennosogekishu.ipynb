# %% [markdown]
# # 2021-04-16_名探偵コナン異次元の狙撃手の金ローの口コミ

# %%
import pandas as pd

# %%
from mlask import MLAsk
emotion_analyzer = MLAsk()

# %%
df = pd.read_csv("./2021-04-16_名探偵コナン異次元の狙撃手.csv")

# %%
# tweetサンプル
df[df ["retweet"] < 10].text[:20]
# Out:
# 1      RT @vader0627: 女子高生蘭姉ちゃんと戦士蘭姉ちゃんが見れるのはコナンの映画のい...
# 6      やっぱり安定のコナンはドキドキ感がヤバい😳💓@kinro_ntv 金ローで過去作全部やって欲...
# 15     RT @fm09051: いいかい？よく聞くんだ！『ボヘミアン・ラプソディ』吹替版の本編は、...
# 17                 俺は高校生探偵工藤新一…あれれおかしいぞ？やらんのか？#金曜ロードSHOW
# 33     RT @autunn0: あ、今流れた浜辺美波ちゃんのコメント映像、作りました！！！(不意打...
# 51     金曜ロードショー見逃した方無料で見れます！違法サイトじゃないです！笑#コナン #conan ...
# 70     RT @fm09051: いいかい？よく聞くんだ！『ボヘミアン・ラプソディ』吹替版の本編は、...
# 72     RT @vader0627: 女子高生蘭姉ちゃんと戦士蘭姉ちゃんが見れるのはコナンの映画のい...
# 89     RT @https_nasi_gore: #金曜ロードSHOW1度トランプ氏だと思ったらもう...
# 90     異次元の狙撃手は去年DVDをレンタルしたけど、沖矢昴の正体が赤井秀一である事が当時の原作でも...
# 107    今夜の名探偵コナンの映画異次元の狙撃手面白かった３ ＃金曜ロードＳＨＯＷ／＃金曜ロードショー...
# 109    今夜の名探偵コナンの映画異次元の狙撃手面白かった２ ＃金曜ロードＳＨＯＷ／＃金曜ロードショー...
# 110    今夜の名探偵コナンの映画異次元の狙撃手面白かった１ ＃金曜ロードＳＨＯＷ／＃金曜ロードショー...
# 111    やっぱりコナンは面白いわ！今、公開してる劇場版も見たいな！この流れで前に金曜ロードショーで録...
# 116    異次元の狙撃手よかった！！やっぱり赤井さんかっこいい❤️来週の天国へのカウントダウンも大好き...
# 126    劇場版名探偵コナンの地上波放送、EDカットだけでなくOPもカットされてたのな。。　#名探偵コ...
# 131    え！？細目の方から赤井さんの声がしたんだけど！！！#金曜ロードSHOW #名探偵コナン異次元...
# 132    RT @mk513love: ティモシーさん、普通に歩いて逃亡してて草#名探偵コナン異次元の...
# 133                           #金曜ロードSHOWヘルメットがなければ即死だったw
# 142    RT @susuki_Mk2: 園子「蘭なら空手で跳ね返すんじゃない？」蘭「も～、そんなわけ...
# Name: text, dtype: object

# %%
result_dict = {}
no_emo = 0
for tmp_text in df[df ["retweet"] < 10].text:
#     print(tmp_text)
    tmp_result = emotion_analyzer.analyze(tmp_text)
    if "orientation" in tmp_result.keys():
        print ("representative:",tmp_result["representative"] , "orientation:" , tmp_result["orientation"], ",  activation:", tmp_result["activation"])
        if not tmp_result["representative"][0] in result_dict.keys():
            result_dict[tmp_result["representative"][0]] = 1
        else:
            result_dict[tmp_result["representative"][0]] += 1
        
    else:
        no_emo+=1
# Out:
# representative: ('odoroki', ['驚く']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['大好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['楽しむ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['笑い', '面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['かわいい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好く']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('odoroki', ['びっくり']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('yorokobi', ['楽しみ', '面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('kowa', ['不安']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['拍手', '面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['楽しむ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('kowa', ['気になる']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('kowa', ['気になる']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEUTRAL ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['拍手', '面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['お気に入り']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['物足りない', '物足りないさ']) orientation: NEUTRAL ,  activation: NEUTRAL
# representative: ('iya', ['好き*CVS']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ', '面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['大好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しむ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: mostly_NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: mostly_NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['楽しい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: NEUTRAL ,  activation: PASSIVE
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['好き', '情熱']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('aware', ['沈む', '涙']) orientation: NEGATIVE ,  activation: PASSIVE
# representative: ('yorokobi', ['楽しむ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['感謝']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('odoroki', ['衝撃']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('yorokobi', ['笑う']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['楽しむ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['感謝']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しむ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yasu', ['安心']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('haji', ['侮辱']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('odoroki', ['ショック']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('odoroki', ['衝撃']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('yasu', ['カット*CVS']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('aware', ['泣く']) orientation: mostly_NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['鳥肌']) orientation: mostly_NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['可愛い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['懐かしい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('kowa', ['戦慄']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['大好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['後悔']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['可愛い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['爆発する']) orientation: mostly_NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['堪るない']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('odoroki', ['衝撃']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('odoroki', ['びっくり']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('suki', ['惚れる']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや', '舌打ち']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('iya', ['痛い']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['舌打ち']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('suki', ['かわいい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['惜しげ']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('suki', ['大好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('aware', ['痛める']) orientation: NEGATIVE ,  activation: PASSIVE
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('kowa', ['怖い']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['懐かしむ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('aware', ['おいおい']) orientation: NEGATIVE ,  activation: PASSIVE
# representative: ('ikari', ['カット']) orientation: mostly_NEGATIVE ,  activation: mostly_ACTIVE
# representative: ('iya', ['呪う']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('iya', ['卑怯']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('suki', ['懐かしい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('kowa', ['気になる']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('iya', ['鳥肌']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['痛い']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['ナイス']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['感謝']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('odoroki', ['びっくり']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('kowa', ['心配']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['いやらしい*CVS']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('takaburi', ['褒める']) orientation: mostly_POSITIVE ,  activation: ACTIVE
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('suki', ['可愛い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('suki', ['大好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['怒る', '怒るせる']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['可愛い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['可愛い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('aware', ['悲しい']) orientation: NEGATIVE ,  activation: PASSIVE
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('takaburi', ['打つれる']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('aware', ['泣く']) orientation: mostly_NEGATIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('takaburi', ['打つれる']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['震える']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['馬鹿']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('kowa', ['怖い']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['懐かしい']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['ややこしい']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しむ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('odoroki', ['ショック']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('kowa', ['怖い']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yasu', ['安心']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('yorokobi', ['笑う']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['うれしい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('takaburi', ['焦る']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('suki', ['惚れる']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('kowa', ['気になる']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('aware', ['悲しい']) orientation: NEGATIVE ,  activation: PASSIVE
# representative: ('iya', ['堪るない']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('suki', ['惚れる']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['面白いない']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['大好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['見下す']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['幸せ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['迷惑']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['愉快']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yasu', ['さっぱり']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('yorokobi', ['覇気']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['迷惑']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['怒る']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['楽しむ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['諦める']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['笑う']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['いやいや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('aware', ['悲劇']) orientation: NEGATIVE ,  activation: PASSIVE
# representative: ('iya', ['邪魔']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['幸せ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['かわいい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['反抗', '怨恨']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('iya', ['あくどい', 'いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['笑う']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['いやいや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('aware', ['おいおい']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('aware', ['悲しい']) orientation: NEGATIVE ,  activation: PASSIVE
# representative: ('iya', ['参る']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('aware', ['かわいそう']) orientation: NEGATIVE ,  activation: PASSIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('aware', ['泣く', '泣くく面']) orientation: mostly_NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['爆発する']) orientation: mostly_NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['面白い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['いやいや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['苦労']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['かわいい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['痛い']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['爆発する']) orientation: mostly_NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['飽きる']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yasu', ['余裕']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('suki', ['可愛い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('iya', ['ちゃっかり']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('iya', ['容赦ない']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['ナイス']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['飽きる']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['迷惑']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('aware', ['泣ける']) orientation: NEGATIVE ,  activation: PASSIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['満足']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['冷める*CVS']) orientation: mostly_NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['懐かしい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('odoroki', ['びっくり']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('kowa', ['小さいなる']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('kowa', ['怖い']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['大好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['悪質']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yasu', ['気になる*CVS']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yorokobi', ['わーい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('aware', ['悲しい']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['叱る']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('kowa', ['怖い']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('odoroki', ['びっくり', '衝撃']) orientation: mostly_POSITIVE ,  activation: ACTIVE
# representative: ('iya', ['いや']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('iya', ['容赦ない']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('ikari', ['カット']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('yasu', ['落ち着く']) orientation: POSITIVE ,  activation: PASSIVE
# representative: ('iya', ['大変']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['ラッキー']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['嬉しい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['嫌']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('ikari', ['震わせる']) orientation: NEGATIVE ,  activation: ACTIVE
# representative: ('iya', ['大変']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('suki', ['カワイイ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['明るい*CVS']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('suki', ['可愛い']) orientation: NEUTRAL ,  activation: ACTIVE
# representative: ('suki', ['可愛い']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['大変']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['歓声']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('suki', ['好き']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('iya', ['反対']) orientation: NEGATIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['嬉しい']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL
# representative: ('yorokobi', ['楽しみ']) orientation: POSITIVE ,  activation: NEUTRAL

# %%
no_emo
# Out:
# 1154

# %%
ordered_result = sorted(result_dict.items(), key=lambda x:x[1],  reverse=True)

# for tmp_key in result.keys():
#     val_dict=

# %%
from IPython.display import display, HTML
display(HTML("<font size='5' color='#FF7777'>結果<br>" +str (ordered_result) + "</font>"))
# Out:
# <font size='5' color='#FF7777'>結果<br>[('yorokobi', 75), ('ikari', 74), ('suki', 62), ('iya', 58), ('aware', 14), ('kowa', 13), ('odoroki', 11), ('yasu', 7), ('takaburi', 4), ('haji', 1)]</font>

# %%
str (ordered_result)
# Out:
# "[('yorokobi', 75), ('ikari', 74), ('suki', 62), ('iya', 58), ('aware', 14), ('kowa', 13), ('odoroki', 11), ('yasu', 7), ('takaburi', 4), ('haji', 1)]"

# %%
for x in ordered_result :
    print("感情_"+x[0]+"\t:"+ str( x[1])+"人が感じた")
# Out:
# 感情_yorokobi	:75人が感じた
# 感情_ikari	:74人が感じた
# 感情_suki	:62人が感じた
# 感情_iya	:58人が感じた
# 感情_aware	:14人が感じた
# 感情_kowa	:13人が感じた
# 感情_odoroki	:11人が感じた
# 感情_yasu	:7人が感じた
# 感情_takaburi	:4人が感じた
# 感情_haji	:1人が感じた

# %%
# tableau用
tableau_dict = {
        "iya":0,
    "yorokobi":0,
    "kowa":0,
    "yasu":0,
    "aware":0,
    "suki":0,
    "ikari":0,
    "takaburi":0,
    "haji":0,
    "odoroki":0,
}

for tmp in ordered_result :
    tableau_dict[tmp[0]] = tmp[1]

df_t = pd.DataFrame(tableau_dict,index=['num',]).T.reset_index().rename(columns={'index': 'emotion'})

df_t["movie_name"] = "名探偵コナン異次元の狙撃手"
df_t["movie_date"] = "2021-04-16"
df_t["all_tweet_num"] = len(df)
df_t["tweet_num_no_many_retweet"] = len(df[df ["retweet"] < 10])

df_t.to_csv(df_t["movie_name"][0]+".csv", encoding="shift_jis")
